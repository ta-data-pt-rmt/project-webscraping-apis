# %%
# this is the library that we will use to create break times in order to mimic human behaviour 
import time

# this library will be used for getting your credentials but keeping them hidden in the script 
from getpass import getpass

# these are the Classes we will use for interaction with a webpage
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager 


# library for interacting with the operating system
import os

# you know pandas it's your best buddy 
import pandas as pd


#Ignore warning -- Some methods are going to be deprecated and I didn't change all (mainly in the function scrapper)
import warnings
warnings.filterwarnings('ignore')

# Extract soup for scraping
from bs4 import BeautifulSoup
import re
import requests
import random
import numpy as np

# %%
#https://www.glassdoor.ie/member/home/index.htm
#https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm?clickSource=searchBtn

# %%
headers= {'Accept-Encoding':'gzip, deflate',
          'Accept-Language':'en-US,en;q=0.9',
          'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}

# %%
#response = requests.get(html ,headers=headers)
#soup = BeautifulSoup(response.content)

# %%
# driver path

## driver path should be the location of the folder where the driver you downloaded is ## 

#driver_path = '/Users/alex/Documents/Tools/Drivers - Selenium/chromedriver' 

## first we need to initiate the driver - probably the most important part of the code ##
#driver = webdriver.Chrome(executable_path = driver_path)

# or new version 
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#driver.get('https://www.glassdoor.ie/member/home/index.htm')
driver.get('https://www.glassdoor.com/member/home/index.htm')

# login into your Glassdoor account

# input your email

email = input('Enter your email: ')

# here we are going to find the box where we input the email
email_box = driver.find_element(By.ID, "inlineUserEmail") #email_box = driver.find_element_by_id("username") #deprecated

#clear the search box if it has already something in there
email_box.clear()

# with the method send_keys() you can send the information from the script to the webpage
email_box.send_keys(email)
time.sleep(2)

# input the password
password = getpass('Enter your password: ')

# here we are going to find the box where we input the password
pass_box = driver.find_element(By.ID, 'inlineUserPassword') #pass_box = driver.find_element_by_id('password') #deprecated

#clear the paword box if it has already something in there
pass_box.clear()

# here we will send the password to the driver 
pass_box.send_keys(password)
time.sleep(1)

login = driver.find_element(By.CLASS_NAME,'gd-ui-button') #login = driver.find_element_by_class_name('gd-ui-button mt-std minWidthBtn css-14xfqow evpplnh0') #deprecated
#login =  driver.find_element(By.CSS_SELECTOR, '[name="submit"]').send_keys("webElement")
login.click()
time.sleep(1)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [C:\Users\Sergio Manzano\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache
# Enter your email: libertad.pozos@gmail.com
# Enter your password: ········

# %%
role = input('Enter position role: ')
# here we are going to find the box where we input the email
seachboxrole = driver.find_element(By.ID, "sc.keyword")
#clear the search box if it has already something in there
seachboxrole.clear()
# with the method send_keys() you can send the information from the script to the webpage
seachboxrole.send_keys(role)
time.sleep(2)

#Click dropdown to select salaries
#dropdown_salaries = driver.find_element(By.CLASS_NAME,'selectedLabel') 
dropdown = driver.find_element(By.CLASS_NAME,'css-5j38mw')
#dropdown = driver.find_element(By.CLASS_NAME,'css-5j38mw')
dropdown.click()

#test max window
#driver.maximize_window()

#Click dropdown to select salaries
#dropdown_salaries = driver.find_element(By.CLASS_NAME,'selectedLabel') 
dropdown_salaries = driver.find_element_by_xpath("// span[contains(text(),\'Salaries')]").click()
# Out:
# Enter position role: Web Developer junior

# %%
# Get data for every city in the list
maindf3= pd.DataFrame()
output =[]
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']
count = 0
mainlist=[]

for city in cities:
    
    try:   
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        time.sleep(3)
        
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        
        
                
        #driver.get(html)
        soup = BeautifulSoup(html)
        output.append(soup)
        # send html to a .txt rewrite the name for each one 
        
        
       

        #url = driver.current_url
        #response = requests.get(url ,headers=headers)
        print(response)
        #soup = BeautifulSoup(response.content)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys = city
        #citydetail[0]["value"]
        position_summary_detail.append(citys)
        print(citys)
    
        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        
        
        position = positiondetail[0].text
        position_summary_detail.append(position)
        print(positions)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)
        print(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)
        print(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)
        print(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)
        print(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)
        print(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)
        print(positioninfo)
        
        mainlist.append(position_summary_detail)
        print('Main list: ',position_summary_detail)
        
        #Dataframe creation
        position_summary_detail_df = pd.DataFrame(np.array(position_summary_detail).reshape(-1,len(position_summary_detail)))
        position_summary_detail_df.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
        position_summary_detail_df
        maindf3 = pd.concat([maindf,position_summary_detail_df])

    except:
        
        print("Falied city:",city)
    
    
       
num = np.random.randint(1,10000000)    
glassdoor_role_table = maindf.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_table{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_unique.csv')
maindf3
# Out:
# <Response [200]>
# Dublin
# Falied city: Dublin
# <Response [200]>
# Amsterdam
# Falied city: Amsterdam
# <Response [200]>
# Madrid
# Falied city: Madrid
# <Response [200]>
# Paris
# Falied city: Paris
# <Response [200]>
# Berlin
# Falied city: Berlin
# <Response [200]>
# Milan
# Falied city: Milan
# <Response [200]>
# London
# Falied city: London
# <Response [200]>
# Barcelona
# Falied city: Barcelona
# <Response [200]>
# Frankfurt
# Falied city: Frankfurt
# <Response [200]>
# Lisbon
# Falied city: Lisbon
# Empty DataFrame
# Columns: []
# Index: []

# %%
position_summary_detail
# Out:
# ['Lisbon', 'Junior Data Analyst Salaries in Lisbon, Portugal Area']

# %%
position
# Out:
# 'Junior Data Analyst Salaries in Lisbon, Portugal Area'

# %%
updatedate
# Out:
# 'Updated 1 May 2022'

# %%
avgbasepay
# Out:
# '€44,470'

# %%
positioninfo
# Out:
# 'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.'

# %%
soup
# Out:
# <html class="canvas svgfilters cssfilters no-touchevents" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head>
# <title>Salary: Junior Data Analyst in Lisbon, Portugal | Glassdoor</title>
# <meta content="8gasaHBZws6-VlwUeolXJRSp0aUrfYzMYjiPfCwfn7" name="globalsign-domain-verification"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="yes" name="apple-mobilegi-web-app-capable"/><meta content="origin" name="referrer"/><meta content="589698942" property="al:ios:app_store_id"/><meta content="Glassdoor" property="al:ios:app_name"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="website" property="og:type"/><meta content="Glassdoor" property="og:site_name"/><meta content="129253937150340" property="fb:app_id"/><meta content="https://www.glassdoor.ie/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" property="og:url"/><meta content="https://www.glassdoor.com/app/static/img/partners/fb/logo-1200x630.png?v=721f9cswl" property="og:image"/><meta content="app-id=589698942" name="apple-itunes-app"/><meta content="app-id=com.glassdoor.app" name="google-play-app"/>
# <meta content="Salary: Junior Data Analyst in Lisbon, Portugal" data-rh="true" property="og:title"/><meta content="543 Junior Data Analyst Salaries in Lisbon, Portugal provided anonymously by employees. What salary does a Junior Data Analyst earn in Lisbon?" data-rh="true" name="description"/><meta content="543 Junior Data Analyst Salaries in Lisbon, Portugal provided anonymously by employees. What salary does a Junior Data Analyst earn in Lisbon?" data-rh="true" property="og:description"/>
# <link data-rh="true" href="https://www.glassdoor.ie/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm?clickSource=searchBtn" rel="canonical"/><link data-rh="true" href="https://www.glassdoor.ie/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26_IP2.htm?clickSource=searchBtn" rel="next"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link href="https://www.glassdoor.com/app/static/css/gd-salary-search-core.css?v=12da73993m" media="all" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/app/static/js/dist/gd-site-header.bundle.css?v=f2b9beoqb" media="all" rel="stylesheet" type="text/css"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-57.png?v=595028252" rel="apple-touch-icon-precomposed"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-72.png?v=e859f12fg" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-114.png?v=81fd863hl" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-144.png?v=0efaf240j" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="/manifest.json" rel="manifest"/><link href="https://www.glassdoor.ie/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" rel="canonical"/><link href="https://www.glassdoor.ie/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-IE" rel="alternate"/><link href="https://www.glassdoor.com.au/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-AU" rel="alternate"/><link href="https://www.glassdoor.ca/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-CA" rel="alternate"/><link href="https://www.glassdoor.com.hk/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-HK" rel="alternate"/><link href="https://www.glassdoor.co.in/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-IN" rel="alternate"/><link href="https://www.glassdoor.co.nz/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-NZ" rel="alternate"/><link href="https://www.glassdoor.sg/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-SG" rel="alternate"/><link href="https://www.glassdoor.co.uk/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en-GB" rel="alternate"/><link href="https://www.glassdoor.com/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm" hreflang="en" rel="alternate"/>
# <script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=8294f20830faf9e24a0e8ab5b69c846f"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-RJF0GNZNXE&amp;l=gdGlobals&amp;cx=c" type="text/javascript"></script><script async="" src="https://unpkg.com/web-vitals/dist/web-vitals.iife.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-RC95PMVB3H&amp;l=gdGlobals&amp;cx=c" type="text/javascript"></script><script defer="" src="//www.googletagmanager.com/gtm.js?id=GTM-PST2JZ&amp;l=gdGlobals"></script><script>
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/search/salaries?cat=Salaries&o=data+analyst+junior&l=Lisbon+%28M%3A+1121%29",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-IE',
# 			'env': 'prod',
# 			'release': '20220426-2',
# 			'appName': 'app',
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.ie",
# 								'domainId':		18,
# 								'domainCountryId': 70,
#
#
# 								'domainSuffix': "ie",
#
#
# 								'group':        "Search-Salaries",
#
#
# 								'projectUrlGroup':        "[]",
#
#
# 								'guid':         '000001808bfd0748beff41aa82ab895b',
#
#
# 								'flex':         true,
#
#
# 								'section':      "search",
#
#
# 								'type':         "search:search-salaries",
#
#
# 								'id':           "search:search-salaries",
#
# 								'med': '',
#
# 								'src' : '',
# 								'content' : '',
# 								'campaign' : '',
# 								'term' : '',
# 								'state' : 'open',
# 								'untranslatedUrl' : 'https://www.glassdoor.com/Salaries/lisbon-data-analyst-junior-salary-SRCH_IL.0,6_IM1121_KO7,26.htm'
#
#                                     , 'modulesDisplayed': {
#                                         'occMedianNationalShown': 'N',
#                                         'occMedianMetroShown': 'N',
#                                         'employerSalariesShown': 'N',
#                                         'recentSalariesShown': 'N',
#                                         'relatedSalariesShown': 'N',
#                                         'kywPromoShown': 'Y'
#                                     }
#
# 							},
#
# 			'user':         {
#
# 								'guid':         'ad7a112e-9b1d-473b-8c25-d19fb6f1a372',
#
# 									'id': "177444508",
#
# 									'membershipType': "BASIC",
# 									'isLapsedMember': "FALSE",
# 									'age' : "",
# 									'gender' : "",
# 									'education' : "",
# 									'regDate' : '20201214',
# 									'regMonth' : 'diciembre',
# 									'profile' : 'true',
#
# 								'ipAddr':       "84.203.86.255",
#
#
# 								'locale':       "en_IE",
#
#
# 								'country':      "IE",
# 								'ipLocationId': "2739035",
# 								'ipLocationType': "C",
#
# 								'elligibleForAppBoy': true,
# 							},
#
# 			'vendor':       {
# 								'fbReqPerms':   ""
# 							},
#
# 				'implicitLoc':'Lisbon, Portugal Area (Portugal)',
#
# 			'search':       {
#
# 				"rawKeyword":"Data analyst junior"
#
# 								, 'location': "Lisbon, Portugal",
# 								'locationType': "M",
# 								'locationId': "1121"
#
# 								, 'occupation' : "data analyst junior"
#
# 								, 'totalSearchResults': "0",
# 								'displayedSearchResults': "-1",
# 								'pageNumber': "1",
# 								'noData' : 'true'
#
# 								, 'searchQueryGuid' : ""
#
# 							, 'segmentType' : "OL"
#
# 			},
# 			'employer' : {
#
# 			},
# 			'job' : {
#
# 			},
# 			'test' : {
#
# 				'planoutIdList': [
#
# 						, "site_discovery_ugc_search2.PROD_ugc_search2_v1"
#
# 						, "site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1"
#
# 						, "lightweight_data_collection.exp_user_profile_catchall"
#
# 						, "growth_global.exp_growth_global_catchAll"
#
# 						, "brand_ads_company_explorer.native_ads_explore"
#
# 						, "user_profile.exp_user_profile_catchall"
#
# 						, "total_comp_salaries_ui_refresh_dec2021.PROD_total_comp_salaries_ui_refresh_20211202"
#
# 						, "content_single_page_survey.CXP_1419_PROD_test"
#
# 						, "brand_ads_company_compare.native_ads_compare"
#
# 						, "site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1"
#
# 						, "content_reviews_node.I18N_redirect_reviews_node_test_20190530"
#
# 						, "content_survey_global_context.CON_238_PROD_test_051221"
#
# 						, "site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1"
#
# 						, "nuf_steps.last_step_test"
#
# 						, "ei_compare_rollout.TRFC_4368_ei_compare"
#
# 						, "company_explorer.TRFC_4524_02102020"
#
# 						, "growth_user_activation.user_activation_post_auth_redirect_exp_20220201"
#
# 						, "site_discovery_nav.site_discovery_nav_t2"
#
# 						, "nuf_v2_1.ipad_promotion_test"
#
# 						, "growth_jobs.growth_jobs_default_catchAll"
#
# 						, "nuf_gd_logo.disabled_logo_test"
#
# 						, "site_discovery_header.exp_site_discovery_header_catchall"
#
# 						, "total_comp_salary_occupation_new_ui.total_comp_salary_occupation_new_ui_test_04142021"
#
# 						, "site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall"
#
# 				],
# 				'planoutTreatmentList': [
#
# 						, "ugc_search2_t1"
#
# 						, "ugc_search2_salaries_t1"
#
# 						, "lightweight_data_collection_default"
#
# 						, "growth_global_default"
#
# 						, "native_ads_explore_t1"
#
# 						, "user_profile_default_treatment"
#
# 						, "salaries_ui_t1"
#
# 						, "single_page_t1"
#
# 						, "native_ads_compare_t1"
#
# 						, "ugc_search2_autocomplete_t1"
#
# 						, "redirect2Node_t1"
#
# 						, "new_suggested_companies_t1"
#
# 						, "ugc_search2_interviews_t1"
#
# 						, "last_step_test_control"
#
# 						, "ei_compare_activated"
#
# 						, "test_on"
#
# 						, "post_auth_redirect_t1"
#
# 						, "career_nav_t2"
#
# 						, "nuf_v2_1_control"
#
# 						, "growth_jobs_default"
#
# 						, "disabled_logo_test_t1"
#
# 						, "site_discovery_header_default"
#
# 						, "salary_occupation_new_ui_t1"
#
# 						, "fishbowl_default"
#
# 				]
# 			},
# 			'staticList' : {
#
# 			}
#
# 		}];
#
# 	if(window.projectUrlGroup && Array.isArray(window.projectUrlGroup)) {
# 		var globalsProjectUrlGroup = JSON.parse(gdGlobals[0].page.projectUrlGroup);
# 		var combined = globalsProjectUrlGroup.concat(window.projectUrlGroup);
# 		gdGlobals[0].page.projectUrlGroup = JSON.stringify(combined);
# 	}
#
#
# 	window.getGdGlobals = window.getGdGlobals ||
# 			function() {
# 				return gdGlobals[0];
# 			};
#
# 	GD = window.GD || {};
# 	GD.pageInfo = GD.pageInfo || {};
# 	GD.pageInfo.pageGroup = getGdGlobals().page.group;
# 	GD.domain = getGdGlobals().page.domain;
#
# 	</script><script>
#
# 			(function(w,d,s,l,i) {
# 				w[l] = w[l] || [];
# 				w[l].push({
# 					'gtm.start': new Date().getTime(),
# 					event:       'gtm.js'
# 				});
# 				var f = d.getElementsByTagName(s)[0],
# 						j = d.createElement(s),
# 						dl = l != 'dataLayer' ? '&l=' + l : '';
# 				j.defer=true;
# 				j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
# 				f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','gdGlobals','GTM-PST2JZ');
# 		</script><script>
# try {
# !function r(s,c,a){function l(t,e){if(!c[t]){if(!s[t]){var n="function"==typeof require&&require;if(!e&&n)return n(t,!0);if(f)return f(t,!0);var o=new Error("Cannot find module '"+t+"'");throw o.code="MODULE_NOT_FOUND",o}var i=c[t]={exports:{}};s[t][0].call(i.exports,function(e){return l(s[t][1][e]||e)},i,i.exports,r,s,c,a)}return c[t].exports}for(var f="function"==typeof require&&require,e=0;e<a.length;e++)l(a[e]);return l}({1:[function(e,t,n){"use strict";t.exports=e("./lib/GDLogger")},{"./lib/GDLogger":4}],2:[function(e,t,n){"use strict";t.exports=function(e,t){var n=!1;if(!e||e<=0)n=!1;else if(100<=e)n=!0;else if(t){for(var o=0,i=0;i<t.length;i+=1)o+=t.charCodeAt(i);n=(o%=100)<e}return n}},{}],3:[function(e,t,n){"use strict";t.exports={SERVER_LOG_PREFIX:"[JS-LOG]",SERVER_URL:"/util/ajax/lgr.htm",VERSION:4,LEVELS:{ALL:{name:"a",severity:0},INFO:{name:"i",severity:10},DEBUG:{name:"d",severity:20},WARNING:{name:"w",severity:30},ERROR:{name:"e",severity:40},FATAL:{name:"f",severity:50},NONE:{name:"0",severity:100}}}},{}],4:[function(e,t,n){"use strict";var o=e("./LogClient"),i=e("./LogServer"),r=e("./Constants"),s=e("gd-util/lib/extend"),c=e("./ASCIISumThreshold");function a(e){var t={clientLogging:!0,serverLogging:!0,serverLoggingPct:1,clientLevel:r.LEVELS.ALL,serverLevel:r.LEVELS.NONE,guid:"ababababab-58b7-11e5-a837-0800200c9a66"};this.settings=s({},t,e),"string"==typeof this.settings.clientLevel&&r.LEVELS.hasOwnProperty(this.settings.clientLevel)&&(this.settings.clientLevel=r.LEVELS[this.settings.clientLevel]),"string"==typeof this.settings.serverLevel&&r.LEVELS.hasOwnProperty(this.settings.serverLevel)&&(this.settings.serverLevel=r.LEVELS[this.settings.serverLevel]),this.client=new o(this.settings.clientLogging,this.settings.clientLevel),this.server=new i(this.settings.serverLogging,this.settings.serverLevel),this.settings.serverLogging=c(this.settings.serverLoggingPct,this.settings.guid)}var l=a.prototype;function f(e){return this.isClientLogging()&&this.client.getLevel().severity<=e.severity}function g(e){return this.isServerLogging()&&this.server.getLevel().severity<=e.severity}l.version=r.VERSION,l.LEVELS=r.LEVELS,l.info=function(e,t){f.call(this,r.LEVELS.INFO)&&this.client.info(e,t),g.call(this,r.LEVELS.INFO)&&this.server.log(e,r.LEVELS.INFO)},l.debug=function(e,t){f.call(this,r.LEVELS.DEBUG)&&this.client.debug(e,t),g.call(this,r.LEVELS.DEBUG)&&this.server.log(e,r.LEVELS.DEBUG)},l.warn=function(e,t){f.call(this,r.LEVELS.WARNING)&&this.client.warn(e,t),g.call(this,r.LEVELS.WARNING)&&this.server.log(e,r.LEVELS.WARNING)},l.error=function(e,t){f.call(this,r.LEVELS.ERROR)&&this.client.error(e,t),g.call(this,r.LEVELS.ERROR)&&this.server.log(e,r.LEVELS.ERROR)},l.fatal=function(e,t){f.call(this,r.LEVELS.FATAL)&&this.client.fatal(e,t),g.call(this,r.LEVELS.FATAL)&&this.server.log(e,r.LEVELS.FATAL)},l.inspect=function(e,t){f.call(this,r.LEVELS.DEBUG)&&this.client.inspect(e,t),g.call(this,r.LEVELS.DEBUG)&&(t&&this.server.log("Inspect: "+t,r.LEVELS.DEBUG),JSON&&JSON.stringify&&this.server.log(JSON.stringify(e),r.LEVELS.DEBUG))},l.trace=function(e){this.isClientLogging()&&this.client.trace(e)},l.timer=function(e){this.isClientLogging()&&this.client.timer(e)},l.timerEnd=function(e){this.isClientLogging()&&this.client.timerEnd(e)},l.profile=function(e){this.isClientLogging()&&this.client.profile(e)},l.profileEnd=function(){this.isClientLogging()&&this.client.profileEnd()},l.windowError=function(e,t,n){this.client.windowError(e,t,n)},l.setClientLoggingLevel=function(e){this.LEVELS.hasOwnProperty(e)?this.settings.clientLevel=this.LEVELS[e]:this.settings.clientLevel=this.LEVELS.NONE,this.client.setLevel(this.settings.clientLevel)},l.setServerLoggingLevel=function(e){this.LEVELS.hasOwnProperty(e)?this.settings.serverLevel=this.LEVELS[e]:this.settings.serverLevel=this.LEVELS.NONE,this.server.setLevel(this.settings.serverLevel)},l.setClientLogging=function(e){this.settings.clientLogging=e,this.client.setEnabled(e)},l.setServerLogging=funct ...
#
# }
#  catch (e) {
# var log=window.console?window.console.log:function(o){alert(o)};
# log('Error with inline script "/gd-core-top.js": ' + e);
# }
# </script><script>
# try {
# !function i(a,s,l){function u(t,e){if(!s[t]){if(!a[t]){var r="function"==typeof require&&require;if(!e&&r)return r(t,!0);if(c)return c(t,!0);var n=new Error("Cannot find module '"+t+"'");throw n.code="MODULE_NOT_FOUND",n}var o=s[t]={exports:{}};a[t][0].call(o.exports,function(e){return u(a[t][1][e]||e)},o,o.exports,i,a,s,l)}return s[t].exports}for(var c="function"==typeof require&&require,e=0;e<l.length;e++)u(l[e]);return u}({1:[function(e,t,r){t.exports=function(e,t){(null==t||t>e.length)&&(t=e.length);for(var r=0,n=new Array(t);r<t;r++)n[r]=e[r];return n},t.exports.__esModule=!0,t.exports.default=t.exports},{}],2:[function(e,t,r){var n=e("./arrayLikeToArray.js");t.exports=function(e){if(Array.isArray(e))return n(e)},t.exports.__esModule=!0,t.exports.default=t.exports},{"./arrayLikeToArray.js":1}],3:[function(e,t,r){t.exports=function(e){if(void 0===e)throw new ReferenceError("this hasn't been initialised - super() hasn't been called");return e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],4:[function(e,t,r){function l(e,t,r,n,o,i,a){try{var s=e[i](a),l=s.value}catch(e){return void r(e)}s.done?t(l):Promise.resolve(l).then(n,o)}t.exports=function(s){return function(){var e=this,a=arguments;return new Promise(function(t,r){var n=s.apply(e,a);function o(e){l(n,t,r,o,i,"next",e)}function i(e){l(n,t,r,o,i,"throw",e)}o(void 0)})}},t.exports.__esModule=!0,t.exports.default=t.exports},{}],5:[function(e,t,r){t.exports=function(e,t){if(!(e instanceof t))throw new TypeError("Cannot call a class as a function")},t.exports.__esModule=!0,t.exports.default=t.exports},{}],6:[function(e,t,r){function n(e,t){for(var r=0;r<t.length;r++){var n=t[r];n.enumerable=n.enumerable||!1,n.configurable=!0,"value"in n&&(n.writable=!0),Object.defineProperty(e,n.key,n)}}t.exports=function(e,t,r){return t&&n(e.prototype,t),r&&n(e,r),Object.defineProperty(e,"prototype",{writable:!1}),e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],7:[function(e,t,r){t.exports=function(e,t,r){return t in e?Object.defineProperty(e,t,{value:r,enumerable:!0,configurable:!0,writable:!0}):e[t]=r,e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],8:[function(e,t,r){function n(e){return t.exports=n=Object.setPrototypeOf?Object.getPrototypeOf:function(e){return e.__proto__||Object.getPrototypeOf(e)},t.exports.__esModule=!0,t.exports.default=t.exports,n(e)}t.exports=n,t.exports.__esModule=!0,t.exports.default=t.exports},{}],9:[function(e,t,r){var n=e("./setPrototypeOf.js");t.exports=function(e,t){if("function"!=typeof t&&null!==t)throw new TypeError("Super expression must either be null or a function");e.prototype=Object.create(t&&t.prototype,{constructor:{value:e,writable:!0,configurable:!0}}),Object.defineProperty(e,"prototype",{writable:!1}),t&&n(e,t)},t.exports.__esModule=!0,t.exports.default=t.exports},{"./setPrototypeOf.js":15}],10:[function(e,t,r){t.exports=function(e){return e&&e.__esModule?e:{default:e}},t.exports.__esModule=!0,t.exports.default=t.exports},{}],11:[function(e,t,r){t.exports=function(e){if("undefined"!=typeof Symbol&&null!=e[Symbol.iterator]||null!=e["@@iterator"])return Array.from(e)},t.exports.__esModule=!0,t.exports.default=t.exports},{}],12:[function(e,t,r){t.exports=function(){throw new TypeError("Invalid attempt to spread non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")},t.exports.__esModule=!0,t.exports.default=t.exports},{}],13:[function(e,t,r){var o=e("./defineProperty.js");t.exports=function(t){for(var e=1;e<arguments.length;e++){var r=null!=arguments[e]?Object(arguments[e]):{},n=Object.keys(r);"function"==typeof Object.getOwnPropertySymbols&&n.push.apply(n,Object.getOwnPropertySymbols(r).filter(function(e){return Object.getOwnPropertyDescriptor(r,e).enumerable})),n.forEach(function(e){o(t,e,r[e])})}return t},t.exports.__esModule=!0,t.exports.default=t.exports},{"./defineProperty.js":7}],14:[function(e,t,r){var n=e("./typeof.js").default,o=e("./assertThisInitial ...
#
# }
#  catch (e) {
# var log=window.console?window.console.log:function(o){alert(o)};
# log('Error with inline script "/gd-i18n-site-en-IE.js": ' + e);
# }
# </script><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react/17.0.1/umd/react.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/17.0.1/umd/react-dom.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-transition-group/1.2.1/react-transition-group.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-core-bottom-en-IE.js?v=7023bb4tx5"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-search.js?v=f4b61d7be"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-search-salaries-en-IE.js?v=bae4368sx"></script><script>
# $(function() {
#   if(new Date().getTime() - (sessionStorage['js-session-valid'] || 0) > 45 * 60 * 1000) {
#     sessionStorage['js-session-valid'] = new Date().getTime();
#     jQuery.ajax({
#           url: 'app' === 'jobs-ux-app' ? '/Job/bwl.htm' : '/util/ajax/bwl.htm',
#           type: 'POST',
#           data: { guid: getGdGlobals().page.guid, gdToken: GD.page.gdToken },
#           success: function() { console.info('JSSV'); }
#     });
#   }
# });
# </script>
# <link href="/salaries/static/gd-salary-srch.bundle.css?v=4ba5c460a1b05fe4c6dd" media="all" rel="stylesheet"/>
# <script defer="" src="/salaries/static/js/gd-vendor.bundle.js?v=4ba5c460a1b05fe4c6dd" type="text/javascript"></script><script defer="" src="/salaries/static/js/gd-salary-srch.bundle.js?v=4ba5c460a1b05fe4c6dd" type="text/javascript"></script>
# <style data-rh="true">#PageContent { width: auto; margin: 0; background: white; }</style>
# <style data-emotion-css="aks2zl">.css-aks2zl{margin:0 auto;max-width:1280px;width:100%;}</style><style data-emotion-css="1837fe">.css-1837fe{font-size:24px;line-height:36px;font-weight:900;color:#20262e;}</style><style data-emotion-css="1b6bxoo">.css-1b6bxoo{font-size:15px;line-height:24px;color:#505863;}</style><style data-emotion-css="186p6k2">.css-186p6k2{cursor:pointer;}.css-186p6k2 svg{width:20px;height:24px;}</style><style data-emotion-css="146zilq">.css-146zilq{font-size:44px;line-height:56px;font-weight:900;color:#20262e;}@media (max-width:767px){.css-146zilq{font-size:36px;line-height:48px;}}</style><style data-emotion-css="18stkbk">.css-18stkbk{font-size:15px;line-height:24px;color:#505863;font-weight:700;}</style><style data-emotion-css="1vkj9it">.css-1vkj9it{font-size:12px;line-height:20px;color:#505863;}</style><style data-emotion-css="615r19">.css-615r19{position:relative;height:80px;gap:6px;}</style><style data-emotion-css="1nrqqd7">.css-1nrqqd7{position:absolute !important;height:100%;}</style><style data-emotion-css="146cx6h">.css-146cx6h{height:0;width:100%;-webkit-transition:height 0.5s ease-out;transition:height 0.5s ease-out;background-color:#dee0e3;border-top:1px solid #858c94;}</style><style data-emotion-css="6vyvtw">.css-6vyvtw{background-color:#0c4085;border-top:2px solid #0c4085;}</style><style data-emotion-css="93svrw">.css-93svrw{font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><style data-emotion-css="g261rn">.css-g261rn{font-size:18px;line-height:28px;font-weight:700;color:#20262e;}</style><style data-emotion-css="gui0u7">.css-gui0u7{font-size:15px;line-height:24px;color:#505863;font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><style data-emotion-css="15cs8dz">.css-15cs8dz{gap:16px;position:relative;}.css-15cs8dz:before{content:'';display:block;position:absolute;top:0;bottom:0;border-left:1px dotted #858c94;left:4px;z-index:-1;}.css-15cs8dz > div .gsm-dot-container{position:relative;overflow:hidden;min-width:9px;}.css-15cs8dz > div:first-child .gsm-dot-container:before,.css-15cs8dz > div:last-child .gsm-dot-container:after{content:'';display:block;position:absolute;background-color:white;height:100%;width:100%;z-index:-1;}.css-15cs8dz > div:first-child .gsm-dot-container:before{bottom:50%;}.css-15cs8dz > div:last-child .gsm-dot-container:after{top:50%;}</style><style data-emotion-css="1n68k6m">.css-1n68k6m{width:8px;height:14px;background-color:#dee0e3;border-radius:50%;border:1px solid #858c94;width:9px;height:9px;position:relative;}.css-1n68k6m.active{background-color:#0c4085;}.css-1n68k6m:before{content:'';display:block;background:white;position:absolute;top:-2px;bottom:-2px;left:0;right:0;z-index:-1;}</style><style data-emotion-css="1a3t88b">.css-1a3t88b{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-1a3t88b:hover{color:#0c4085;}.css-1a3t88b:not(:hover){color:#505863 !important;}</style><style data-emotion-css="1xkb4fk">.css-1xkb4fk{cursor:pointer;font-size:15px;line-height:24px;font-weight:700;color:#1861bf;}.css-1xkb4fk:hover{color:#0c4085;}</style><style data-emotion-css="123ngk9">.css-123ngk9{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-123ngk9:hover{color:#0c4085;}</style><style data-emotion-css="uukk77">.css-uukk77{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;top:0;bottom:0;left:0;right:0;position:fixed;z-index:8000;-webkit-animation-name:showModal;animation-name:showModal;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}@-webkit-keyframes showModal{from{opacity:0;}to{opacity:1;}}@keyframes showModal{from{opacity:0;}to{opacity:1;}}.css-uukk77 .background-overlay{position:fixed;left:0px;top:0px;background:#20262e;opacity:0.8;width:100%;height:100%;}@-webkit-keyfr ...
# .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;}
# .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style data-emotion="css-global"></style><style data-emotion="css"></style><link href="https://www.glassdoor.com/app/static/js/dist/gd-footer.bundle.css?v=b1e3903ov" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/garnish/static/css/gd-user-login.bundle.css?v=851238bb07224f9317a932300b7fc94c2b8b5d84" rel="stylesheet" type="text/css"/><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style data-emotion="css"></style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style data-emotion="css"></style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><script async="" src="https://cdn.cookielaw.org/scripttemplates/6.28.0/otBannerSdk.js" type="text/javascript"></script><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes slideInFromBottomDelay{0%{opacity:0;transform:translateY(100%)}97%{opacity:0;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}</style></head>
# <body class="main flex loggedIn lang-en en-IE hollywood gdGrid _initOk noTouch desktop" data-locale="en-IE" marginheight="0" marginwidth="0" style="margin:0;"><div id="FlexTestFF"><div class="testMQ mqHH"></div><div class="testMQ mqTab"></div><div class="testMQ mqDT"></div></div><div id="UserAlertBarSubstitute"></div><header class="gdGrid" data-career-enabled="true" data-is-cached-page="false" data-search-box-v1="false" data-search-hidden="false" data-signed-in="true" id="SiteNav"><nav class="d-flex align-items-center HeaderStyles__navigationBackground HeaderStyles__relativePosition" data-test="background-header-nav"><div class="col HeaderStyles__bottomShadow"><div class="HeaderStyles__navigationWrapper"><div class="d-flex justify-content-between align-items-center px-std px-md-lg HeaderStyles__mainNav"><div class="d-flex d-lg-none"><div class="d-flex"><button aria-label="Account Menu" class="p-0 HeaderStyles__iconBtn" data-test="user-profile-drawer-trigger" title="Open Account Menu" type="button"><img alt="user avatar" class="HeaderStyles__mobileAvatar" src="https://media.glassdoor.com/userprofileuser/upul/38942356/38942356-userprofileuser-1618331409256.jpg"/></button><div class="d-flex flex-column DrawerStyles__drawerContainer DrawerStyles__drawerPositionLeft DrawerStyles__drawerAnimation"><div><div class="col HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><span class=""><div class="HeaderStyles__h1">Profile</div></span></div></div><div><div class="d-flex flex-row"><button aria-label="Close navigation menu" class="p-0 ml-std HeaderStyles__iconBtn" title="Close navigation menu" type="button"><span class="SVGInline d-flex IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"></path></svg></span></button></div></div></div></div></div><div class="d-flex flex-column col DrawerStyles__drawerContent"><ul class="p-0 m-0 HeaderStyles__list HeaderStyles__menu"><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std MenuItemStyles__menuItem MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Profile" href="/member/profile/index.htm" rel="nofollow" target="_top"><img alt="user avatar" class="mr-sm MenuItemStyles__menuAvatar" src="https://media.glassdoor.com/userprofileuser/upul/38942356/38942356-userprofileuser-1618331409256.jpg"/><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="MenuItemStyles__menuItemColor">Profile</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std MenuItemStyles__menuItem MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Resumes" href="/member/profile/resumes.htm" rel="nofollow" target="_top"><span class="SVGInline d-flex IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M16 2l4 5h-3.5a.5.5 0 01-.5-.5zm-6 2.5a2 2 0 011.15 3.64 4.14 4.14 0 012.74 2.43 1 1 0 01-.47 1.33.91.91 0 01-.42.1H7a1 1 0 01-1-1 .91.91 0 01.1-.43 4.14 4.14 0 012.75-2.43A2 2 0 0110 4.5zM17.5 15a.5.5 0 010 1h-11a.5.5 0 010-1zm0 3a.5.5 0 010 1h-11a.5.5 0 010-1zM13.75 3h-8.5a.24.24 0 00-.25.19v17.56a.24.24 0 00.19.24h13.56a.24.24 0 00.24-.19V9.25a.24.24 0 00-.18-.25H14.5a.5.5 0 01-.5-.41V3.25a.25.25 0 00-.25-.25zM15 2v5.5a.5.5 0 00.5.5H20v13a1 1 0 01-1 1H5a1 1 0 01-1-1V3a1 1 0 011-1z" fill="currentColor" fill-rule="evenodd"></path></svg></span><div class="d-flex align-items-center py-st ...
# "undefined"!=typeof GD?GD.untranslatedURL=a:null}catch(b){}})();</script><script id="" type="text/javascript">(function(){var temp;try{if(google_tag_manager["GTM-PST2JZ"].macro(262)=="analyticsFired"&&google_tag_manager["GTM-PST2JZ"].macro(263)=="pageview")if(typeof GD!="undefined"&&/http/.test(google_tag_manager["GTM-PST2JZ"].macro(264))!=true){var ac=google_tag_manager["GTM-PST2JZ"].macro(265);if(/^\/employers\/ec\/.*/.test(ac)){ac=ac.replace(/app\//,"");ac=ac.replace(/[0-9]{1,}/,"");ac=ac.replace(/\?(.*)/,"");ac=ac.replace(/\.htm/,"");GD.abstractURL=ac}else{GD.abstractURL=google_tag_manager["GTM-PST2JZ"].macro(266);return google_tag_manager["GTM-PST2JZ"].macro(267)}}}catch(e){}var pp=google_tag_manager["GTM-PST2JZ"].macro(268);try{if(google_tag_manager["GTM-PST2JZ"].macro(269)||
# /^\/(blog|press|mz-survey)/i.test(google_tag_manager["GTM-PST2JZ"].macro(270))){if(/\/employers\/ec\/applicantTracking\/view-([0-9]*)\.htm/i.test(pp))pp=pp.replace(pp.match(/\/employers\/ec\/applicantTracking\/view(-[0-9]*)\.htm/i)[1],"");else if(/\/employers\/ec\/applicantTracking\/[0-9]+\/info\.htm(\?.*)?/i.test(pp))pp=pp.replace(/\/[0-9]+\//i,"/[jobApplicationId]/");else if(/^\/employers\/ec\/.*/.test(pp)){pp=pp.replace(/app\//,"");pp=pp.replace(/[0-9]{1,}/,"");pp=pp.replace(/\?(.*)/,"");pp=pp.replace(/\.htm/,"")}typeof GD!=
# "undefined"?GD.abstractURL=pp:null;return pp}}catch(e){}try{if(/^\/compare\//i.test(pp))return"/compare"}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(272))pp=pp.replace(/IL\x2e0\x2c6_IM1121_KO7\x2c26/i,"[PRM]")}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(276))pp=pp.replace(/undefined/i,"[QTN]")}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(289))if(google_tag_manager["GTM-PST2JZ"].macro(291)){var regexEmp=new RegExp(google_tag_manager["GTM-PST2JZ"].macro(293),"gi");pp=pp.replace(regexEmp,"[EMP]");regexEmp=new RegExp(decodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(295)),"gi");
# pp=pp.replace(regexEmp,"[EMP]")}else{temp=decodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(306));temp=temp.replace(/&#039;/g,"-");temp=temp.replace(/\\/g,"");temp=temp.replace(/ &amp; /g,"-and-");temp=temp.replace(/ & /g,"-and-");temp=temp.replace(/&amp;/g,"-and-");temp=temp.replace(/&/g,"-and-");temp=temp.replace(/ \+ /g,"-");temp=temp.replace(/\+/g,"");temp=temp.replace(/' /g,"-");temp=temp.replace(/, /g,"-");temp=temp.replace(/[|/*]/g,"-");temp=temp.replace(/[\u2018\u2019\u201C\u201D]/g,"-");temp=temp.replace(/'(?=[a-z,0-9])/gi,
# "-");temp=temp.replace(/( |,|\.(?=[a-z,A-Z,0-9]))/g,"-");temp=temp.replace(/[.?']/g,"");temp=temp.replace(/\-\-\-/g,"-");temp=temp.replace(/\-\-/g,"-");temp=temp.replace(/!/g,"");temp=encodeURIComponent(temp);var regexEmp=new RegExp(temp,"gi");pp=pp.replace(regexEmp,"[EMP]")}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(322))if(google_tag_manager["GTM-PST2JZ"].macro(324)){temp="lisbon";pp=pp.split(temp).join("[LOC]");temp="lisbon".toLowerCase();pp=pp.split(temp).join("[LOC]");temp=decodeURIComponent("lisbon");
# pp=pp.split(temp).join("[LOC]")}else{temp=encodeURIComponent("Lisbon, Portugal".replace(/(\.| )/gi,"-"));pp=pp.split(temp).join("[LOC]");temp=encodeURIComponent("Lisbon, Portugal".toLowerCase().replace(/(\.| )/gi,"-"));pp=pp.split(temp).join("[LOC]");temp=encodeURIComponent("Lisbon, Portugal".toLowerCase().replace(/(\.| )/gi,"-"));pp=pp.split(temp).join("[LOC]");if(google_tag_manager["GTM-PST2JZ"].macro(388).indexOf(",")>-1){temp=google_tag_manager["GTM-PST2JZ"].macro(404).substring(0,google_tag_manager["GTM-PST2JZ"].macro(420).indexOf(","));
# temp=temp.replace(" ","-");pp=pp.split(temp).join("[LOC]")}}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(431))if(google_tag_manager["GTM-PST2JZ"].macro(433)){temp="data-analyst-junior";pp=pp.split(temp).join("[OCC]");temp="data-analyst-junior".toLowerCase();pp=pp.split(temp).join("[OCC]");temp=ecodeURIComponent("data-analyst-junior");pp=pp.split(temp).join("[OCC]")}else if(google_tag_manager["GTM-PST2JZ"].macro(437)||google_tag_manager["GTM-PST2JZ"].macro(438)){temp="data analyst junior";pp=pp.split(temp).join("[OCC]");temp="data analyst junior".toLowerCase();
# pp=pp.split(temp).join("[OCC]");temp=encodeURIComponent("data analyst junior".replace(/(\.|\/| - | )/g,"-"));if(/\w\(\w/.test(temp))temp=temp.replace(/\(| - /g,"-");temp=temp.replace(/(\(|\)|,|& )/g,"");pp=pp.split(temp).join("[OCC]");temp=encodeURIComponent("data analyst junior".toLowerCase().replace(/(\.|\/| - | )/g,"-"));if(/\w\(\w/.test(temp))temp=temp.replace(/\(| - /g,"-");temp=temp.replace(/(\(|\)|,|& )/g,"");pp=pp.split(temp).join("[OCC]")}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(479)){pp=
# pp.replace(google_tag_manager["GTM-PST2JZ"].macro(480),"[BFT]");temp=encodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(481).replace(/(\.| )/gi,"-"));temp=temp.replace(/(\(|\)|,|& )/g,"");var regexBen=new RegExp(temp,"gi");pp=pp.replace(regexBen,"[BFT]")}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(482)){pp=pp.replace(google_tag_manager["GTM-PST2JZ"].macro(483),"[BID]");temp=encodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(484).replace(/(\.| )/gi,"-"));temp=temp.replace(/(\(|\)|,|& )/g,"");var regexBid=new RegExp(temp,"gi");pp=pp.replace(regexBid,"[BID]")}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(486))pp=
# pp.replace(/undefined/i,"[PLG]")}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(495))pp=pp.replace(/undefined/i,"[EID]")}catch(e){}try{if(pp.match(/-RVW([0-9]+)\./i))pp=pp.replace(/-RVW([0-9]+)(?=\.)/i,"-RVW[RID]")}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(513)){temp=encodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(524).replace(/& /g,""));temp=temp.replace(/(\.| )/g,"-");var regexInd=new RegExp(temp,"gi");pp=pp.replace(regexInd,"[IND]")}}catch(e){}try{if(google_tag_manager["GTM-PST2JZ"].macro(528)){temp=encodeURIComponent(google_tag_manager["GTM-PST2JZ"].macro(532).replace(/& /g,
# ...
# </div><script defer="" src="https://www.glassdoor.com/app/static/js/gd-fj-ads-init.js?v=f25c605t3"></script><script defer="" src="https://www.glassdoor.com/garnish/static/js/gd-job-alert-next.bundle.js?v=851238bb07224f9317a932300b7fc94c2b8b5d84"></script><script defer="" src="https://www.glassdoor.com/garnish/static/js/gd-site-header.bundle.js?v=851238bb07224f9317a932300b7fc94c2b8b5d84"></script><script defer="" src="https://www.glassdoor.com/app/static/js/dist/gd-footer.bundle.js?v=966f876swj"></script><script defer="" src="https://www.glassdoor.com/garnish/static/js/gd-user-login.bundle.js?v=851238bb07224f9317a932300b7fc94c2b8b5d84"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-content-wall-12mgtg-thankyou.js?v=3274e6jn"></script>
# <script id="" type="text/javascript">(function(){var k=setInterval(function(){window.gdGlobals?(clearInterval(k),q()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(k)},1E4);var q=function(){function l(){e=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/youtube.com\/embed/.test(a.src)})}function r(){var a=window.YT;"undefined"!==typeof a&&"undefined"!==typeof a.Player?(window.clearInterval(f),e.map(m),t(),console.log("~ Glassdoor video")):5>=n?n++:window.clearInterval(f)}
# function m(a){-1===a.src.indexOf("enablejsapi\x3d")&&(a.src+=(~a.src.indexOf("?")?"\x26":"?")+"enablejsapi\x3d1");var b=window.YT;b=new b.Player(a,{events:{onReady:u,onError:v}});b._asData={eventType:void 0,previousEventType:void 0,currentTime:void 0,previousTime:void 0,videoTitle:"not set",videoPlayer:"YT",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,nonInteraction:null,hitValue:0,isPlaylist:!1,nextVidClick:!1,
# adPlaying:!1,videoLoaded:!1};a=b;var c=w,d;for(d in c)a[d]=c[d];b.setListeners();g.push(b)}function u(a){a.target._asData.isPlaylist=!(0>a.target.getPlaylistIndex());a.target._vidLoaded()}function v(a){console.log("~ YT Player Error: "+a._asData)}function t(){document.addEventListener("webkitfullscreenchange",function(a){h()},!1);document.addEventListener("mozfullscreenchange",function(a){h()},!1);document.addEventListener("fullscreenchange",function(a){h()},!1)}function h(){if(document.fullscreenElement){var a=
# g.filter(function(b){return b._asData.videoSrc===document.fullscreenElement.src});a[0]._vidFullScreen()}}function x(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());if(d>b+c)for(b=d,l(),c=0;c<e.length;c++)-1===e[c].src.indexOf("enablejsapi\x3d")&&m(e[c])},3E3)}var y=
# function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"youtube",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),w={setMilestones:function(){var a=this.getVideoLength();this._asData.milestones=
# this._asData.milestones.map(function(b){return b/100*a})},setVideoTitle:function(){this._asData.videoTitle=this.getVideoTitle()},getVideoTitle:function(){var a=this._asData.videoTitle;this.playerInfo&&this.playerInfo.videoData&&this.playerInfo.videoData.title?a=this.playerInfo.videoData.title:this.getVideoData&&this.getVideoData().title&&(a=this.getVideoData().title);a!==this._asData.videoTitle&&this._asData.videoLoaded&&(this._asData.videoLoaded=!1);return a},getVideoLength:function(){return this.getDuration?
# Math.round(this.getDuration()):this.playerInfo&&this.playerInfo.duration?Math.round(this.playerInfo.duration):null},setVideoLength:function(){this._asData.videoLength=this.getVideoLength()},_getCurrentTime:function(){return this.getCurrentTime?Math.round(this.getCurrentTime()):this.playerInfo&&this.playerInfo.currentTime?Math.round(this.playerInfo.currentTime):null},isVideo:function(){return this&&"VIDEO"===this.nodeName},_vidLoaded:function(){this._asData.videoLoaded||(this.setVideoTitle(),this.setVideoLength(),
# this.setMilestones(),this._asData.videoLoaded=!0)},_vidPlay:function(a){var b=void 0===a?this:a.target;b._asData.adPlaying||b._vidLoaded();if(b._asData.adPlaying)b._asData.adPlaying=!1;else if(void 0===a&&this._asData&&"player loaded"===this._asData.eventType&&(this._asData.adPlaying=!0),"autoplay"!==b._asData.eventType&&"click to play"!==b._asData.eventType||0!==b._asData.currentTime){b.milestoneCheck&&window.clearInterval(b.milestoneCheck);b.milestoneCheck=window.setInterval(b._vidMilestones,1E3,
# a);if(b._asData.justFinished&&(b._asData.justFinished=!1,!b._asData.isPlaylist))return;a=b._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===a.length?(b._asData.firstPlay=!1,b._asData.autoplay?b._sendHit(a[1],!0):b._sendHit(a[0],!1)):b._asData.justSeeked||b._sendHit(a,!1);5<Math.abs(b._asData.currentTime-b._asData.previousTime)&&!b._asData.justFinished&&b._sendHit("seek",!1);b._asData.justSeeked=!1}},_vidPause:function(a){var b=a.target;"cued"!==b._asData.eventType&&(window.clearInterval(b.milestoneCheck),
# 5<Math.abs(b._asData.currentTime-b._asData.previousTime)?b._vidSeek(a):b._getCurrentTime()!==b._asData.videoLength&&b._sendHit("pause",!1))},_vidSeek:function(a){a=a.target;"cued"!==a._asData.eventType&&(a._asData.adPlaying||a._asData.justFinished||0===a._asData.currentTime&&(0===a._asData.milestones.length||3===a._asData.milestones.length)||a._asData.justSeeked||a._asData.firstPlay||a._asData.justFinished||a._sendHit("seek",!1),a._asData.justSeeked=!0)},_vidComplete:function(a){a=a.target;if(0<a._asData.milestones.length)for(var b=
# 0;b<a._asData.milestones.length;b++){var c=a._asData.milestones[b];c=c/a._asData.videoLength*100;!Number.isNaN(c)&&0===c%25&&0<c&&100>=c&&(a._asData.hitValue=c,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+c+"%")),!0))}a._asData.justFinished||(a._asData.adPlaying=!1,window.clearInterval(a.milestoneCheck),a._asData.hitValue=100,a._sendHit("complete",!0),a._asData.firstPlay=!0,a._asData.justFinished=!0,a._asData.milestones=[25,50,75],a._asData.isPlaylist?a._asData.finalPlaylistVid||
# (b=a.getPlaylistIndex(),c=a.getPlaylist().length,b+1===c&&(a._asData.finalPlaylistVid=!0),a._asData.autoplay=!0,a._asData.videoLoaded=!1,a._vidLoaded()):(a._asData.autoplay=!1,a.setVideoLength(),a.setMilestones()))},_vidMilestones:function(a){if(void 0!==a){a=a.target;var b=a._getCurrentTime();a._asData.previousTime=b;if(!(b<a._asData.milestones[0])){0===a._asData.milestones.length&&window.clearInterval(a.milestoneCheck);do{var c=a._asData.milestones.splice(0,1)[0];a._asData.firstPlay&&(a._sendHit("autoplay",
# !0),a._asData.firstPlay=!1)}while(c>b);b=c/a._asData.videoLength*100;!Number.isNaN(b)&&0===b%25&&0<b&&100>=b&&(a._asData.hitValue=b,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}}},_vidMuted:function(){if(this.isMuted)if(this.isMuted())this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=!1;else return;else if(this.playerInfo)if(this.playerInfo.muted)this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=
# !1;else return;this._asData.currentTime=this._getCurrentTime();void 0===this._asData.currentTime||1>this._asData.currentTime||(this._asData.justMuted?this._sendHit("mute",!1):this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.previousEventType=this._asData.eventType;this._asData.eventType=a;this._asData.hitValue=
# a.match(/milestone|complete/i)?this._asData.hitValue:null;this._asData.nonInteraction=b;y(this._asData)},setListeners:function(){this.addEventListener("onStateChange",function(a){if(-1===a.data){if("cued"===a.target._asData.eventType)return;if("player loaded"===a.target._asData.eventType){a.target._vidPlay(a);return}if(a.target._asData.videoTitle!==a.target.getVideoTitle()){a.target._asData.milestones=[25,50,75];a.target._asData.autoplay=!1;a.target._asData.firstPlay=!0;a.target._asData.videoLoaded=
# !1;a.target._asData.adPlaying=!1;a.target._vidLoaded();return}}if(5===a.data)a.target._asData.milestones=[25,50,75],a.target._asData.autoplay=!1,a.target._asData.firstPlay=!0,a.target._asData.videoLoaded=!1,a.target._asData.adPlaying=!1,a.target._asData.eventType="cued",a.target._asData.videoTitle="not set";else{a.target._asData.currentTime=a.target._getCurrentTime();var b=[a.target._vidComplete,a.target._vidPlay,a.target._vidPause,a.target._vidSeek];(b=b[a.data]||void 0)&&b(a);a.target._asData.previousTime=
# a.target._asData.currentTime}},!0);this.addEventListener("onVolumeChange",function(a){a=a.target;a._vidMuted()},!0)}},g=[];window._asVideos=g;var f,n=0,e,p=setInterval(function(){l();if(0<e.length){clearInterval(p);var a=window.YT;if(0<e.length){a="undefined"!==typeof a&&"undefined"!==typeof a.Player;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="//www.youtube.com/iframe_api";b.parentNode.insertBefore(a,b)}f=window.setInterval(r,
# 1E3)}}},500);setTimeout(function(){clearInterval(p)},1E4);setTimeout(function(){x()},5E3)}})();</script>
# <script id="" type="text/javascript">(function(){var l=setInterval(function(){window.gdGlobals?(clearInterval(l),r()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(l)},1E4);var r=function(){function m(){g=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/player.vimeo.com/.test(a.src)})}function t(){var a=window.Vimeo;"undefined"!==typeof a?(window.clearInterval(h),g.map(n)):5>p?p++:window.clearInterval(h)}function n(a){var b=window.Vimeo;b=new b.Player(a);b._asData=
# {eventType:void 0,videoTitle:"not set",videoPlayer:"Vimeo_iframe",videoLength:"not set",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,vidLoaded:!1,nonInteraction:null,hitValue:0};var c=b,d=u,f;for(f in d)c[f]=d[f];b.setListeners();v.push(b);b._vidLoaded();a._asProcessed=!0}function w(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),
# Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());d>b+c&&(b=d,m(),g.map(function(f){f._asProcessed||n(f)}))},3E3)}var x=function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"vimeo",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,
# videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),u={setMilestones:function(){var a=this,b=window.setInterval(function(){var c=a._asData.videoLength;"not set"!==c&&(a._asData.milestones=a._asData.milestones.map(function(d){return d/100*c}),window.clearInterval(b))},200,a)},setVideoTitle:function(){var a=this;this.getVideoTitle().then(function(b){a._asData.videoTitle=b})},replayOrNewVid:function(){var a=this;this._asData.milestones=
# [25,50,75];this.getVideoTitle().then(function(b){a._asData.videoTitle===b?(a._asData.justFinished=!1,a.setMilestones()):a._vidLoaded();a._vidPlay()})},setVideoLength:function(){var a=this;this.getDuration().then(function(b){a._asData.videoLength=Math.round(b)})},_asGetCurrentTime:function(){var a=this;this.getCurrentTime().then(function(b){a._asData.currentTime=b})},_vidLoaded:function(){var a=this;this.setVideoTitle();this.setVideoLength();this.setMilestones();this.getVolume().then(function(c){0===
# c&&(a._asData.justMuted=!0)});var b=setInterval(function(){"not set"!==a._asData.videoTitle&&clearInterval(b)},75);this._asData.justFinished=!1;this._asData.vidLoaded=!0},_vidPlay:function(){if(!e){var a=this;window.setTimeout(function(){if(!e)if(a._asData.justFinished&&a._asData.firstPlay)a.replayOrNewVid();else{var b=a._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===b.length?(a._asData.firstPlay=!1,a._asData.autoplay?a._sendHit(b[1],!0):a._sendHit(b[0],!1)):a._sendHit(b,!1)}},
# 1E3,a)}},_vidPause:function(){var a=this;a._asData.justFinished||e||window.setTimeout(function(){a._asData.justFinished||e||a.getCurrentTime()!==a._asData.videoLength&&a._sendHit("pause",!1)},1E3,a)},_vidSeek:function(){e||this._asData.justFinished||(e=!0,this._sendHit("seek",!1),window.setTimeout(function(){e=!1},2E3))},_vidComplete:function(){if(0<this._asData.milestones.length)for(var a=0;a<this._asData.milestones.length;a++){var b=this._asData.milestones[a];b=b/this._asData.videoLength*100;!Number.isNaN(b)&&
# 0===b%25&&0<b&&100>=b&&(this._asData.hitValue=b,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}this._asData.hitValue=100;this._sendHit("complete",!0);this._asData.firstPlay=!0;this._asData.justFinished=!0;this._asData.autoplay=!1},_vidMilestones:function(a){this._asData.currentTime=a.seconds;if(!(k||(k=!0,window.setTimeout(function(){k=!1},2E3),this._asData.firstPlay&&3<a.seconds&&this._vidPlay(),a.seconds<this._asData.milestones[0]||0===this._asData.milestones.length))){a=
# a.seconds;do var b=this._asData.milestones.splice(0,1)[0];while(b>a);a=b/this._asData.videoLength*100;!Number.isNaN(a)&&0===a%25&&0<a&&100>=a&&(this._asData.hitValue=a,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+a+"%")),!0))}},_vidMuted:function(a){!1===this._asData.justMuted&&0===a.volume?(this._asData.justMuted=!0,this._sendHit("mute",!1)):this._asData.justMuted&&0<a.volume&&(this._asData.justMuted=!1,this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||
# document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.eventType=a;this._asData.nonInteraction=b;this._asData.hitValue=a.match(/milestone|complete/i)?this._asData.hitValue:null;x(this._asData)},setListeners:function(){this.on("play",function(){this._vidPlay()},!0);this.on("pause",function(){this._vidPause()},!0);this.on("seeked",function(){this._vidSeek()},!0);this.on("ended",function(){this._vidComplete()},
# !0);this.on("timeupdate",function(a){this._vidMilestones(a)},!0);this.on("volumechange",function(a){this._vidMuted(a)},!0);this.on("fullscreenchange",function(){this._vidFullScreen()},!0);this.on("webkitfullscreenchange",function(){this._vidFullScreen()},!0);this.on("mozfullscreenchange",function(){this._vidFullScreen()},!0);this.on("msfullscreenchange",function(){this._vidFullScreen()},!0)}},v=[],h,p=0,g,e=!1,k=!1,q=setInterval(function(){m();if(0<g.length){clearInterval(q);var a=window.Vimeo;if(0<
# g.length){a="undefined"!==typeof a;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="https://player.vimeo.com/api/player.js";b.parentNode.insertBefore(a,b)}h=window.setInterval(t,1E3)}}},500);setTimeout(function(){clearInterval(q)},1E4);setTimeout(function(){w()},5E3)}})();</script></body></html>

# %%
position_summary_detail_df
# Out:
#      city                                           position  \
# 0  Lisbon  Junior Data Analyst Salaries in Berlin, German...
#
#            updatedate avgbasepay minpay avgpay maxpay  \
# 0  Updated 1 May 2022    €44,470   €37K   €44K   €50K
#
#                                         positioninfo
# 0  The average salary for Junior Data Analyst is ...

# %%
maindf
# Out:
#         city                                           position  \
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam        Junior Data Analyst Salaries in Dublin Area
# 0     Madrid        Junior Data Analyst Salaries in Dublin Area
# 0      Paris  Junior Data Analyst Salaries in Madrid, Spain ...
# 0     Berlin  Junior Data Analyst Salaries in Paris, France ...
# 0      Milan  Junior Data Analyst Salaries in Paris, France ...
# 0     London  Junior Data Analyst Salaries in Milan, Italy Area
#
#            updatedate avgbasepay minpay avgpay  \
# 0  Updated 2 May 2022    €33,139   €29K   €33K
# 0  Updated 2 May 2022    €33,139   €29K   €33K
# 0  Updated 2 May 2022    €33,139   €29K   €33K
# 0  Updated 2 May 2022    €26,404   €20K   €26K
# 0  Updated 2 May 2022    €39,835   €29K   €40K
# 0  Updated 2 May 2022    €39,835   €29K   €40K
# 0  Updated 2 May 2022    €26,537   €23K   €27K
#
#                                               maxpay  \
# 0                                               €40K
# 0                                               €40K
# 0                                               €40K
# 0                                               €32K
# 0                                               €48K
# 0                                               €48K
# 0  No additional cash compensation has been repor...
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...

# %%
glassdoor_role_table = maindf.reset_index()
glassdoor_role_table
# Out:
#    index       city                                           position  \
# 0      0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 1      0  Amsterdam        Junior Data Analyst Salaries in Dublin Area
# 2      0     Madrid        Junior Data Analyst Salaries in Dublin Area
# 3      0      Paris  Junior Data Analyst Salaries in Madrid, Spain ...
# 4      0     Berlin  Junior Data Analyst Salaries in Paris, France ...
# 5      0      Milan  Junior Data Analyst Salaries in Paris, France ...
# 6      0     London  Junior Data Analyst Salaries in Milan, Italy Area
#
#            updatedate avgbasepay minpay avgpay  \
# 0  Updated 2 May 2022    €33,139   €29K   €33K
# 1  Updated 2 May 2022    €33,139   €29K   €33K
# 2  Updated 2 May 2022    €33,139   €29K   €33K
# 3  Updated 2 May 2022    €26,404   €20K   €26K
# 4  Updated 2 May 2022    €39,835   €29K   €40K
# 5  Updated 2 May 2022    €39,835   €29K   €40K
# 6  Updated 2 May 2022    €26,537   €23K   €27K
#
#                                               maxpay  \
# 0                                               €40K
# 1                                               €40K
# 2                                               €40K
# 3                                               €32K
# 4                                               €48K
# 5                                               €48K
# 6  No additional cash compensation has been repor...
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 1  How much does a Junior Data Analyst make in Du...
# 2  How much does a Junior Data Analyst make in Du...
# 3  The average salary for Junior Data Analyst is ...
# 4  The average salary for Junior Data Analyst is ...
# 5  The average salary for Junior Data Analyst is ...
# 6  How much does a Junior Data Analyst make in Mi...

# %%
glassdoor_role_table.to_csv('glassdoor_role_table.csv')

# %%
glassdoor_role_table.to_csv('glassdoor_role_table_noindex.csv',index=False)

# %%
soup
# Out:
# <html class="canvas svgfilters cssfilters no-touchevents" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head>
# <title>Salary: Junior Data Analyst in Milan, Italy | Glassdoor</title>
# <meta content="8gasaHBZws6-VlwUeolXJRSp0aUrfYzMYjiPfCwfn7" name="globalsign-domain-verification"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="yes" name="apple-mobilegi-web-app-capable"/><meta content="origin" name="referrer"/><meta content="589698942" property="al:ios:app_store_id"/><meta content="Glassdoor" property="al:ios:app_name"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="website" property="og:type"/><meta content="Glassdoor" property="og:site_name"/><meta content="129253937150340" property="fb:app_id"/><meta content="https://www.glassdoor.ie/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" property="og:url"/><meta content="https://www.glassdoor.com/app/static/img/partners/fb/logo-1200x630.png?v=721f9cswl" property="og:image"/><meta content="app-id=589698942" name="apple-itunes-app"/><meta content="app-id=com.glassdoor.app" name="google-play-app"/>
# <meta content="Salary: Junior Data Analyst in Milan, Italy" data-rh="true" property="og:title"/><meta content="1,079 Junior Data Analyst Salaries in Milan, Italy provided anonymously by employees. What salary does a Junior Data Analyst earn in Milan?" data-rh="true" name="description"/><meta content="1,079 Junior Data Analyst Salaries in Milan, Italy provided anonymously by employees. What salary does a Junior Data Analyst earn in Milan?" data-rh="true" property="og:description"/>
# <link data-rh="true" href="https://www.glassdoor.ie/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm?clickSource=searchBtn" rel="canonical"/><link data-rh="true" href="https://www.glassdoor.ie/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25_IP2.htm?clickSource=searchBtn" rel="next"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link href="https://www.glassdoor.com/app/static/css/gd-salary-search-core.css?v=12da73993m" media="all" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/app/static/js/dist/gd-site-header.bundle.css?v=f2b9beoqb" media="all" rel="stylesheet" type="text/css"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-57.png?v=595028252" rel="apple-touch-icon-precomposed"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-72.png?v=e859f12fg" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-114.png?v=81fd863hl" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-144.png?v=0efaf240j" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="/manifest.json" rel="manifest"/><link href="https://www.glassdoor.ie/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" rel="canonical"/><link href="https://www.glassdoor.ie/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-IE" rel="alternate"/><link href="https://www.glassdoor.com.au/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-AU" rel="alternate"/><link href="https://www.glassdoor.ca/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-CA" rel="alternate"/><link href="https://www.glassdoor.com.hk/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-HK" rel="alternate"/><link href="https://www.glassdoor.co.in/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-IN" rel="alternate"/><link href="https://www.glassdoor.co.nz/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-NZ" rel="alternate"/><link href="https://www.glassdoor.sg/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-SG" rel="alternate"/><link href="https://www.glassdoor.co.uk/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en-GB" rel="alternate"/><link href="https://www.glassdoor.com/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm" hreflang="en" rel="alternate"/>
# <script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=31ed244fd18018a2cb2dda3f7be50d7b"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-RJF0GNZNXE&amp;l=gdGlobals&amp;cx=c" type="text/javascript"></script><script async="" src="https://unpkg.com/web-vitals/dist/web-vitals.iife.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-RC95PMVB3H&amp;l=gdGlobals&amp;cx=c" type="text/javascript"></script><script defer="" src="//www.googletagmanager.com/gtm.js?id=GTM-PST2JZ&amp;l=gdGlobals"></script><script>
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/search/salaries?cat=Salaries&o=data+analyst+junior&l=Milan+%28M%3A+1058%29",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-IE',
# 			'env': 'prod',
# 			'release': '20220426-2',
# 			'appName': 'app',
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.ie",
# 								'domainId':		18,
# 								'domainCountryId': 70,
#
#
# 								'domainSuffix': "ie",
#
#
# 								'group':        "Search-Salaries",
#
#
# 								'projectUrlGroup':        "[]",
#
#
# 								'guid':         '000001808b609c2cb779b18d0899f27b',
#
#
# 								'flex':         true,
#
#
# 								'section':      "search",
#
#
# 								'type':         "search:search-salaries",
#
#
# 								'id':           "search:search-salaries",
#
# 								'med': '',
#
# 								'src' : '',
# 								'content' : '',
# 								'campaign' : '',
# 								'term' : '',
# 								'state' : 'open',
# 								'untranslatedUrl' : 'https://www.glassdoor.com/Salaries/milan-data-analyst-junior-salary-SRCH_IL.0,5_IM1058_KO6,25.htm'
#
#                                     , 'modulesDisplayed': {
#                                         'occMedianNationalShown': 'N',
#                                         'occMedianMetroShown': 'N',
#                                         'employerSalariesShown': 'N',
#                                         'recentSalariesShown': 'N',
#                                         'relatedSalariesShown': 'N',
#                                         'kywPromoShown': 'Y'
#                                     }
#
# 							},
#
# 			'user':         {
#
# 								'guid':         '549223b6-08ca-4efa-9b90-aa105fd038f9',
#
# 									'id': "177444508",
#
# 									'membershipType': "BASIC",
# 									'isLapsedMember': "FALSE",
# 									'age' : "",
# 									'gender' : "",
# 									'education' : "",
# 									'regDate' : '20201214',
# 									'regMonth' : 'diciembre',
# 									'profile' : 'true',
#
# 								'ipAddr':       "84.203.86.255",
#
#
# 								'locale':       "en_IE",
#
#
# 								'country':      "IE",
# 								'ipLocationId': "2739035",
# 								'ipLocationType': "C",
#
# 								'elligibleForAppBoy': true,
# 							},
#
# 			'vendor':       {
# 								'fbReqPerms':   ""
# 							},
#
# 				'implicitLoc':'Milan, Italy Area (Italy)',
#
# 			'search':       {
#
# 				"rawKeyword":"data analyst junior"
#
# 								, 'location': "Milan, Italy",
# 								'locationType': "M",
# 								'locationId': "1058"
#
# 								, 'occupation' : "data analyst junior"
#
# 								, 'totalSearchResults': "0",
# 								'displayedSearchResults': "-1",
# 								'pageNumber': "1",
# 								'noData' : 'true'
#
# 								, 'searchQueryGuid' : ""
#
# 							, 'segmentType' : "OL"
#
# 			},
# 			'employer' : {
#
# 			},
# 			'job' : {
#
# 			},
# 			'test' : {
#
# 				'planoutIdList': [
#
# 						, "site_discovery_ugc_search2.PROD_ugc_search2_v1"
#
# 						, "site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1"
#
# 						, "lightweight_data_collection.exp_user_profile_catchall"
#
# 						, "growth_global.exp_growth_global_catchAll"
#
# 						, "brand_ads_company_explorer.native_ads_explore"
#
# 						, "user_profile.exp_user_profile_catchall"
#
# 						, "total_comp_salaries_ui_refresh_dec2021.PROD_total_comp_salaries_ui_refresh_20211202"
#
# 						, "content_single_page_survey.CXP_1419_PROD_test"
#
# 						, "brand_ads_company_compare.native_ads_compare"
#
# 						, "site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1"
#
# 						, "content_reviews_node.I18N_redirect_reviews_node_test_20190530"
#
# 						, "content_survey_global_context.CON_238_PROD_test_051221"
#
# 						, "site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1"
#
# 						, "nuf_steps.last_step_test"
#
# 						, "ei_compare_rollout.TRFC_4368_ei_compare"
#
# 						, "company_explorer.TRFC_4524_02102020"
#
# 						, "growth_user_activation.user_activation_post_auth_redirect_exp_20220201"
#
# 						, "site_discovery_nav.site_discovery_nav_t2"
#
# 						, "nuf_v2_1.ipad_promotion_test"
#
# 						, "growth_jobs.growth_jobs_default_catchAll"
#
# 						, "nuf_gd_logo.disabled_logo_test"
#
# 						, "site_discovery_header.exp_site_discovery_header_catchall"
#
# 						, "total_comp_salary_occupation_new_ui.total_comp_salary_occupation_new_ui_test_04142021"
#
# 						, "site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall"
#
# 				],
# 				'planoutTreatmentList': [
#
# 						, "ugc_search2_t1"
#
# 						, "ugc_search2_salaries_t1"
#
# 						, "lightweight_data_collection_default"
#
# 						, "growth_global_default"
#
# 						, "native_ads_explore_t1"
#
# 						, "user_profile_default_treatment"
#
# 						, "salaries_ui_t1"
#
# 						, "single_page_t1"
#
# 						, "native_ads_compare_t1"
#
# 						, "ugc_search2_autocomplete_t1"
#
# 						, "redirect2Node_t1"
#
# 						, "new_suggested_companies_t1"
#
# 						, "ugc_search2_interviews_t1"
#
# 						, "last_step_test_control"
#
# 						, "ei_compare_activated"
#
# 						, "test_on"
#
# 						, "post_auth_redirect_t1"
#
# 						, "career_nav_t2"
#
# 						, "nuf_v2_1_control"
#
# 						, "growth_jobs_default"
#
# 						, "disabled_logo_test_t1"
#
# 						, "site_discovery_header_default"
#
# 						, "salary_occupation_new_ui_t1"
#
# 						, "fishbowl_default"
#
# 				]
# 			},
# 			'staticList' : {
#
# 			}
#
# 		}];
#
# 	if(window.projectUrlGroup && Array.isArray(window.projectUrlGroup)) {
# 		var globalsProjectUrlGroup = JSON.parse(gdGlobals[0].page.projectUrlGroup);
# 		var combined = globalsProjectUrlGroup.concat(window.projectUrlGroup);
# 		gdGlobals[0].page.projectUrlGroup = JSON.stringify(combined);
# 	}
#
#
# 	window.getGdGlobals = window.getGdGlobals ||
# 			function() {
# 				return gdGlobals[0];
# 			};
#
# 	GD = window.GD || {};
# 	GD.pageInfo = GD.pageInfo || {};
# 	GD.pageInfo.pageGroup = getGdGlobals().page.group;
# 	GD.domain = getGdGlobals().page.domain;
#
# 	</script><script>
#
# 			(function(w,d,s,l,i) {
# 				w[l] = w[l] || [];
# 				w[l].push({
# 					'gtm.start': new Date().getTime(),
# 					event:       'gtm.js'
# 				});
# 				var f = d.getElementsByTagName(s)[0],
# 						j = d.createElement(s),
# 						dl = l != 'dataLayer' ? '&l=' + l : '';
# 				j.defer=true;
# 				j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
# 				f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','gdGlobals','GTM-PST2JZ');
# 		</script><script>
# try {
# !function r(s,c,a){function l(t,e){if(!c[t]){if(!s[t]){var n="function"==typeof require&&require;if(!e&&n)return n(t,!0);if(f)return f(t,!0);var o=new Error("Cannot find module '"+t+"'");throw o.code="MODULE_NOT_FOUND",o}var i=c[t]={exports:{}};s[t][0].call(i.exports,function(e){return l(s[t][1][e]||e)},i,i.exports,r,s,c,a)}return c[t].exports}for(var f="function"==typeof require&&require,e=0;e<a.length;e++)l(a[e]);return l}({1:[function(e,t,n){"use strict";t.exports=e("./lib/GDLogger")},{"./lib/GDLogger":4}],2:[function(e,t,n){"use strict";t.exports=function(e,t){var n=!1;if(!e||e<=0)n=!1;else if(100<=e)n=!0;else if(t){for(var o=0,i=0;i<t.length;i+=1)o+=t.charCodeAt(i);n=(o%=100)<e}return n}},{}],3:[function(e,t,n){"use strict";t.exports={SERVER_LOG_PREFIX:"[JS-LOG]",SERVER_URL:"/util/ajax/lgr.htm",VERSION:4,LEVELS:{ALL:{name:"a",severity:0},INFO:{name:"i",severity:10},DEBUG:{name:"d",severity:20},WARNING:{name:"w",severity:30},ERROR:{name:"e",severity:40},FATAL:{name:"f",severity:50},NONE:{name:"0",severity:100}}}},{}],4:[function(e,t,n){"use strict";var o=e("./LogClient"),i=e("./LogServer"),r=e("./Constants"),s=e("gd-util/lib/extend"),c=e("./ASCIISumThreshold");function a(e){var t={clientLogging:!0,serverLogging:!0,serverLoggingPct:1,clientLevel:r.LEVELS.ALL,serverLevel:r.LEVELS.NONE,guid:"ababababab-58b7-11e5-a837-0800200c9a66"};this.settings=s({},t,e),"string"==typeof this.settings.clientLevel&&r.LEVELS.hasOwnProperty(this.settings.clientLevel)&&(this.settings.clientLevel=r.LEVELS[this.settings.clientLevel]),"string"==typeof this.settings.serverLevel&&r.LEVELS.hasOwnProperty(this.settings.serverLevel)&&(this.settings.serverLevel=r.LEVELS[this.settings.serverLevel]),this.client=new o(this.settings.clientLogging,this.settings.clientLevel),this.server=new i(this.settings.serverLogging,this.settings.serverLevel),this.settings.serverLogging=c(this.settings.serverLoggingPct,this.settings.guid)}var l=a.prototype;function f(e){return this.isClientLogging()&&this.client.getLevel().severity<=e.severity}function g(e){return this.isServerLogging()&&this.server.getLevel().severity<=e.severity}l.version=r.VERSION,l.LEVELS=r.LEVELS,l.info=function(e,t){f.call(this,r.LEVELS.INFO)&&this.client.info(e,t),g.call(this,r.LEVELS.INFO)&&this.server.log(e,r.LEVELS.INFO)},l.debug=function(e,t){f.call(this,r.LEVELS.DEBUG)&&this.client.debug(e,t),g.call(this,r.LEVELS.DEBUG)&&this.server.log(e,r.LEVELS.DEBUG)},l.warn=function(e,t){f.call(this,r.LEVELS.WARNING)&&this.client.warn(e,t),g.call(this,r.LEVELS.WARNING)&&this.server.log(e,r.LEVELS.WARNING)},l.error=function(e,t){f.call(this,r.LEVELS.ERROR)&&this.client.error(e,t),g.call(this,r.LEVELS.ERROR)&&this.server.log(e,r.LEVELS.ERROR)},l.fatal=function(e,t){f.call(this,r.LEVELS.FATAL)&&this.client.fatal(e,t),g.call(this,r.LEVELS.FATAL)&&this.server.log(e,r.LEVELS.FATAL)},l.inspect=function(e,t){f.call(this,r.LEVELS.DEBUG)&&this.client.inspect(e,t),g.call(this,r.LEVELS.DEBUG)&&(t&&this.server.log("Inspect: "+t,r.LEVELS.DEBUG),JSON&&JSON.stringify&&this.server.log(JSON.stringify(e),r.LEVELS.DEBUG))},l.trace=function(e){this.isClientLogging()&&this.client.trace(e)},l.timer=function(e){this.isClientLogging()&&this.client.timer(e)},l.timerEnd=function(e){this.isClientLogging()&&this.client.timerEnd(e)},l.profile=function(e){this.isClientLogging()&&this.client.profile(e)},l.profileEnd=function(){this.isClientLogging()&&this.client.profileEnd()},l.windowError=function(e,t,n){this.client.windowError(e,t,n)},l.setClientLoggingLevel=function(e){this.LEVELS.hasOwnProperty(e)?this.settings.clientLevel=this.LEVELS[e]:this.settings.clientLevel=this.LEVELS.NONE,this.client.setLevel(this.settings.clientLevel)},l.setServerLoggingLevel=function(e){this.LEVELS.hasOwnProperty(e)?this.settings.serverLevel=this.LEVELS[e]:this.settings.serverLevel=this.LEVELS.NONE,this.server.setLevel(this.settings.serverLevel)},l.setClientLogging=function(e){this.settings.clientLogging=e,this.client.setEnabled(e)},l.setServerLogging=funct ...
#
# }
#  catch (e) {
# var log=window.console?window.console.log:function(o){alert(o)};
# log('Error with inline script "/gd-core-top.js": ' + e);
# }
# </script><script>
# try {
# !function i(a,s,l){function u(t,e){if(!s[t]){if(!a[t]){var r="function"==typeof require&&require;if(!e&&r)return r(t,!0);if(c)return c(t,!0);var n=new Error("Cannot find module '"+t+"'");throw n.code="MODULE_NOT_FOUND",n}var o=s[t]={exports:{}};a[t][0].call(o.exports,function(e){return u(a[t][1][e]||e)},o,o.exports,i,a,s,l)}return s[t].exports}for(var c="function"==typeof require&&require,e=0;e<l.length;e++)u(l[e]);return u}({1:[function(e,t,r){t.exports=function(e,t){(null==t||t>e.length)&&(t=e.length);for(var r=0,n=new Array(t);r<t;r++)n[r]=e[r];return n},t.exports.__esModule=!0,t.exports.default=t.exports},{}],2:[function(e,t,r){var n=e("./arrayLikeToArray.js");t.exports=function(e){if(Array.isArray(e))return n(e)},t.exports.__esModule=!0,t.exports.default=t.exports},{"./arrayLikeToArray.js":1}],3:[function(e,t,r){t.exports=function(e){if(void 0===e)throw new ReferenceError("this hasn't been initialised - super() hasn't been called");return e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],4:[function(e,t,r){function l(e,t,r,n,o,i,a){try{var s=e[i](a),l=s.value}catch(e){return void r(e)}s.done?t(l):Promise.resolve(l).then(n,o)}t.exports=function(s){return function(){var e=this,a=arguments;return new Promise(function(t,r){var n=s.apply(e,a);function o(e){l(n,t,r,o,i,"next",e)}function i(e){l(n,t,r,o,i,"throw",e)}o(void 0)})}},t.exports.__esModule=!0,t.exports.default=t.exports},{}],5:[function(e,t,r){t.exports=function(e,t){if(!(e instanceof t))throw new TypeError("Cannot call a class as a function")},t.exports.__esModule=!0,t.exports.default=t.exports},{}],6:[function(e,t,r){function n(e,t){for(var r=0;r<t.length;r++){var n=t[r];n.enumerable=n.enumerable||!1,n.configurable=!0,"value"in n&&(n.writable=!0),Object.defineProperty(e,n.key,n)}}t.exports=function(e,t,r){return t&&n(e.prototype,t),r&&n(e,r),Object.defineProperty(e,"prototype",{writable:!1}),e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],7:[function(e,t,r){t.exports=function(e,t,r){return t in e?Object.defineProperty(e,t,{value:r,enumerable:!0,configurable:!0,writable:!0}):e[t]=r,e},t.exports.__esModule=!0,t.exports.default=t.exports},{}],8:[function(e,t,r){function n(e){return t.exports=n=Object.setPrototypeOf?Object.getPrototypeOf:function(e){return e.__proto__||Object.getPrototypeOf(e)},t.exports.__esModule=!0,t.exports.default=t.exports,n(e)}t.exports=n,t.exports.__esModule=!0,t.exports.default=t.exports},{}],9:[function(e,t,r){var n=e("./setPrototypeOf.js");t.exports=function(e,t){if("function"!=typeof t&&null!==t)throw new TypeError("Super expression must either be null or a function");e.prototype=Object.create(t&&t.prototype,{constructor:{value:e,writable:!0,configurable:!0}}),Object.defineProperty(e,"prototype",{writable:!1}),t&&n(e,t)},t.exports.__esModule=!0,t.exports.default=t.exports},{"./setPrototypeOf.js":15}],10:[function(e,t,r){t.exports=function(e){return e&&e.__esModule?e:{default:e}},t.exports.__esModule=!0,t.exports.default=t.exports},{}],11:[function(e,t,r){t.exports=function(e){if("undefined"!=typeof Symbol&&null!=e[Symbol.iterator]||null!=e["@@iterator"])return Array.from(e)},t.exports.__esModule=!0,t.exports.default=t.exports},{}],12:[function(e,t,r){t.exports=function(){throw new TypeError("Invalid attempt to spread non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")},t.exports.__esModule=!0,t.exports.default=t.exports},{}],13:[function(e,t,r){var o=e("./defineProperty.js");t.exports=function(t){for(var e=1;e<arguments.length;e++){var r=null!=arguments[e]?Object(arguments[e]):{},n=Object.keys(r);"function"==typeof Object.getOwnPropertySymbols&&n.push.apply(n,Object.getOwnPropertySymbols(r).filter(function(e){return Object.getOwnPropertyDescriptor(r,e).enumerable})),n.forEach(function(e){o(t,e,r[e])})}return t},t.exports.__esModule=!0,t.exports.default=t.exports},{"./defineProperty.js":7}],14:[function(e,t,r){var n=e("./typeof.js").default,o=e("./assertThisInitial ...
#
# }
#  catch (e) {
# var log=window.console?window.console.log:function(o){alert(o)};
# log('Error with inline script "/gd-i18n-site-en-IE.js": ' + e);
# }
# </script><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react/17.0.1/umd/react.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/17.0.1/umd/react-dom.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-transition-group/1.2.1/react-transition-group.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-core-bottom-en-IE.js?v=7023bb4tx5"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-search.js?v=f4b61d7be"></script><script defer="" src="https://www.glassdoor.com/app/static/js/gd-search-salaries-en-IE.js?v=bae4368sx"></script><script>
# $(function() {
#   if(new Date().getTime() - (sessionStorage['js-session-valid'] || 0) > 45 * 60 * 1000) {
#     sessionStorage['js-session-valid'] = new Date().getTime();
#     jQuery.ajax({
#           url: 'app' === 'jobs-ux-app' ? '/Job/bwl.htm' : '/util/ajax/bwl.htm',
#           type: 'POST',
#           data: { guid: getGdGlobals().page.guid, gdToken: GD.page.gdToken },
#           success: function() { console.info('JSSV'); }
#     });
#   }
# });
# </script>
# <link href="/salaries/static/gd-salary-srch.bundle.css?v=17a6e6868f92390fb793" media="all" rel="stylesheet"/>
# <script defer="" src="/salaries/static/js/gd-vendor.bundle.js?v=17a6e6868f92390fb793" type="text/javascript"></script><script defer="" src="/salaries/static/js/gd-salary-srch.bundle.js?v=17a6e6868f92390fb793" type="text/javascript"></script>
# <style data-rh="true">#PageContent { width: auto; margin: 0; background: white; }</style>
# <style data-emotion-css="aks2zl">.css-aks2zl{margin:0 auto;max-width:1280px;width:100%;}</style><style data-emotion-css="1837fe">.css-1837fe{font-size:24px;line-height:36px;font-weight:900;color:#20262e;}</style><style data-emotion-css="1b6bxoo">.css-1b6bxoo{font-size:15px;line-height:24px;color:#505863;}</style><style data-emotion-css="186p6k2">.css-186p6k2{cursor:pointer;}.css-186p6k2 svg{width:20px;height:24px;}</style><style data-emotion-css="146zilq">.css-146zilq{font-size:44px;line-height:56px;font-weight:900;color:#20262e;}@media (max-width:767px){.css-146zilq{font-size:36px;line-height:48px;}}</style><style data-emotion-css="18stkbk">.css-18stkbk{font-size:15px;line-height:24px;color:#505863;font-weight:700;}</style><style data-emotion-css="1vkj9it">.css-1vkj9it{font-size:12px;line-height:20px;color:#505863;}</style><style data-emotion-css="615r19">.css-615r19{position:relative;height:80px;gap:6px;}</style><style data-emotion-css="1nrqqd7">.css-1nrqqd7{position:absolute !important;height:100%;}</style><style data-emotion-css="146cx6h">.css-146cx6h{height:0;width:100%;-webkit-transition:height 0.5s ease-out;transition:height 0.5s ease-out;background-color:#dee0e3;border-top:1px solid #858c94;}</style><style data-emotion-css="6vyvtw">.css-6vyvtw{background-color:#0c4085;border-top:2px solid #0c4085;}</style><style data-emotion-css="g261rn">.css-g261rn{font-size:18px;line-height:28px;font-weight:700;color:#20262e;}</style><style data-emotion-css="gui0u7">.css-gui0u7{font-size:15px;line-height:24px;color:#505863;font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><style data-emotion-css="15cs8dz">.css-15cs8dz{gap:16px;position:relative;}.css-15cs8dz:before{content:'';display:block;position:absolute;top:0;bottom:0;border-left:1px dotted #858c94;left:4px;z-index:-1;}.css-15cs8dz > div .gsm-dot-container{position:relative;overflow:hidden;min-width:9px;}.css-15cs8dz > div:first-child .gsm-dot-container:before,.css-15cs8dz > div:last-child .gsm-dot-container:after{content:'';display:block;position:absolute;background-color:white;height:100%;width:100%;z-index:-1;}.css-15cs8dz > div:first-child .gsm-dot-container:before{bottom:50%;}.css-15cs8dz > div:last-child .gsm-dot-container:after{top:50%;}</style><style data-emotion-css="1n68k6m">.css-1n68k6m{width:8px;height:14px;background-color:#dee0e3;border-radius:50%;border:1px solid #858c94;width:9px;height:9px;position:relative;}.css-1n68k6m.active{background-color:#0c4085;}.css-1n68k6m:before{content:'';display:block;background:white;position:absolute;top:-2px;bottom:-2px;left:0;right:0;z-index:-1;}</style><style data-emotion-css="1a3t88b">.css-1a3t88b{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-1a3t88b:hover{color:#0c4085;}.css-1a3t88b:not(:hover){color:#505863 !important;}</style><style data-emotion-css="1xkb4fk">.css-1xkb4fk{cursor:pointer;font-size:15px;line-height:24px;font-weight:700;color:#1861bf;}.css-1xkb4fk:hover{color:#0c4085;}</style><style data-emotion-css="123ngk9">.css-123ngk9{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-123ngk9:hover{color:#0c4085;}</style><style data-emotion-css="uukk77">.css-uukk77{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;top:0;bottom:0;left:0;right:0;position:fixed;z-index:8000;-webkit-animation-name:showModal;animation-name:showModal;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}@-webkit-keyframes showModal{from{opacity:0;}to{opacity:1;}}@keyframes showModal{from{opacity:0;}to{opacity:1;}}.css-uukk77 .background-overlay{position:fixed;left:0px;top:0px;background:#20262e;opacity:0.8;width:100%;height:100%;}@-webkit-keyframes showMain{from{max-width:0px;max-height:0px;}to{max-width:600px;max-height:80%;}}@keyframes showMain{from{max-wi ...
# .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;}
# .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style data-emotion="css-global"></style><style data-emotion="css"></style><link href="https://www.glassdoor.com/app/static/js/dist/gd-footer.bundle.css?v=b1e3903ov" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/garnish/static/css/gd-user-login.bundle.css?v=851238bb07224f9317a932300b7fc94c2b8b5d84" rel="stylesheet" type="text/css"/><style data-emotion="css"></style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style data-emotion="css"></style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><style>.resize-polyfill-wrapper {position: relative;top: auto !important;left: auto !important;} .resize-polyfill-polyfilled textarea {width: 100%;height: 100%;} .resize-polyfill-br {background: url("...") no-repeat center center;border: 2px solid transparent;bottom: 0px;cursor: se-resize;height: 8px;position: absolute;right: 0px;width: 8px;}</style><script async="" src="https://cdn.cookielaw.org/scripttemplates/6.28.0/otBannerSdk.js" type="text/javascript"></script><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes slideInFromBottomDelay{0%{opacity:0;transform:translateY(100%)}97%{opacity:0;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}</style><style id="onetrust-style">#onetrust-banner-sdk{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}#onetrust-banner-sdk .onetrust-vendors-list-handler{cursor:pointer;color:#1f96db;font-size:inherit;font-weight:bold;text-decoration:none;margin-left:5px}#onetrust-banner-sdk .onetrust-vendors-list-handler:hover{color:#1f96db}#onetrust-banner-sdk:focus{outline:2px solid #000;outline-offset:-2px}#onetrust-banner-sdk a:focus{outline:2px solid #000}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{outline-offset:1px}#onetrust-banner-sdk .ot-close-icon,#onetrust-pc-sdk .ot-close-icon,#ot-sync-ntfy .ot-close-icon{background-image:url("data:image/svg+xml;base64,...");background-size:contain;background-repeat:no-repeat;background-position:center;height:12px;width:12px}#onetrust-banner-sdk .powered-by-logo,#onetrust-banner-sdk .ot-pc-footer-logo  ...
# #onetrust-banner-sdk,#onetrust-pc-sdk,#ot-sdk-cookie-policy,#ot-sync-ntfy{font-size:16px}#onetrust-banner-sdk *,#onetrust-banner-sdk ::after,#onetrust-banner-sdk ::before,#onetrust-pc-sdk *,#onetrust-pc-sdk ::after,#onetrust-pc-sdk ::before,#ot-sdk-cookie-policy *,#ot-sdk-cookie-policy ::after,#ot-sdk-cookie-policy ::before,#ot-sync-ntfy *,#ot-sync-ntfy ::after,#ot-sync-ntfy ::before{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}#onetrust-banner-sdk div,#onetrust-banner-sdk span,#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-banner-sdk p,#onetrust-banner-sdk img,#onetrust-banner-sdk svg,#onetrust-banner-sdk button,#onetrust-banner-sdk section,#onetrust-banner-sdk a,#onetrust-banner-sdk label,#onetrust-banner-sdk input,#onetrust-banner-sdk ul,#onetrust-banner-sdk li,#onetrust-banner-sdk nav,#onetrust-banner-sdk table,#onetrust-banner-sdk thead,#onetrust-banner-sdk tr,#onetrust-banner-sdk td,#onetrust-banner-sdk tbody,#onetrust-banner-sdk .ot-main-content,#onetrust-banner-sdk .ot-toggle,#onetrust-banner-sdk #ot-content,#onetrust-banner-sdk #ot-pc-content,#onetrust-banner-sdk .checkbox,#onetrust-pc-sdk div,#onetrust-pc-sdk span,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#onetrust-pc-sdk p,#onetrust-pc-sdk img,#onetrust-pc-sdk svg,#onetrust-pc-sdk button,#onetrust-pc-sdk section,#onetrust-pc-sdk a,#onetrust-pc-sdk label,#onetrust-pc-sdk input,#onetrust-pc-sdk ul,#onetrust-pc-sdk li,#onetrust-pc-sdk nav,#onetrust-pc-sdk table,#onetrust-pc-sdk thead,#onetrust-pc-sdk tr,#onetrust-pc-sdk td,#onetrust-pc-sdk tbody,#onetrust-pc-sdk .ot-main-content,#onetrust-pc-sdk .ot-toggle,#onetrust-pc-sdk #ot-content,#onetrust-pc-sdk #ot-pc-content,#onetrust-pc-sdk .checkbox,#ot-sdk-cookie-policy div,#ot-sdk-cookie-policy span,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy p,#ot-sdk-cookie-policy img,#ot-sdk-cookie-policy svg,#ot-sdk-cookie-policy button,#ot-sdk-cookie-policy section,#ot-sdk-cookie-policy a,#ot-sdk-cookie-policy label,#ot-sdk-cookie-policy input,#ot-sdk-cookie-policy ul,#ot-sdk-cookie-policy li,#ot-sdk-cookie-policy nav,#ot-sdk-cookie-policy table,#ot-sdk-cookie-policy thead,#ot-sdk-cookie-policy tr,#ot-sdk-cookie-policy td,#ot-sdk-cookie-policy tbody,#ot-sdk-cookie-policy .ot-main-content,#ot-sdk-cookie-policy .ot-toggle,#ot-sdk-cookie-policy #ot-content,#ot-sdk-cookie-policy #ot-pc-content,#ot-sdk-cookie-policy .checkbox,#ot-sync-ntfy div,#ot-sync-ntfy span,#ot-sync-ntfy h1,#ot-sync-ntfy h2,#ot-sync-ntfy h3,#ot-sync-ntfy h4,#ot-sync-ntfy h5,#ot-sync-ntfy h6,#ot-sync-ntfy p,#ot-sync-ntfy img,#ot-sync-ntfy svg,#ot-sync-ntfy button,#ot-sync-ntfy section,#ot-sync-ntfy a,#ot-sync-ntfy label,#ot-sync-ntfy input,#ot-sync-ntfy ul,#ot-sync-ntfy li,#ot-sync-ntfy nav,#ot-sync-ntfy table,#ot-sync-ntfy thead,#ot-sync-ntfy tr,#ot-sync-ntfy td,#ot-sync-ntfy tbody,#ot-sync-ntfy .ot-main-content,#ot-sync-ntfy .ot-toggle,#ot-sync-ntfy #ot-content,#ot-sync-ntfy #ot-pc-content,#ot-sync-ntfy .checkbox{font-family:inherit;font-weight:normal;-webkit-font-smoothing:auto;letter-spacing:normal;line-height:normal;padding:0;margin:0;height:auto;min-height:0;max-height:none;width:auto;min-width:0;max-width:none;border-radius:0;border:none;clear:none;float:none;position:static;bottom:auto;left:auto;right:auto;top:auto;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;white-space:normal;background:none;overflow:visible;vertical-align:baseline;visibility:visible;z-index:auto;box-shadow:none}#onetrust-banner-sdk label:before,#onetrust-banner-sdk label:after,#onetrust-banner-sdk .checkbox:after,#onetrust-banner-sdk .checkbox:before,#onetrust-pc-sdk label:before,#onetrust-pc-sdk label:afte ...
# #onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{position:relative;width:100%;max-width:100%;margin:0 auto;padding:0 20px;box-sizing:border-box}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{width:100%;float:left;box-sizing:border-box;padding:0;display:initial}@media (min-width: 400px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:90%;padding:0}}@media (min-width: 550px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:100%}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{margin-left:4%}#onetrust-banner-sdk .ot-sdk-column:first-child,#onetrust-banner-sdk .ot-sdk-columns:first-child,#onetrust-pc-sdk .ot-sdk-column:first-child,#onetrust-pc-sdk .ot-sdk-columns:first-child,#ot-sdk-cookie-policy .ot-sdk-column:first-child,#ot-sdk-cookie-policy .ot-sdk-columns:first-child{margin-left:0}#onetrust-banner-sdk .ot-sdk-two.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-two.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-two.ot-sdk-columns{width:13.3333333333%}#onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-three.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-three.ot-sdk-columns{width:22%}#onetrust-banner-sdk .ot-sdk-four.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-four.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-four.ot-sdk-columns{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-eight.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eight.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eight.ot-sdk-columns{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-nine.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-nine.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-nine.ot-sdk-columns{width:74%}#onetrust-banner-sdk .ot-sdk-ten.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-ten.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-ten.ot-sdk-columns{width:82.6666666667%}#onetrust-banner-sdk .ot-sdk-eleven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eleven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eleven.ot-sdk-columns{width:91.3333333333%}#onetrust-banner-sdk .ot-sdk-twelve.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-twelve.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-twelve.ot-sdk-columns{width:100%;margin-left:0}}#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6{margin-top:0;font-weight:600;font-family:inherit}#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem;line-height:1.2}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem;line-height:1.25}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size:1.5rem;line-height:1.3}#onetrust-banner-sdk h4,#onetrust-pc-sdk h4,#ot-sdk-cookie-policy h4{font-size:1.5rem;line-height:1.35}#onetrust-banner-sdk h5,#onetrust-pc-sdk h5,#ot-sdk-cookie-policy h5{font-size:1.5rem;line-height:1.5}#onetrust-banner-sdk h6,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h6{font-size:1.5rem;line-height:1.6}@media (min-width: 550px){#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size: ...
# ...
# g.filter(function(b){return b._asData.videoSrc===document.fullscreenElement.src});a[0]._vidFullScreen()}}function x(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());if(d>b+c)for(b=d,l(),c=0;c<e.length;c++)-1===e[c].src.indexOf("enablejsapi\x3d")&&m(e[c])},3E3)}var y=
# function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"youtube",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),w={setMilestones:function(){var a=this.getVideoLength();this._asData.milestones=
# this._asData.milestones.map(function(b){return b/100*a})},setVideoTitle:function(){this._asData.videoTitle=this.getVideoTitle()},getVideoTitle:function(){var a=this._asData.videoTitle;this.playerInfo&&this.playerInfo.videoData&&this.playerInfo.videoData.title?a=this.playerInfo.videoData.title:this.getVideoData&&this.getVideoData().title&&(a=this.getVideoData().title);a!==this._asData.videoTitle&&this._asData.videoLoaded&&(this._asData.videoLoaded=!1);return a},getVideoLength:function(){return this.getDuration?
# Math.round(this.getDuration()):this.playerInfo&&this.playerInfo.duration?Math.round(this.playerInfo.duration):null},setVideoLength:function(){this._asData.videoLength=this.getVideoLength()},_getCurrentTime:function(){return this.getCurrentTime?Math.round(this.getCurrentTime()):this.playerInfo&&this.playerInfo.currentTime?Math.round(this.playerInfo.currentTime):null},isVideo:function(){return this&&"VIDEO"===this.nodeName},_vidLoaded:function(){this._asData.videoLoaded||(this.setVideoTitle(),this.setVideoLength(),
# this.setMilestones(),this._asData.videoLoaded=!0)},_vidPlay:function(a){var b=void 0===a?this:a.target;b._asData.adPlaying||b._vidLoaded();if(b._asData.adPlaying)b._asData.adPlaying=!1;else if(void 0===a&&this._asData&&"player loaded"===this._asData.eventType&&(this._asData.adPlaying=!0),"autoplay"!==b._asData.eventType&&"click to play"!==b._asData.eventType||0!==b._asData.currentTime){b.milestoneCheck&&window.clearInterval(b.milestoneCheck);b.milestoneCheck=window.setInterval(b._vidMilestones,1E3,
# a);if(b._asData.justFinished&&(b._asData.justFinished=!1,!b._asData.isPlaylist))return;a=b._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===a.length?(b._asData.firstPlay=!1,b._asData.autoplay?b._sendHit(a[1],!0):b._sendHit(a[0],!1)):b._asData.justSeeked||b._sendHit(a,!1);5<Math.abs(b._asData.currentTime-b._asData.previousTime)&&!b._asData.justFinished&&b._sendHit("seek",!1);b._asData.justSeeked=!1}},_vidPause:function(a){var b=a.target;"cued"!==b._asData.eventType&&(window.clearInterval(b.milestoneCheck),
# 5<Math.abs(b._asData.currentTime-b._asData.previousTime)?b._vidSeek(a):b._getCurrentTime()!==b._asData.videoLength&&b._sendHit("pause",!1))},_vidSeek:function(a){a=a.target;"cued"!==a._asData.eventType&&(a._asData.adPlaying||a._asData.justFinished||0===a._asData.currentTime&&(0===a._asData.milestones.length||3===a._asData.milestones.length)||a._asData.justSeeked||a._asData.firstPlay||a._asData.justFinished||a._sendHit("seek",!1),a._asData.justSeeked=!0)},_vidComplete:function(a){a=a.target;if(0<a._asData.milestones.length)for(var b=
# 0;b<a._asData.milestones.length;b++){var c=a._asData.milestones[b];c=c/a._asData.videoLength*100;!Number.isNaN(c)&&0===c%25&&0<c&&100>=c&&(a._asData.hitValue=c,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+c+"%")),!0))}a._asData.justFinished||(a._asData.adPlaying=!1,window.clearInterval(a.milestoneCheck),a._asData.hitValue=100,a._sendHit("complete",!0),a._asData.firstPlay=!0,a._asData.justFinished=!0,a._asData.milestones=[25,50,75],a._asData.isPlaylist?a._asData.finalPlaylistVid||
# (b=a.getPlaylistIndex(),c=a.getPlaylist().length,b+1===c&&(a._asData.finalPlaylistVid=!0),a._asData.autoplay=!0,a._asData.videoLoaded=!1,a._vidLoaded()):(a._asData.autoplay=!1,a.setVideoLength(),a.setMilestones()))},_vidMilestones:function(a){if(void 0!==a){a=a.target;var b=a._getCurrentTime();a._asData.previousTime=b;if(!(b<a._asData.milestones[0])){0===a._asData.milestones.length&&window.clearInterval(a.milestoneCheck);do{var c=a._asData.milestones.splice(0,1)[0];a._asData.firstPlay&&(a._sendHit("autoplay",
# !0),a._asData.firstPlay=!1)}while(c>b);b=c/a._asData.videoLength*100;!Number.isNaN(b)&&0===b%25&&0<b&&100>=b&&(a._asData.hitValue=b,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}}},_vidMuted:function(){if(this.isMuted)if(this.isMuted())this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=!1;else return;else if(this.playerInfo)if(this.playerInfo.muted)this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=
# !1;else return;this._asData.currentTime=this._getCurrentTime();void 0===this._asData.currentTime||1>this._asData.currentTime||(this._asData.justMuted?this._sendHit("mute",!1):this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.previousEventType=this._asData.eventType;this._asData.eventType=a;this._asData.hitValue=
# a.match(/milestone|complete/i)?this._asData.hitValue:null;this._asData.nonInteraction=b;y(this._asData)},setListeners:function(){this.addEventListener("onStateChange",function(a){if(-1===a.data){if("cued"===a.target._asData.eventType)return;if("player loaded"===a.target._asData.eventType){a.target._vidPlay(a);return}if(a.target._asData.videoTitle!==a.target.getVideoTitle()){a.target._asData.milestones=[25,50,75];a.target._asData.autoplay=!1;a.target._asData.firstPlay=!0;a.target._asData.videoLoaded=
# !1;a.target._asData.adPlaying=!1;a.target._vidLoaded();return}}if(5===a.data)a.target._asData.milestones=[25,50,75],a.target._asData.autoplay=!1,a.target._asData.firstPlay=!0,a.target._asData.videoLoaded=!1,a.target._asData.adPlaying=!1,a.target._asData.eventType="cued",a.target._asData.videoTitle="not set";else{a.target._asData.currentTime=a.target._getCurrentTime();var b=[a.target._vidComplete,a.target._vidPlay,a.target._vidPause,a.target._vidSeek];(b=b[a.data]||void 0)&&b(a);a.target._asData.previousTime=
# a.target._asData.currentTime}},!0);this.addEventListener("onVolumeChange",function(a){a=a.target;a._vidMuted()},!0)}},g=[];window._asVideos=g;var f,n=0,e,p=setInterval(function(){l();if(0<e.length){clearInterval(p);var a=window.YT;if(0<e.length){a="undefined"!==typeof a&&"undefined"!==typeof a.Player;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="//www.youtube.com/iframe_api";b.parentNode.insertBefore(a,b)}f=window.setInterval(r,
# 1E3)}}},500);setTimeout(function(){clearInterval(p)},1E4);setTimeout(function(){x()},5E3)}})();</script>
# <script id="" type="text/javascript">(function(){var l=setInterval(function(){window.gdGlobals?(clearInterval(l),r()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(l)},1E4);var r=function(){function m(){g=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/player.vimeo.com/.test(a.src)})}function t(){var a=window.Vimeo;"undefined"!==typeof a?(window.clearInterval(h),g.map(n)):5>p?p++:window.clearInterval(h)}function n(a){var b=window.Vimeo;b=new b.Player(a);b._asData=
# {eventType:void 0,videoTitle:"not set",videoPlayer:"Vimeo_iframe",videoLength:"not set",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,vidLoaded:!1,nonInteraction:null,hitValue:0};var c=b,d=u,f;for(f in d)c[f]=d[f];b.setListeners();v.push(b);b._vidLoaded();a._asProcessed=!0}function w(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),
# Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());d>b+c&&(b=d,m(),g.map(function(f){f._asProcessed||n(f)}))},3E3)}var x=function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"vimeo",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,
# videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),u={setMilestones:function(){var a=this,b=window.setInterval(function(){var c=a._asData.videoLength;"not set"!==c&&(a._asData.milestones=a._asData.milestones.map(function(d){return d/100*c}),window.clearInterval(b))},200,a)},setVideoTitle:function(){var a=this;this.getVideoTitle().then(function(b){a._asData.videoTitle=b})},replayOrNewVid:function(){var a=this;this._asData.milestones=
# [25,50,75];this.getVideoTitle().then(function(b){a._asData.videoTitle===b?(a._asData.justFinished=!1,a.setMilestones()):a._vidLoaded();a._vidPlay()})},setVideoLength:function(){var a=this;this.getDuration().then(function(b){a._asData.videoLength=Math.round(b)})},_asGetCurrentTime:function(){var a=this;this.getCurrentTime().then(function(b){a._asData.currentTime=b})},_vidLoaded:function(){var a=this;this.setVideoTitle();this.setVideoLength();this.setMilestones();this.getVolume().then(function(c){0===
# c&&(a._asData.justMuted=!0)});var b=setInterval(function(){"not set"!==a._asData.videoTitle&&clearInterval(b)},75);this._asData.justFinished=!1;this._asData.vidLoaded=!0},_vidPlay:function(){if(!e){var a=this;window.setTimeout(function(){if(!e)if(a._asData.justFinished&&a._asData.firstPlay)a.replayOrNewVid();else{var b=a._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===b.length?(a._asData.firstPlay=!1,a._asData.autoplay?a._sendHit(b[1],!0):a._sendHit(b[0],!1)):a._sendHit(b,!1)}},
# 1E3,a)}},_vidPause:function(){var a=this;a._asData.justFinished||e||window.setTimeout(function(){a._asData.justFinished||e||a.getCurrentTime()!==a._asData.videoLength&&a._sendHit("pause",!1)},1E3,a)},_vidSeek:function(){e||this._asData.justFinished||(e=!0,this._sendHit("seek",!1),window.setTimeout(function(){e=!1},2E3))},_vidComplete:function(){if(0<this._asData.milestones.length)for(var a=0;a<this._asData.milestones.length;a++){var b=this._asData.milestones[a];b=b/this._asData.videoLength*100;!Number.isNaN(b)&&
# 0===b%25&&0<b&&100>=b&&(this._asData.hitValue=b,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}this._asData.hitValue=100;this._sendHit("complete",!0);this._asData.firstPlay=!0;this._asData.justFinished=!0;this._asData.autoplay=!1},_vidMilestones:function(a){this._asData.currentTime=a.seconds;if(!(k||(k=!0,window.setTimeout(function(){k=!1},2E3),this._asData.firstPlay&&3<a.seconds&&this._vidPlay(),a.seconds<this._asData.milestones[0]||0===this._asData.milestones.length))){a=
# a.seconds;do var b=this._asData.milestones.splice(0,1)[0];while(b>a);a=b/this._asData.videoLength*100;!Number.isNaN(a)&&0===a%25&&0<a&&100>=a&&(this._asData.hitValue=a,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+a+"%")),!0))}},_vidMuted:function(a){!1===this._asData.justMuted&&0===a.volume?(this._asData.justMuted=!0,this._sendHit("mute",!1)):this._asData.justMuted&&0<a.volume&&(this._asData.justMuted=!1,this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||
# document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.eventType=a;this._asData.nonInteraction=b;this._asData.hitValue=a.match(/milestone|complete/i)?this._asData.hitValue:null;x(this._asData)},setListeners:function(){this.on("play",function(){this._vidPlay()},!0);this.on("pause",function(){this._vidPause()},!0);this.on("seeked",function(){this._vidSeek()},!0);this.on("ended",function(){this._vidComplete()},
# !0);this.on("timeupdate",function(a){this._vidMilestones(a)},!0);this.on("volumechange",function(a){this._vidMuted(a)},!0);this.on("fullscreenchange",function(){this._vidFullScreen()},!0);this.on("webkitfullscreenchange",function(){this._vidFullScreen()},!0);this.on("mozfullscreenchange",function(){this._vidFullScreen()},!0);this.on("msfullscreenchange",function(){this._vidFullScreen()},!0)}},v=[],h,p=0,g,e=!1,k=!1,q=setInterval(function(){m();if(0<g.length){clearInterval(q);var a=window.Vimeo;if(0<
# g.length){a="undefined"!==typeof a;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="https://player.vimeo.com/api/player.js";b.parentNode.insertBefore(a,b)}h=window.setInterval(t,1E3)}}},500);setTimeout(function(){clearInterval(q)},1E4);setTimeout(function(){w()},5E3)}})();</script><div id="onetrust-consent-sdk"><div class="onetrust-pc-dark-filter ot-hide ot-fade-in"></div><div class="otFlat bottom ot-wo-title vertical-align-content" id="onetrust-banner-sdk" style="bottom: 0px;" tabindex="0"><div aria-describedby="onetrust-policy-text" aria-label="Privacy" role="alertdialog"><div class="ot-sdk-container"><div class="ot-sdk-row"><div class="ot-sdk-eight ot-sdk-columns" id="onetrust-group-container"><div class="banner_logo"></div><div id="onetrust-policy"><p id="onetrust-policy-text">We use first and third-party cookies on our platform (including strictly necessary; analysis and user experience improvement; and ad personalization and effectiveness cookies). To agree to these cookies for these purposes, please Accept Cookies. Learn more in our <a _blank="" href="http://hrtechprivacy.com/brands/glassdoor#cookie-policy">Cookie Policy</a>. Change your choices via Select Cookies or the Cookie Consent Tool in our footer.</p></div></div><div class="ot-sdk-three ot-sdk-columns has-reject-all-button" id="onetrust-button-group-parent"><div id="onetrust-button-group"><button class="cookie-setting-link" id="onetrust-pc-btn-handler">Select Cookies</button> <button id="onetrust-reject-all-handler">Reject All</button> <button id="onetrust-accept-btn-handler">Accept Cookies</button></div></div></div></div><!-- Close Button --><div id="onetrust-close-btn-container"></div><!-- Close Button END--></div></div></div><script id="" type="text/javascript">if(google_tag_manager["GTM-PST2JZ"].macro(2041).includes("C0017")){var now=new Date,time=now.getTime(),futureTime=time+63072E6;now.setTime(futureTime);document.cookie="_optionalConsent\x3dtrue; path\x3d/; expires\x3d"+now.toUTCString()}else now=new Date,time=now.getTime(),futureTime=time+63072E6,now.setTime(futureTime),document.cookie="_optionalConsent\x3dfalse; path\x3d/; expires\x3d"+now.toUTCString();</script><script id="" type="text/javascript">if(google_tag_manager["GTM-PST2JZ"].macro(2048).includes("C0017")){var now=new Date,time=now.getTime(),futureTime=time+63072E6;now.setTime(futureTime);document.cookie="_optionalConsent\x3dtrue; path\x3d/; expires\x3d"+now.toUTCString()}else now=new Date,time=now.getTime(),futureTime=time+63072E6,now.setTime(futureTime),document.cookie="_optionalConsent\x3dfalse; path\x3d/; expires\x3d"+now.toUTCString();</script></body></html>

# %%
soup.find_all('h1', {'class':'m-0 css-1837fe'})
# Out:
# []

# %%
listoutput = pd.Series(output)
listoutput
# Out:
# 0    [[[\n, <title>Salary: Junior Data Analyst in D...
# 1    [[[\n, <title>Salary: Junior Data Analyst in A...
# 2    [[[\n, <title>Salary: Junior Data Analyst in A...
# 3    [[[\n, <title>Salary: Junior Data Analyst in P...
# 4    [[[\n, <title>Salary: Junior Data Analyst in B...
# 5    [[[\n, <title>Salary: Junior Data Analyst in M...
# 6    [[[\n, <title>Salary: Junior Data Analyst in L...
# 7    [[[\n, <title>Salary: Junior Data Analyst in B...
# 8    [[[\n, <title>Salary: Junior Data Analyst in B...
# 9    [[[\n, <title>Salary: Junior Data Analyst in L...
# dtype: object

# %%
soup.find_all('input', {'id':'sc.location'})
# Out:
# []

# %%
url
# Out:
# 'https://www.glassdoor.ie/Salaries/dublin-data-analyst-salary-SRCH_IL.0,6_IM1052_KO7,19.htm?clickSource=searchBtn'

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="flex" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# glassdoor: http://ogp.me/ns/fb/glassdoor#"><!-- because the getter clears the value --><script>
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/profile/login",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-IE',
# 			'env': 'prod',
# 			'release': '20220426-2',
# 			'appName': 'app',
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.ie",
# 								'domainId':		18,
# 								'domainCountryId': 70,
#
#
# 								'domainSuffix': "ie",
#
#
# 								'group':        "Account-Login",
#
#
# 								'projectUrlGroup':        "[]",
#
#
# 								'guid':         '000001808b35394fb875891e6a18fde1',
#
#
# 								'flex':         true,
#
#
# 								'section':      "profile",
#
#
# 								'type':         "SignIn",
#
#
# 								'id':           "signin",
#
# 								'med': '',
#
# 								'src' : '',
# 								'content' : '',
# 								'campaign' : '',
# 								'term' : '',
# 								'state' : 'locked',
# 								'untranslatedUrl' : 'https://www.glassdoor.com/profile/login_input.htm'
#
# 							},
#
# 			'user':         {
#
# 								'guid':         '2307feb2-6542-429a-b551-36f8f92592e1',
#
# 								'ipAddr':       "84.203.86.255",
#
#
# 								'locale':       "en_IE",
#
#
# 								'country':      "IE",
# 								'ipLocationId': "2739035",
# 								'ipLocationType': "C",
#
# 								'elligibleForAppBoy': false,
# 							},
#
# 			'vendor':       {
# 								'fbReqPerms':   ""
# 							},
#
# 			'search':       {
#
# 				"rawKeyword":""
#
# 			},
# 			'employer' : {
#
# 			},
# 			'job' : {
#
# 			},
# 			'test' : {
#
# 				'planoutIdList': [
#
# 						, "site_discovery_ugc_search2.PROD_ugc_search2_v1"
#
# 						, "site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1"
#
# 						, "growth_global.exp_growth_global_catchAll"
#
# 						, "lightweight_data_collection.exp_user_profile_catchall"
#
# 						, "user_profile.exp_user_profile_catchall"
#
# 						, "content_single_page_survey.CXP_1419_PROD_test"
#
# 						, "site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1"
#
# 						, "content_reviews_node.I18N_redirect_reviews_node_test_20190530"
#
# 						, "content_survey_global_context.CON_238_PROD_test_051221"
#
# 						, "nuf_steps.last_step_test"
#
# 						, "site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1"
#
# 						, "ei_compare_rollout.TRFC_4368_ei_compare"
#
# 						, "company_explorer.TRFC_4524_02102020"
#
# 						, "growth_user_activation.user_activation_post_auth_redirect_exp_20220201"
#
# 						, "site_discovery_nav.site_discovery_nav_t2"
#
# 						, "nuf_v2_1.ipad_promotion_test"
#
# 						, "growth_jobs.growth_jobs_default_catchAll"
#
# 						, "nuf_gd_logo.disabled_logo_test"
#
# 						, "site_discovery_header.exp_site_discovery_header_catchall"
#
# 						, "site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall"
#
# 				],
# 				'planoutTreatmentList': [
#
# 						, "ugc_search2_t1"
#
# 						, "ugc_search2_salaries_t1"
#
# 						, "growth_global_default"
#
# 						, "lightweight_data_collection_default"
#
# 						, "user_profile_default_treatment"
#
# 						, "single_page_t1"
#
# 						, "ugc_search2_autocomplete_t1"
#
# 						, "redirect2Node_t1"
#
# 						, "new_suggested_companies_t1"
#
# 						, "last_step_test_control"
#
# 						, "ugc_search2_interviews_t1"
#
# 						, "ei_compare_activated"
#
# 						, "test_on"
#
# 						, "post_auth_redirect_t1"
#
# 						, "career_nav_t2"
#
# 						, "nuf_v2_1_control"
#
# 						, "growth_jobs_default"
#
# 						, "disabled_logo_test_t1"
#
# 						, "site_discovery_header_default"
#
# 						, "fishbowl_default"
#
# 				]
# 			},
# 			'staticList' : {
#
# 			}
#
# 		}];
#
# 	if(window.projectUrlGroup && Array.isArray(window.projectUrlGroup)) {
# 		var globalsProjectUrlGroup = JSON.parse(gdGlobals[0].page.projectUrlGroup);
# 		var combined = globalsProjectUrlGroup.concat(window.projectUrlGroup);
# 		gdGlobals[0].page.projectUrlGroup = JSON.stringify(combined);
# 	}
#
#
# 	window.getGdGlobals = window.getGdGlobals ||
# 			function() {
# 				return gdGlobals[0];
# 			};
#
# 	GD = window.GD || {};
# 	GD.pageInfo = GD.pageInfo || {};
# 	GD.pageInfo.pageGroup = getGdGlobals().page.group;
# 	GD.domain = getGdGlobals().page.domain;
#
# 	</script><!-- Google Tag Manager --><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PST2JZ" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>
#
# 			(function(w,d,s,l,i) {
# 				w[l] = w[l] || [];
# 				w[l].push({
# 					'gtm.start': new Date().getTime(),
# 					event:       'gtm.js'
# 				});
# 				var f = d.getElementsByTagName(s)[0],
# 						j = d.createElement(s),
# 						dl = l != 'dataLayer' ? '&l=' + l : '';
# 				j.defer=true;
# 				j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
# 				f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','gdGlobals','GTM-PST2JZ');
# 		</script><!-- End Google Tag Manager --><link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link href="https://www.glassdoor.com/app/static/css/gd-core.css?v=759371b5qo" media="all" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/app/static/css/sections/gd-profile.css?v=2aefa36nl" media="all" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/app/static/js/dist/gd-site-header.bundle.css?v=f2b9beoqb" media="all" rel="stylesheet" type="text/css"/><script></script></head></html>

# %%
citys
# Out:
# 'Dublin'

# %%
soup.find_all('input', {'id':'sc.location'})
# Out:
# []

# %%
position_summary_detail
# Out:
# []

# %%
soup
# Out:
# <html><body><p>https://www.glassdoor.ie/Salaries/dublin-data-analyst-salary-SRCH_IL.0,6_IM1052_KO7,19.htm?clickSource=searchBtn</p></body></html>

# %%
position_summary_detail
# Out:
# ['Dublin']

# %%
citys
# Out:
# 'Dublin'

# %%
soup.find_all('h1')
# Out:
# [<h1 data-test="job-location-title">Explore Jobs Near You</h1>,
#  <h1 data-test="jobs-container-explore-gd-title">Explore Glassdoor</h1>,
#  <h1 class="mb-std css-18lin6p">Explore Salaries</h1>,
#  <h1 data-test="compnay-follows-with-followed-title">Companies You Follow</h1>]

# %%
positiondetail
# Out:
# []

# %%
soup
# Out:
# <html lang="en" style="height: 100%;" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="/manifest.json" rel="manifest"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://www.facebook.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://cdnjs.cloudflare.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6uyw4BMUTPHjx4wXiWtFCc.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2" rel="preload" type="font/woff2"/><link href="/garnish/static/css/gd-core.bundle.8c00c.css" rel="stylesheet"/><link href="/garnish/static/css/gd-footer.bundle.0c586.css" rel="stylesheet"/><link href="/garnish/static/css/gd-siteHeader.bundle.eacd4.css" rel="stylesheet"/><title>Glassdoor Job Search | Find the job that fits your life</title><meta content="Search millions of jobs and get the inside scoop on companies with employee reviews, personalised salary tools, and more. Hiring? Post a job for free." data-rh="true" name="description"/><meta content="noindex" data-rh="true" name="robots"/><style data-emotion-css="j7qwjs">.css-j7qwjs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><style data-emotion-css="1q3ssei">.css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}</style><style data-emotion-css="eyudwk">.css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}</style><style data-emotion-css="5j38mw">.css-5j38mw{font-size:15px;background-color:#fff;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;color:#858c94;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-5j38mw:hover{border-color:#858c94;color:#505863;}.css-5j38mw::-webkit-input-placeholder{color:#c4c7cc;}.css-5j38mw::-moz-placeholder{color:#c4c7cc;}.css-5j38mw:-ms-input-placeholder{color:#c4c7cc;}.css-5j38mw::placeholder{color:#c4c7cc;}.css-5j38mw:focus,.css-5j38mw:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7 ...
# #onetrust-banner-sdk,#onetrust-pc-sdk,#ot-sdk-cookie-policy,#ot-sync-ntfy{font-size:16px}#onetrust-banner-sdk *,#onetrust-banner-sdk ::after,#onetrust-banner-sdk ::before,#onetrust-pc-sdk *,#onetrust-pc-sdk ::after,#onetrust-pc-sdk ::before,#ot-sdk-cookie-policy *,#ot-sdk-cookie-policy ::after,#ot-sdk-cookie-policy ::before,#ot-sync-ntfy *,#ot-sync-ntfy ::after,#ot-sync-ntfy ::before{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}#onetrust-banner-sdk div,#onetrust-banner-sdk span,#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-banner-sdk p,#onetrust-banner-sdk img,#onetrust-banner-sdk svg,#onetrust-banner-sdk button,#onetrust-banner-sdk section,#onetrust-banner-sdk a,#onetrust-banner-sdk label,#onetrust-banner-sdk input,#onetrust-banner-sdk ul,#onetrust-banner-sdk li,#onetrust-banner-sdk nav,#onetrust-banner-sdk table,#onetrust-banner-sdk thead,#onetrust-banner-sdk tr,#onetrust-banner-sdk td,#onetrust-banner-sdk tbody,#onetrust-banner-sdk .ot-main-content,#onetrust-banner-sdk .ot-toggle,#onetrust-banner-sdk #ot-content,#onetrust-banner-sdk #ot-pc-content,#onetrust-banner-sdk .checkbox,#onetrust-pc-sdk div,#onetrust-pc-sdk span,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#onetrust-pc-sdk p,#onetrust-pc-sdk img,#onetrust-pc-sdk svg,#onetrust-pc-sdk button,#onetrust-pc-sdk section,#onetrust-pc-sdk a,#onetrust-pc-sdk label,#onetrust-pc-sdk input,#onetrust-pc-sdk ul,#onetrust-pc-sdk li,#onetrust-pc-sdk nav,#onetrust-pc-sdk table,#onetrust-pc-sdk thead,#onetrust-pc-sdk tr,#onetrust-pc-sdk td,#onetrust-pc-sdk tbody,#onetrust-pc-sdk .ot-main-content,#onetrust-pc-sdk .ot-toggle,#onetrust-pc-sdk #ot-content,#onetrust-pc-sdk #ot-pc-content,#onetrust-pc-sdk .checkbox,#ot-sdk-cookie-policy div,#ot-sdk-cookie-policy span,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy p,#ot-sdk-cookie-policy img,#ot-sdk-cookie-policy svg,#ot-sdk-cookie-policy button,#ot-sdk-cookie-policy section,#ot-sdk-cookie-policy a,#ot-sdk-cookie-policy label,#ot-sdk-cookie-policy input,#ot-sdk-cookie-policy ul,#ot-sdk-cookie-policy li,#ot-sdk-cookie-policy nav,#ot-sdk-cookie-policy table,#ot-sdk-cookie-policy thead,#ot-sdk-cookie-policy tr,#ot-sdk-cookie-policy td,#ot-sdk-cookie-policy tbody,#ot-sdk-cookie-policy .ot-main-content,#ot-sdk-cookie-policy .ot-toggle,#ot-sdk-cookie-policy #ot-content,#ot-sdk-cookie-policy #ot-pc-content,#ot-sdk-cookie-policy .checkbox,#ot-sync-ntfy div,#ot-sync-ntfy span,#ot-sync-ntfy h1,#ot-sync-ntfy h2,#ot-sync-ntfy h3,#ot-sync-ntfy h4,#ot-sync-ntfy h5,#ot-sync-ntfy h6,#ot-sync-ntfy p,#ot-sync-ntfy img,#ot-sync-ntfy svg,#ot-sync-ntfy button,#ot-sync-ntfy section,#ot-sync-ntfy a,#ot-sync-ntfy label,#ot-sync-ntfy input,#ot-sync-ntfy ul,#ot-sync-ntfy li,#ot-sync-ntfy nav,#ot-sync-ntfy table,#ot-sync-ntfy thead,#ot-sync-ntfy tr,#ot-sync-ntfy td,#ot-sync-ntfy tbody,#ot-sync-ntfy .ot-main-content,#ot-sync-ntfy .ot-toggle,#ot-sync-ntfy #ot-content,#ot-sync-ntfy #ot-pc-content,#ot-sync-ntfy .checkbox{font-family:inherit;font-weight:normal;-webkit-font-smoothing:auto;letter-spacing:normal;line-height:normal;padding:0;margin:0;height:auto;min-height:0;max-height:none;width:auto;min-width:0;max-width:none;border-radius:0;border:none;clear:none;float:none;position:static;bottom:auto;left:auto;right:auto;top:auto;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;white-space:normal;background:none;overflow:visible;vertical-align:baseline;visibility:visible;z-index:auto;box-shadow:none}#onetrust-banner-sdk label:before,#onetrust-banner-sdk label:after,#onetrust-banner-sdk .checkbox:after,#onetrust-banner-sdk .checkbox:before,#onetrust-pc-sdk label:before,#onetrust-pc-sdk label:afte ...
# #onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{position:relative;width:100%;max-width:100%;margin:0 auto;padding:0 20px;box-sizing:border-box}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{width:100%;float:left;box-sizing:border-box;padding:0;display:initial}@media (min-width: 400px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:90%;padding:0}}@media (min-width: 550px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:100%}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{margin-left:4%}#onetrust-banner-sdk .ot-sdk-column:first-child,#onetrust-banner-sdk .ot-sdk-columns:first-child,#onetrust-pc-sdk .ot-sdk-column:first-child,#onetrust-pc-sdk .ot-sdk-columns:first-child,#ot-sdk-cookie-policy .ot-sdk-column:first-child,#ot-sdk-cookie-policy .ot-sdk-columns:first-child{margin-left:0}#onetrust-banner-sdk .ot-sdk-two.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-two.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-two.ot-sdk-columns{width:13.3333333333%}#onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-three.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-three.ot-sdk-columns{width:22%}#onetrust-banner-sdk .ot-sdk-four.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-four.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-four.ot-sdk-columns{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-eight.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eight.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eight.ot-sdk-columns{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-nine.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-nine.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-nine.ot-sdk-columns{width:74%}#onetrust-banner-sdk .ot-sdk-ten.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-ten.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-ten.ot-sdk-columns{width:82.6666666667%}#onetrust-banner-sdk .ot-sdk-eleven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eleven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eleven.ot-sdk-columns{width:91.3333333333%}#onetrust-banner-sdk .ot-sdk-twelve.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-twelve.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-twelve.ot-sdk-columns{width:100%;margin-left:0}}#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6{margin-top:0;font-weight:600;font-family:inherit}#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem;line-height:1.2}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem;line-height:1.25}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size:1.5rem;line-height:1.3}#onetrust-banner-sdk h4,#onetrust-pc-sdk h4,#ot-sdk-cookie-policy h4{font-size:1.5rem;line-height:1.35}#onetrust-banner-sdk h5,#onetrust-pc-sdk h5,#ot-sdk-cookie-policy h5{font-size:1.5rem;line-height:1.5}#onetrust-banner-sdk h6,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h6{font-size:1.5rem;line-height:1.6}@media (min-width: 550px){#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size: ...
# #onetrust-banner-sdk{box-shadow:0 0 18px rgba(0,0,0,.2)}#onetrust-banner-sdk.otFlat{position:fixed;z-index:2147483645;bottom:0;right:0;left:0;background-color:#fff;max-height:90%;overflow-x:hidden;overflow-y:auto}#onetrust-banner-sdk.otFlat.top{top:0px;bottom:auto}#onetrust-banner-sdk.otRelFont{font-size:1rem}#onetrust-banner-sdk>.ot-sdk-container{overflow:hidden}#onetrust-banner-sdk::-webkit-scrollbar{width:11px}#onetrust-banner-sdk::-webkit-scrollbar-thumb{border-radius:10px;background:#c1c1c1}#onetrust-banner-sdk{scrollbar-arrow-color:#c1c1c1;scrollbar-darkshadow-color:#c1c1c1;scrollbar-face-color:#c1c1c1;scrollbar-shadow-color:#c1c1c1}#onetrust-banner-sdk #onetrust-policy{margin:1.25em 0 .625em 2em;overflow:hidden}#onetrust-banner-sdk #onetrust-policy .ot-gv-list-handler{float:left;font-size:.82em;padding:0;margin-bottom:0;border:0;line-height:normal;height:auto;width:auto}#onetrust-banner-sdk #onetrust-policy-title{font-size:1.2em;line-height:1.3;margin-bottom:10px}#onetrust-banner-sdk #onetrust-policy-text{clear:both;text-align:left;font-size:.88em;line-height:1.4}#onetrust-banner-sdk #onetrust-policy-text *{font-size:inherit;line-height:inherit}#onetrust-banner-sdk #onetrust-policy-text a{font-weight:bold;margin-left:5px}#onetrust-banner-sdk #onetrust-policy-title,#onetrust-banner-sdk #onetrust-policy-text{color:dimgray;float:left}#onetrust-banner-sdk #onetrust-button-group-parent{min-height:1px;text-align:center}#onetrust-banner-sdk #onetrust-button-group{display:inline-block}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{background-color:#68b631;color:#fff;border-color:#68b631;margin-right:1em;min-width:125px;height:auto;white-space:normal;word-break:break-word;word-wrap:break-word;padding:12px 10px;line-height:1.2;font-size:.813em;font-weight:600}#onetrust-banner-sdk #onetrust-pc-btn-handler.cookie-setting-link{background-color:#fff;border:none;color:#68b631;text-decoration:underline;padding-left:0;padding-right:0}#onetrust-banner-sdk .onetrust-close-btn-ui{width:44px;height:44px;background-size:12px;border:none;position:relative;margin:auto;padding:0}#onetrust-banner-sdk .banner_logo{display:none}#onetrust-banner-sdk .ot-b-addl-desc{clear:both;float:left;display:block}#onetrust-banner-sdk #banner-options{float:left;display:table;margin-right:0;margin-left:1em;width:calc(100% - 1em)}#onetrust-banner-sdk .banner-option-input{cursor:pointer;width:auto;height:auto;border:none;padding:0;padding-right:3px;margin:0 0 10px;font-size:.82em;line-height:1.4}#onetrust-banner-sdk .banner-option-input *{pointer-events:none;font-size:inherit;line-height:inherit}#onetrust-banner-sdk .banner-option-input[aria-expanded=true]~.banner-option-details{display:block;height:auto}#onetrust-banner-sdk .banner-option-input[aria-expanded=true] .ot-arrow-container{transform:rotate(90deg)}#onetrust-banner-sdk .banner-option{margin-bottom:12px;margin-left:0;border:none;float:left;padding:0}#onetrust-banner-sdk .banner-option:first-child{padding-left:2px}#onetrust-banner-sdk .banner-option:not(:first-child){padding:0;border:none}#onetrust-banner-sdk .banner-option-header{cursor:pointer;display:inline-block}#onetrust-banner-sdk .banner-option-header :first-child{color:dimgray;font-weight:bold;float:left}#onetrust-banner-sdk .banner-option-header .ot-arrow-container{display:inline-block;border-top:6px solid transparent;border-bottom:6px solid transparent;border-left:6px solid dimgray;margin-left:10px;vertical-align:middle}#onetrust-banner-sdk .banner-option-details{display:none;font-size:.83em;line-height:1.5;padding:10px 0px 5px 10px;margin-right:10px;height:0px}#onetrust-banner-sdk .banner-option-details *{font-size:inherit;line-height:inherit;color:dimgray}#onetrust-banner-sdk .ot-arrow-container,#onetrust-banner-sdk .banner-option-details{transition:all 300ms ease-in 0s;-webkit-transition:all 300ms ease-in 0s;-moz-transition:all 300ms ease-in 0s;-o ...
#         #onetrust-consent-sdk #onetrust-banner-sdk {background-color: #FFFFFF;}
#             #onetrust-consent-sdk #onetrust-policy-title,
#                     #onetrust-consent-sdk #onetrust-policy-text,
#                     #onetrust-consent-sdk .ot-b-addl-desc,
#                     #onetrust-consent-sdk .ot-dpd-desc,
#                     #onetrust-consent-sdk .ot-dpd-title,
#                     #onetrust-consent-sdk #onetrust-policy-text *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk .ot-dpd-desc *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk #onetrust-banner-sdk #banner-options *,
#                     #onetrust-banner-sdk .ot-cat-header {
#                         color: #505863;
#                     }
#             #onetrust-consent-sdk #onetrust-banner-sdk .banner-option-details {
#                     background-color: #E9E9E9;}
#              #onetrust-consent-sdk #onetrust-banner-sdk a[href],
#                     #onetrust-consent-sdk #onetrust-banner-sdk a[href] font,
#                     #onetrust-consent-sdk #onetrust-banner-sdk .ot-link-btn
#                         {
#                             color: #3860BE;
#                         }#onetrust-consent-sdk #onetrust-accept-btn-handler,
#                          #onetrust-banner-sdk #onetrust-reject-all-handler {
#                             background-color: #1861BF;border-color: #1861BF;
#                 color: #FFFFFF;
#             }
#             #onetrust-consent-sdk #onetrust-banner-sdk *:focus,
#             #onetrust-consent-sdk #onetrust-banner-sdk:focus {
#                outline-color: #000000;
#                outline-width: 1px;
#             }
#             #onetrust-consent-sdk #onetrust-pc-btn-handler,
#             #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link {
#                 color: #0caa41; border-color: #0caa41;
#                 background-color:
#                 #FFFFFF;
#             }#onetrust-banner-sdk {
#     box-shadow: 0px 0px 2px #c4c7cc;
# }.ot-sdk-cookie-policy{font-family:inherit;font-size:16px}.ot-sdk-cookie-policy.otRelFont{font-size:1rem}.ot-sdk-cookie-policy h3,.ot-sdk-cookie-policy h4,.ot-sdk-cookie-policy h6,.ot-sdk-cookie-policy p,.ot-sdk-cookie-policy li,.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy th,.ot-sdk-cookie-policy #cookie-policy-description,.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}.ot-sdk-cookie-policy h4{font-size:1.2em}.ot-sdk-cookie-policy h6{font-size:1em;margin-top:2em}.ot-sdk-cookie-policy th{min-width:75px}.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy a:hover{background:#fff}.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}.ot-sdk-cookie-policy .ot-mobile-border{display:none}.ot-sdk-cookie-policy section{margin-bottom:2em}.ot-sdk-cookie-policy table{border-collapse:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy{font-family:inherit;font-size:1rem}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup{margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group-desc,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-table-header,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td{font-size:.9em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td a{font-size:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group{font-size:1em;margin-bottom:.6em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-title{margin-bottom:1.2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy>section{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th{min-width:75px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a:hover{background:#fff}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-mobile-border{display:none}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy section{margin-bottom:2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li{list-style:disc;margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li h4{display:inline-block}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table{border-collapse:inherit;margin:auto;border:1px solid #d7d7d7;border-radius:5px;border-spacing:initial;width:100%;overflow:hidden}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table td{border-bottom:1px solid #d7d7d7;border-right:1px solid #d7d7d7}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr:last-child td{border-bottom:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr th:last-child,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr td:last-child{border-right:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-host,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-cookies-type{width:25%}.ot-sdk-cookie-policy[dir=rtl]{text-align:left}#ot-sdk-cookie-policy h3{font-size:1.5em}@media only screen and (max-wi ...
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h5,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group {
#                         color: #696969;
#                     }
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title {
#                             color: #696969;
#                         }
#
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th {
#                             background-color: #F8F8F8;
#                         }
#
#
#                       @keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       @-webkit-keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       @-moz-keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       </style><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes slideInFromBottomDelay{0%{opacity:0;transform:translateY(100%)}97%{opacity:0;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}</style></head><body class="main loggedIn lang-en en-IE gdGrid _initOk" data-locale="en-IE" marginheight="0" marginwidth="0">
# <!--<decorator:body/> -->
# <div id="UserAlert"></div><header id="SiteNav"><nav class="d-flex align-items-center siteHeader__HeaderStyles__navigationBackground siteHeader__HeaderStyles__relativePosition" data-test="background-header-nav"><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="siteHeader__HeaderStyles__navigationWrapper"><div class="d-flex justify-content-between align-items-center px-std px-md-lg siteHeader__HeaderStyles__mainNav"><div class="d-flex d-lg-none"><div class="d-flex"><button aria-label="Account Menu" class="p-0 siteHeader__HeaderStyles__iconBtn" data-test="user-profile-drawer-trigger" title="Open Account Menu" type="button"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"></path></svg></span></button><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionLeft drawer__DrawerStyles__drawerAnimation"><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><span class=""><div class="siteHeader__HeaderStyles__h1">Profile</div></span></div></div><div><div class="d-flex flex-row"><button aria-label="Close navigation menu" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" type="button"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"></path></svg></span></button></div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__drawerContent"><ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu"><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Profile" href="/member/profile/index.htm" rel="nofollow" target="_top"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"></path></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor">Profile</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Resumes" href="/member/profile/resumes.htm" rel="nofollow" target="_top"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M16 2l4 5h-3.5a.5.5 0 01-.5-.5zm-6 2.5a2 2 0 011.15 3.64 4.14 4.14 0 012.74 2.43 1 1 0 01- ...
# window.gdGlobals = window.gdGlobals || [];
# window.gdGlobals[0] = {"analyticsId":"UA-2595786-1","analyticsUrl":"/member/home","deferredScriptType":"text/x-deferred-js","locale":"en-IE","env":"prod","release":"1.14.11","appName":"site-discovery","device":{"handheld":false,"tablet":false,"deviceTypeId":1,"platformTypeId":3,"viewTypeId":4},"page":{"domain":"www.glassdoor.ie","domainId":18,"domainCountryId":70,"domainSuffix":"","projectUrlGroup":"[]","guid":"","flex":false,"section":"home","group":"Home-Member","type":"home:member","id":"home:member","med":"","src":"","content":"","campaign":"","term":"","state":"open","untranslatedUrl":"https://www.glassdoor.ie/member/home/index.htm"},"user":{"guid":"5c59e134-bcb7-4118-aa03-da5624c7bb94","locale":"en_IE","country":"","ipAddr":"190.2.138.12, 141.101.105.214,10.0.194.15, 10.0.212.112","ipLocationId":"3064478","ipLocationType":"C","id":184087058,"membershipType":"BASIC","education":"","occupation":"false","explicitLocation":"false","regDate":"20210227","regMonth":"February","profile":"false","email":"manzov.sergio@gmail.com","isValidated":true,"isContributor":true,"isMemberRoleActive":true},"test":{"planoutIdList":["site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall","site_discovery_header.exp_site_discovery_header_catchall","site_discovery_nav.site_discovery_nav_t2","site_discovery_ugc_search2.PROD_ugc_search2_v1","site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1","site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1","site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1","brand_ads_company_compare.native_ads_compare","brand_ads_company_explorer.native_ads_explore"],"planoutTreatmentList":["fishbowl_default","site_discovery_header_default","career_nav_t2","ugc_search2_t1","ugc_search2_autocomplete_t1","ugc_search2_interviews_t1","ugc_search2_salaries_t1","native_ads_compare_t1","native_ads_explore_t1"]},"job":{},"employer":{},"staticList":{},"search":{"rawKeyword":""},"vendor":{"fbReqPerms":""}};
# window.getGdGlobals = window.getGdGlobals || function () { return gdGlobals[0]; };
# window.GD = window.GD || {};
# window.GD.page = {"ENVIRONMENT":"prod-us-east-1","appleSignInClientID":"com.glassdoor.client","appleSignInEnabled":true,"branchApiKey":"key_live_ckvjcl6hamnn9htW9cXAUcdgAxgsoJtd","deferredDeeplinkEnabled":false,"deferredDeeplinkVariant":false,"dos2":{"fishbowlMemberHome":"t0","enableSameContextSearch":"true","searchBoxV1":"false","careerNav":"t2","ugcSearch2":"true","ugcSearch2_autocomplete":"true","ugcSearch2_interviews":"true","ugcSearch2_salaries":"true","nativeAdsOnCompare":"true","nativeAdsOnExplore":"true"},"fbApi":{"appId":129253937150340,"url":"https://www.glassdoor.ie/secure/crossDomain/facebookChannel.htm","requestLocale":"en-IE"},"googleAppId":"141714232794-u9pltfkeb9skmomag53kf4dt3p4mgp1a.apps.googleusercontent.com","gdpr":{"emailOptOutEnabled":1},"isHandheldDevice":false,"header":{"profilePhotoRelativeUrl":null}};
# window.GD.pageInfo = window.GD.pageInfo || {};
# window.GD.pageInfo.pageGroup = window.getGdGlobals().page.group;
# window.GD.domain = window.getGdGlobals().page.domain;
# </script><script>
# if (window.interceptGlobal) window.interceptGlobal();
# </script><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PST2JZ" style="display:none;visibility:hidden" width="0"></iframe></noscript><script nonce="">
# (function(w,d,s,l){
#     w[l]=w[l]||[];
#     w[l].push({
#         'gtm.start': new Date().getTime(),
#         event:'gtm.js'
#     });
#     var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),
#         dl=l!='dataLayer'?'&l='+l:'';
#     j.async=true;
#     j.src='//www.googletagmanager.com/gtm.js?id=GTM-PST2JZ'+dl;
#     f.parentNode.insertBefore(j,f);
# })(window,document,'script','gdGlobals');
# </script><div>
# <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react/17.0.1/umd/react.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/17.0.1/umd/react-dom.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/es6-promise/3.2.2/es6-promise.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js"></script>
# <script defer="" src="/garnish/static/js/gd-runtime.bundle.d0b3e.js"></script>
# <script defer="" src="/garnish/static/js/gd-vendor.bundle.f495b.js"></script>
# <script defer="" src="/garnish/static/js/gd-core.bundle.6354a.js"></script>
# </div><script>
# window.GD = window.GD || {}; window.GD.page = window.GD.page || {};
# window.GD.page.userAlertData = {"isEligibleForRestoreAccessAlert":false,"isEligibleForVerifyEmailAlert":false};
# window.GD.page.headerData = {"type":"hero","menu":{"userMenu":[{"id":"primarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.profile","link":"/member/profile/index.htm","target":"_top","rel":"nofollow","gaLabel":"My Profile","iconKey":"profile"},{"textKey":"site.header.resumes","link":"/member/profile/resumes.htm","target":"_top","rel":"nofollow","gaLabel":"My Resumes","iconKey":"resume"},{"textKey":"site.header.job-preferences","link":"/member/profile/preferences.htm","target":"_top","rel":"nofollow","gaLabel":"Job Preferences","iconKey":"personalizedOutline"}]},{"id":"secondarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.contributions","link":"/member/account/salaries_input.htm","target":"_top","rel":"nofollow","gaLabel":"Contributions","iconKey":"reviews"},{"textKey":"site.header.company-follows","link":"/member/account/followedCompanies_input.htm","target":"_top","rel":"nofollow","gaLabel":"Company Follows","iconKey":"save"},{"textKey":"site.header.email-alerts","link":"/member/account/emailSettings_input.htm","target":"_top","rel":"nofollow","gaLabel":"Email & Alerts","iconKey":"email"}]},{"id":"tertiarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.account","link":"/member/account/settings_input.htm","target":"_top","rel":"nofollow","gaLabel":"Account","testLabel":"account-settings","iconKey":"setting"}]}],"subUserMenu":[{"id":"subUserMenuPrimary","childNavigationLinks":[{"gaLabel":"Account","iconKey":"questionMark","link":"https://help.glassdoor.com","rel":"nofollow","target":"_blank","testLabel":"help-center","textKey":"link.label.help-center"},{"textKey":"msg.sign-out","link":"/logout.htm","gaLabel":"Sign Out","testLabel":"sign-out","iconKey":"signOut"}]}],"mainMenu":[{"textKey":"site.header.jobs","link":"/Job/jobsHomeRedirect.htm","target":"_top","gaLabel":"null","testLabel":"site-header-jobs","id":"jobs","iconKey":"jobs","childNavigationLinks":[{"textKey":"site.header.jobs.recentActivity","link":"/Job/Home/recentActivity.htm","target":"_top","gaLabel":"RecentActivity","id":"jobs_recentActivity","iconKey":"search"},{"textKey":"site.header.jobs.alerts","link":"/Job/Home/jobAlerts.htm","target":"_top","gaLabel":"Alerts","id":"jobs_jobAlerts","iconKey":"jobAlertAngled"},{"textKey":"site.header.jobs.saved","link":"/Job/Home/savedJobs.htm","target":"_top","gaLabel":"Saved","id":"jobs_savedJobs","iconKey":"save"},{"textKey":"site.header.jobs.applications","link":"/Job/Home/appliedJobs.htm","target":"_top","gaLabel":"Applications","id":"jobs_appliedJobs","iconKey":"application"}]},{"textKey":"site.header.companies","link":"/Reviews/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-companies","id":"companies","iconKey":"companies","childNavigationLinks":[{"textKey":"site.header.companies.discover","link":"/Reviews/index.htm","target":"_top","gaLabel":"Discover","id":"companies_home","iconKey":"search"},{"textKey":"site.header.companies.compare","link":"/Compare/index.htm","target":"_top","gaLabel":"Compare","id":"companies_compare","iconKey":"compare"},{"textKey":"site.header.companies.follows","link":"/follow/companySuggestions.htm","target":"_top","gaLabel":"Suggested","id":"companies_follows","iconKey":"save"},{"textKey":"site.header.companies.add","link":"/mz-survey/start_input.htm?showSurvey=REVIEWS&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"WriteReview","id":"companies_add","iconKey":"add"}]},{"textKey":"site.header.salaries","link":"/Salaries/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-salaries","id":"salaries","iconKey":"salaries","childNavigationLinks":[{"textKey":"site.header.salaries.discover","link":"/Salaries/index.htm","target":"_top","gaLabel":"Discover","id":"salaries_home","iconKey":"search"},{"textKey":"site.header.salaries.add","link":"/mz-survey/start_input.htm?showSurvey=SALARIES&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"AddSalary","id":"salaries_add","iconKey":"add"}]},{"textKey":"site.header.car ...
# window.GD.page.headerPageId = "member";
# ...
# <script id="" type="text/javascript">(function(){var k=setInterval(function(){window.gdGlobals?(clearInterval(k),q()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(k)},1E4);var q=function(){function l(){e=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/youtube.com\/embed/.test(a.src)})}function r(){var a=window.YT;"undefined"!==typeof a&&"undefined"!==typeof a.Player?(window.clearInterval(f),e.map(m),t(),console.log("~ Glassdoor video")):5>=n?n++:window.clearInterval(f)}
# function m(a){-1===a.src.indexOf("enablejsapi\x3d")&&(a.src+=(~a.src.indexOf("?")?"\x26":"?")+"enablejsapi\x3d1");var b=window.YT;b=new b.Player(a,{events:{onReady:u,onError:v}});b._asData={eventType:void 0,previousEventType:void 0,currentTime:void 0,previousTime:void 0,videoTitle:"not set",videoPlayer:"YT",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,nonInteraction:null,hitValue:0,isPlaylist:!1,nextVidClick:!1,
# adPlaying:!1,videoLoaded:!1};a=b;var c=w,d;for(d in c)a[d]=c[d];b.setListeners();g.push(b)}function u(a){a.target._asData.isPlaylist=!(0>a.target.getPlaylistIndex());a.target._vidLoaded()}function v(a){console.log("~ YT Player Error: "+a._asData)}function t(){document.addEventListener("webkitfullscreenchange",function(a){h()},!1);document.addEventListener("mozfullscreenchange",function(a){h()},!1);document.addEventListener("fullscreenchange",function(a){h()},!1)}function h(){if(document.fullscreenElement){var a=
# g.filter(function(b){return b._asData.videoSrc===document.fullscreenElement.src});a[0]._vidFullScreen()}}function x(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());if(d>b+c)for(b=d,l(),c=0;c<e.length;c++)-1===e[c].src.indexOf("enablejsapi\x3d")&&m(e[c])},3E3)}var y=
# function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"youtube",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),w={setMilestones:function(){var a=this.getVideoLength();this._asData.milestones=
# this._asData.milestones.map(function(b){return b/100*a})},setVideoTitle:function(){this._asData.videoTitle=this.getVideoTitle()},getVideoTitle:function(){var a=this._asData.videoTitle;this.playerInfo&&this.playerInfo.videoData&&this.playerInfo.videoData.title?a=this.playerInfo.videoData.title:this.getVideoData&&this.getVideoData().title&&(a=this.getVideoData().title);a!==this._asData.videoTitle&&this._asData.videoLoaded&&(this._asData.videoLoaded=!1);return a},getVideoLength:function(){return this.getDuration?
# Math.round(this.getDuration()):this.playerInfo&&this.playerInfo.duration?Math.round(this.playerInfo.duration):null},setVideoLength:function(){this._asData.videoLength=this.getVideoLength()},_getCurrentTime:function(){return this.getCurrentTime?Math.round(this.getCurrentTime()):this.playerInfo&&this.playerInfo.currentTime?Math.round(this.playerInfo.currentTime):null},isVideo:function(){return this&&"VIDEO"===this.nodeName},_vidLoaded:function(){this._asData.videoLoaded||(this.setVideoTitle(),this.setVideoLength(),
# this.setMilestones(),this._asData.videoLoaded=!0)},_vidPlay:function(a){var b=void 0===a?this:a.target;b._asData.adPlaying||b._vidLoaded();if(b._asData.adPlaying)b._asData.adPlaying=!1;else if(void 0===a&&this._asData&&"player loaded"===this._asData.eventType&&(this._asData.adPlaying=!0),"autoplay"!==b._asData.eventType&&"click to play"!==b._asData.eventType||0!==b._asData.currentTime){b.milestoneCheck&&window.clearInterval(b.milestoneCheck);b.milestoneCheck=window.setInterval(b._vidMilestones,1E3,
# a);if(b._asData.justFinished&&(b._asData.justFinished=!1,!b._asData.isPlaylist))return;a=b._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===a.length?(b._asData.firstPlay=!1,b._asData.autoplay?b._sendHit(a[1],!0):b._sendHit(a[0],!1)):b._asData.justSeeked||b._sendHit(a,!1);5<Math.abs(b._asData.currentTime-b._asData.previousTime)&&!b._asData.justFinished&&b._sendHit("seek",!1);b._asData.justSeeked=!1}},_vidPause:function(a){var b=a.target;"cued"!==b._asData.eventType&&(window.clearInterval(b.milestoneCheck),
# 5<Math.abs(b._asData.currentTime-b._asData.previousTime)?b._vidSeek(a):b._getCurrentTime()!==b._asData.videoLength&&b._sendHit("pause",!1))},_vidSeek:function(a){a=a.target;"cued"!==a._asData.eventType&&(a._asData.adPlaying||a._asData.justFinished||0===a._asData.currentTime&&(0===a._asData.milestones.length||3===a._asData.milestones.length)||a._asData.justSeeked||a._asData.firstPlay||a._asData.justFinished||a._sendHit("seek",!1),a._asData.justSeeked=!0)},_vidComplete:function(a){a=a.target;if(0<a._asData.milestones.length)for(var b=
# 0;b<a._asData.milestones.length;b++){var c=a._asData.milestones[b];c=c/a._asData.videoLength*100;!Number.isNaN(c)&&0===c%25&&0<c&&100>=c&&(a._asData.hitValue=c,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+c+"%")),!0))}a._asData.justFinished||(a._asData.adPlaying=!1,window.clearInterval(a.milestoneCheck),a._asData.hitValue=100,a._sendHit("complete",!0),a._asData.firstPlay=!0,a._asData.justFinished=!0,a._asData.milestones=[25,50,75],a._asData.isPlaylist?a._asData.finalPlaylistVid||
# (b=a.getPlaylistIndex(),c=a.getPlaylist().length,b+1===c&&(a._asData.finalPlaylistVid=!0),a._asData.autoplay=!0,a._asData.videoLoaded=!1,a._vidLoaded()):(a._asData.autoplay=!1,a.setVideoLength(),a.setMilestones()))},_vidMilestones:function(a){if(void 0!==a){a=a.target;var b=a._getCurrentTime();a._asData.previousTime=b;if(!(b<a._asData.milestones[0])){0===a._asData.milestones.length&&window.clearInterval(a.milestoneCheck);do{var c=a._asData.milestones.splice(0,1)[0];a._asData.firstPlay&&(a._sendHit("autoplay",
# !0),a._asData.firstPlay=!1)}while(c>b);b=c/a._asData.videoLength*100;!Number.isNaN(b)&&0===b%25&&0<b&&100>=b&&(a._asData.hitValue=b,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}}},_vidMuted:function(){if(this.isMuted)if(this.isMuted())this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=!1;else return;else if(this.playerInfo)if(this.playerInfo.muted)this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=
# !1;else return;this._asData.currentTime=this._getCurrentTime();void 0===this._asData.currentTime||1>this._asData.currentTime||(this._asData.justMuted?this._sendHit("mute",!1):this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.previousEventType=this._asData.eventType;this._asData.eventType=a;this._asData.hitValue=
# a.match(/milestone|complete/i)?this._asData.hitValue:null;this._asData.nonInteraction=b;y(this._asData)},setListeners:function(){this.addEventListener("onStateChange",function(a){if(-1===a.data){if("cued"===a.target._asData.eventType)return;if("player loaded"===a.target._asData.eventType){a.target._vidPlay(a);return}if(a.target._asData.videoTitle!==a.target.getVideoTitle()){a.target._asData.milestones=[25,50,75];a.target._asData.autoplay=!1;a.target._asData.firstPlay=!0;a.target._asData.videoLoaded=
# !1;a.target._asData.adPlaying=!1;a.target._vidLoaded();return}}if(5===a.data)a.target._asData.milestones=[25,50,75],a.target._asData.autoplay=!1,a.target._asData.firstPlay=!0,a.target._asData.videoLoaded=!1,a.target._asData.adPlaying=!1,a.target._asData.eventType="cued",a.target._asData.videoTitle="not set";else{a.target._asData.currentTime=a.target._getCurrentTime();var b=[a.target._vidComplete,a.target._vidPlay,a.target._vidPause,a.target._vidSeek];(b=b[a.data]||void 0)&&b(a);a.target._asData.previousTime=
# a.target._asData.currentTime}},!0);this.addEventListener("onVolumeChange",function(a){a=a.target;a._vidMuted()},!0)}},g=[];window._asVideos=g;var f,n=0,e,p=setInterval(function(){l();if(0<e.length){clearInterval(p);var a=window.YT;if(0<e.length){a="undefined"!==typeof a&&"undefined"!==typeof a.Player;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="//www.youtube.com/iframe_api";b.parentNode.insertBefore(a,b)}f=window.setInterval(r,
# 1E3)}}},500);setTimeout(function(){clearInterval(p)},1E4);setTimeout(function(){x()},5E3)}})();</script>
# <script id="" type="text/javascript">(function(){var l=setInterval(function(){window.gdGlobals?(clearInterval(l),r()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(l)},1E4);var r=function(){function m(){g=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/player.vimeo.com/.test(a.src)})}function t(){var a=window.Vimeo;"undefined"!==typeof a?(window.clearInterval(h),g.map(n)):5>p?p++:window.clearInterval(h)}function n(a){var b=window.Vimeo;b=new b.Player(a);b._asData=
# {eventType:void 0,videoTitle:"not set",videoPlayer:"Vimeo_iframe",videoLength:"not set",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,vidLoaded:!1,nonInteraction:null,hitValue:0};var c=b,d=u,f;for(f in d)c[f]=d[f];b.setListeners();v.push(b);b._vidLoaded();a._asProcessed=!0}function w(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),
# Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());d>b+c&&(b=d,m(),g.map(function(f){f._asProcessed||n(f)}))},3E3)}var x=function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"vimeo",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,
# videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),u={setMilestones:function(){var a=this,b=window.setInterval(function(){var c=a._asData.videoLength;"not set"!==c&&(a._asData.milestones=a._asData.milestones.map(function(d){return d/100*c}),window.clearInterval(b))},200,a)},setVideoTitle:function(){var a=this;this.getVideoTitle().then(function(b){a._asData.videoTitle=b})},replayOrNewVid:function(){var a=this;this._asData.milestones=
# [25,50,75];this.getVideoTitle().then(function(b){a._asData.videoTitle===b?(a._asData.justFinished=!1,a.setMilestones()):a._vidLoaded();a._vidPlay()})},setVideoLength:function(){var a=this;this.getDuration().then(function(b){a._asData.videoLength=Math.round(b)})},_asGetCurrentTime:function(){var a=this;this.getCurrentTime().then(function(b){a._asData.currentTime=b})},_vidLoaded:function(){var a=this;this.setVideoTitle();this.setVideoLength();this.setMilestones();this.getVolume().then(function(c){0===
# c&&(a._asData.justMuted=!0)});var b=setInterval(function(){"not set"!==a._asData.videoTitle&&clearInterval(b)},75);this._asData.justFinished=!1;this._asData.vidLoaded=!0},_vidPlay:function(){if(!e){var a=this;window.setTimeout(function(){if(!e)if(a._asData.justFinished&&a._asData.firstPlay)a.replayOrNewVid();else{var b=a._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===b.length?(a._asData.firstPlay=!1,a._asData.autoplay?a._sendHit(b[1],!0):a._sendHit(b[0],!1)):a._sendHit(b,!1)}},
# 1E3,a)}},_vidPause:function(){var a=this;a._asData.justFinished||e||window.setTimeout(function(){a._asData.justFinished||e||a.getCurrentTime()!==a._asData.videoLength&&a._sendHit("pause",!1)},1E3,a)},_vidSeek:function(){e||this._asData.justFinished||(e=!0,this._sendHit("seek",!1),window.setTimeout(function(){e=!1},2E3))},_vidComplete:function(){if(0<this._asData.milestones.length)for(var a=0;a<this._asData.milestones.length;a++){var b=this._asData.milestones[a];b=b/this._asData.videoLength*100;!Number.isNaN(b)&&
# 0===b%25&&0<b&&100>=b&&(this._asData.hitValue=b,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}this._asData.hitValue=100;this._sendHit("complete",!0);this._asData.firstPlay=!0;this._asData.justFinished=!0;this._asData.autoplay=!1},_vidMilestones:function(a){this._asData.currentTime=a.seconds;if(!(k||(k=!0,window.setTimeout(function(){k=!1},2E3),this._asData.firstPlay&&3<a.seconds&&this._vidPlay(),a.seconds<this._asData.milestones[0]||0===this._asData.milestones.length))){a=
# a.seconds;do var b=this._asData.milestones.splice(0,1)[0];while(b>a);a=b/this._asData.videoLength*100;!Number.isNaN(a)&&0===a%25&&0<a&&100>=a&&(this._asData.hitValue=a,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+a+"%")),!0))}},_vidMuted:function(a){!1===this._asData.justMuted&&0===a.volume?(this._asData.justMuted=!0,this._sendHit("mute",!1)):this._asData.justMuted&&0<a.volume&&(this._asData.justMuted=!1,this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||
# document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.eventType=a;this._asData.nonInteraction=b;this._asData.hitValue=a.match(/milestone|complete/i)?this._asData.hitValue:null;x(this._asData)},setListeners:function(){this.on("play",function(){this._vidPlay()},!0);this.on("pause",function(){this._vidPause()},!0);this.on("seeked",function(){this._vidSeek()},!0);this.on("ended",function(){this._vidComplete()},
# !0);this.on("timeupdate",function(a){this._vidMilestones(a)},!0);this.on("volumechange",function(a){this._vidMuted(a)},!0);this.on("fullscreenchange",function(){this._vidFullScreen()},!0);this.on("webkitfullscreenchange",function(){this._vidFullScreen()},!0);this.on("mozfullscreenchange",function(){this._vidFullScreen()},!0);this.on("msfullscreenchange",function(){this._vidFullScreen()},!0)}},v=[],h,p=0,g,e=!1,k=!1,q=setInterval(function(){m();if(0<g.length){clearInterval(q);var a=window.Vimeo;if(0<
# g.length){a="undefined"!==typeof a;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="https://player.vimeo.com/api/player.js";b.parentNode.insertBefore(a,b)}h=window.setInterval(t,1E3)}}},500);setTimeout(function(){clearInterval(q)},1E4);setTimeout(function(){w()},5E3)}})();</script></body></html>

# %%
"""
# Get data for every city in the list
maindf= pd.DataFrame()
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']



for city in cities:
    
    if cities.index(city) == 0:
        
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        soup = BeautifulSoup(html)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys =citydetail[0]["value"]
        position_summary_detail.append(citys)

        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        position = positiondetail[0].text
        position_summary_detail.append(position)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)

        #Dataframe creation
        position_summary_detail_df = pd.DataFrame(np.array(position_summary_detail).reshape(-1,len(position_summary_detail)))
        position_summary_detail_df.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
        position_summary_detail_df
        maindf = pd.concat([maindf,position_summary_detail_df])

    else:
        
        print("no paso")
    
maindf    
    
    
    
    
"""

# %%
#Get position 
soup.find_all('h1', {'class':'m-0 css-1837fe'})

# %%
updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
updatedatedetail

# %%
soup
# Out:
# <html lang="en" style="height: 100%;" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="/manifest.json" rel="manifest"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://www.facebook.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://cdnjs.cloudflare.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6uyw4BMUTPHjx4wXiWtFCc.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="true" href="https://fonts.gstatic.com/s/lato/v17/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2" rel="preload" type="font/woff2"/><link href="/garnish/static/css/gd-core.bundle.8c00c.css" rel="stylesheet"/><link href="/garnish/static/css/gd-footer.bundle.0c586.css" rel="stylesheet"/><link href="/garnish/static/css/gd-siteHeader.bundle.eacd4.css" rel="stylesheet"/><title>Glassdoor Job Search | Find the job that fits your life</title><meta content="Search millions of jobs and get the inside scoop on companies with employee reviews, personalised salary tools, and more. Hiring? Post a job for free." data-rh="true" name="description"/><meta content="noindex" data-rh="true" name="robots"/><style data-emotion-css="j7qwjs">.css-j7qwjs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><style data-emotion-css="1q3ssei">.css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}</style><style data-emotion-css="eyudwk">.css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}</style><style data-emotion-css="5j38mw">.css-5j38mw{font-size:15px;background-color:#fff;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;color:#858c94;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-5j38mw:hover{border-color:#858c94;color:#505863;}.css-5j38mw::-webkit-input-placeholder{color:#c4c7cc;}.css-5j38mw::-moz-placeholder{color:#c4c7cc;}.css-5j38mw:-ms-input-placeholder{color:#c4c7cc;}.css-5j38mw::placeholder{color:#c4c7cc;}.css-5j38mw:focus,.css-5j38mw:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7 ...
# #onetrust-banner-sdk,#onetrust-pc-sdk,#ot-sdk-cookie-policy,#ot-sync-ntfy{font-size:16px}#onetrust-banner-sdk *,#onetrust-banner-sdk ::after,#onetrust-banner-sdk ::before,#onetrust-pc-sdk *,#onetrust-pc-sdk ::after,#onetrust-pc-sdk ::before,#ot-sdk-cookie-policy *,#ot-sdk-cookie-policy ::after,#ot-sdk-cookie-policy ::before,#ot-sync-ntfy *,#ot-sync-ntfy ::after,#ot-sync-ntfy ::before{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}#onetrust-banner-sdk div,#onetrust-banner-sdk span,#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-banner-sdk p,#onetrust-banner-sdk img,#onetrust-banner-sdk svg,#onetrust-banner-sdk button,#onetrust-banner-sdk section,#onetrust-banner-sdk a,#onetrust-banner-sdk label,#onetrust-banner-sdk input,#onetrust-banner-sdk ul,#onetrust-banner-sdk li,#onetrust-banner-sdk nav,#onetrust-banner-sdk table,#onetrust-banner-sdk thead,#onetrust-banner-sdk tr,#onetrust-banner-sdk td,#onetrust-banner-sdk tbody,#onetrust-banner-sdk .ot-main-content,#onetrust-banner-sdk .ot-toggle,#onetrust-banner-sdk #ot-content,#onetrust-banner-sdk #ot-pc-content,#onetrust-banner-sdk .checkbox,#onetrust-pc-sdk div,#onetrust-pc-sdk span,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#onetrust-pc-sdk p,#onetrust-pc-sdk img,#onetrust-pc-sdk svg,#onetrust-pc-sdk button,#onetrust-pc-sdk section,#onetrust-pc-sdk a,#onetrust-pc-sdk label,#onetrust-pc-sdk input,#onetrust-pc-sdk ul,#onetrust-pc-sdk li,#onetrust-pc-sdk nav,#onetrust-pc-sdk table,#onetrust-pc-sdk thead,#onetrust-pc-sdk tr,#onetrust-pc-sdk td,#onetrust-pc-sdk tbody,#onetrust-pc-sdk .ot-main-content,#onetrust-pc-sdk .ot-toggle,#onetrust-pc-sdk #ot-content,#onetrust-pc-sdk #ot-pc-content,#onetrust-pc-sdk .checkbox,#ot-sdk-cookie-policy div,#ot-sdk-cookie-policy span,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy p,#ot-sdk-cookie-policy img,#ot-sdk-cookie-policy svg,#ot-sdk-cookie-policy button,#ot-sdk-cookie-policy section,#ot-sdk-cookie-policy a,#ot-sdk-cookie-policy label,#ot-sdk-cookie-policy input,#ot-sdk-cookie-policy ul,#ot-sdk-cookie-policy li,#ot-sdk-cookie-policy nav,#ot-sdk-cookie-policy table,#ot-sdk-cookie-policy thead,#ot-sdk-cookie-policy tr,#ot-sdk-cookie-policy td,#ot-sdk-cookie-policy tbody,#ot-sdk-cookie-policy .ot-main-content,#ot-sdk-cookie-policy .ot-toggle,#ot-sdk-cookie-policy #ot-content,#ot-sdk-cookie-policy #ot-pc-content,#ot-sdk-cookie-policy .checkbox,#ot-sync-ntfy div,#ot-sync-ntfy span,#ot-sync-ntfy h1,#ot-sync-ntfy h2,#ot-sync-ntfy h3,#ot-sync-ntfy h4,#ot-sync-ntfy h5,#ot-sync-ntfy h6,#ot-sync-ntfy p,#ot-sync-ntfy img,#ot-sync-ntfy svg,#ot-sync-ntfy button,#ot-sync-ntfy section,#ot-sync-ntfy a,#ot-sync-ntfy label,#ot-sync-ntfy input,#ot-sync-ntfy ul,#ot-sync-ntfy li,#ot-sync-ntfy nav,#ot-sync-ntfy table,#ot-sync-ntfy thead,#ot-sync-ntfy tr,#ot-sync-ntfy td,#ot-sync-ntfy tbody,#ot-sync-ntfy .ot-main-content,#ot-sync-ntfy .ot-toggle,#ot-sync-ntfy #ot-content,#ot-sync-ntfy #ot-pc-content,#ot-sync-ntfy .checkbox{font-family:inherit;font-weight:normal;-webkit-font-smoothing:auto;letter-spacing:normal;line-height:normal;padding:0;margin:0;height:auto;min-height:0;max-height:none;width:auto;min-width:0;max-width:none;border-radius:0;border:none;clear:none;float:none;position:static;bottom:auto;left:auto;right:auto;top:auto;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;white-space:normal;background:none;overflow:visible;vertical-align:baseline;visibility:visible;z-index:auto;box-shadow:none}#onetrust-banner-sdk label:before,#onetrust-banner-sdk label:after,#onetrust-banner-sdk .checkbox:after,#onetrust-banner-sdk .checkbox:before,#onetrust-pc-sdk label:before,#onetrust-pc-sdk label:afte ...
# #onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{position:relative;width:100%;max-width:100%;margin:0 auto;padding:0 20px;box-sizing:border-box}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{width:100%;float:left;box-sizing:border-box;padding:0;display:initial}@media (min-width: 400px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:90%;padding:0}}@media (min-width: 550px){#onetrust-banner-sdk .ot-sdk-container,#onetrust-pc-sdk .ot-sdk-container,#ot-sdk-cookie-policy .ot-sdk-container{width:100%}#onetrust-banner-sdk .ot-sdk-column,#onetrust-banner-sdk .ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-column,#onetrust-pc-sdk .ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-column,#ot-sdk-cookie-policy .ot-sdk-columns{margin-left:4%}#onetrust-banner-sdk .ot-sdk-column:first-child,#onetrust-banner-sdk .ot-sdk-columns:first-child,#onetrust-pc-sdk .ot-sdk-column:first-child,#onetrust-pc-sdk .ot-sdk-columns:first-child,#ot-sdk-cookie-policy .ot-sdk-column:first-child,#ot-sdk-cookie-policy .ot-sdk-columns:first-child{margin-left:0}#onetrust-banner-sdk .ot-sdk-two.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-two.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-two.ot-sdk-columns{width:13.3333333333%}#onetrust-banner-sdk .ot-sdk-three.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-three.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-three.ot-sdk-columns{width:22%}#onetrust-banner-sdk .ot-sdk-four.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-four.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-four.ot-sdk-columns{width:30.6666666667%}#onetrust-banner-sdk .ot-sdk-eight.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eight.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eight.ot-sdk-columns{width:65.3333333333%}#onetrust-banner-sdk .ot-sdk-nine.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-nine.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-nine.ot-sdk-columns{width:74%}#onetrust-banner-sdk .ot-sdk-ten.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-ten.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-ten.ot-sdk-columns{width:82.6666666667%}#onetrust-banner-sdk .ot-sdk-eleven.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-eleven.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-eleven.ot-sdk-columns{width:91.3333333333%}#onetrust-banner-sdk .ot-sdk-twelve.ot-sdk-columns,#onetrust-pc-sdk .ot-sdk-twelve.ot-sdk-columns,#ot-sdk-cookie-policy .ot-sdk-twelve.ot-sdk-columns{width:100%;margin-left:0}}#onetrust-banner-sdk h1,#onetrust-banner-sdk h2,#onetrust-banner-sdk h3,#onetrust-banner-sdk h4,#onetrust-banner-sdk h5,#onetrust-banner-sdk h6,#onetrust-pc-sdk h1,#onetrust-pc-sdk h2,#onetrust-pc-sdk h3,#onetrust-pc-sdk h4,#onetrust-pc-sdk h5,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h1,#ot-sdk-cookie-policy h2,#ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy h5,#ot-sdk-cookie-policy h6{margin-top:0;font-weight:600;font-family:inherit}#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem;line-height:1.2}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem;line-height:1.25}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size:1.5rem;line-height:1.3}#onetrust-banner-sdk h4,#onetrust-pc-sdk h4,#ot-sdk-cookie-policy h4{font-size:1.5rem;line-height:1.35}#onetrust-banner-sdk h5,#onetrust-pc-sdk h5,#ot-sdk-cookie-policy h5{font-size:1.5rem;line-height:1.5}#onetrust-banner-sdk h6,#onetrust-pc-sdk h6,#ot-sdk-cookie-policy h6{font-size:1.5rem;line-height:1.6}@media (min-width: 550px){#onetrust-banner-sdk h1,#onetrust-pc-sdk h1,#ot-sdk-cookie-policy h1{font-size:1.5rem}#onetrust-banner-sdk h2,#onetrust-pc-sdk h2,#ot-sdk-cookie-policy h2{font-size:1.5rem}#onetrust-banner-sdk h3,#onetrust-pc-sdk h3,#ot-sdk-cookie-policy h3{font-size: ...
# #onetrust-banner-sdk{box-shadow:0 0 18px rgba(0,0,0,.2)}#onetrust-banner-sdk.otFlat{position:fixed;z-index:2147483645;bottom:0;right:0;left:0;background-color:#fff;max-height:90%;overflow-x:hidden;overflow-y:auto}#onetrust-banner-sdk.otFlat.top{top:0px;bottom:auto}#onetrust-banner-sdk.otRelFont{font-size:1rem}#onetrust-banner-sdk>.ot-sdk-container{overflow:hidden}#onetrust-banner-sdk::-webkit-scrollbar{width:11px}#onetrust-banner-sdk::-webkit-scrollbar-thumb{border-radius:10px;background:#c1c1c1}#onetrust-banner-sdk{scrollbar-arrow-color:#c1c1c1;scrollbar-darkshadow-color:#c1c1c1;scrollbar-face-color:#c1c1c1;scrollbar-shadow-color:#c1c1c1}#onetrust-banner-sdk #onetrust-policy{margin:1.25em 0 .625em 2em;overflow:hidden}#onetrust-banner-sdk #onetrust-policy .ot-gv-list-handler{float:left;font-size:.82em;padding:0;margin-bottom:0;border:0;line-height:normal;height:auto;width:auto}#onetrust-banner-sdk #onetrust-policy-title{font-size:1.2em;line-height:1.3;margin-bottom:10px}#onetrust-banner-sdk #onetrust-policy-text{clear:both;text-align:left;font-size:.88em;line-height:1.4}#onetrust-banner-sdk #onetrust-policy-text *{font-size:inherit;line-height:inherit}#onetrust-banner-sdk #onetrust-policy-text a{font-weight:bold;margin-left:5px}#onetrust-banner-sdk #onetrust-policy-title,#onetrust-banner-sdk #onetrust-policy-text{color:dimgray;float:left}#onetrust-banner-sdk #onetrust-button-group-parent{min-height:1px;text-align:center}#onetrust-banner-sdk #onetrust-button-group{display:inline-block}#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-pc-btn-handler{background-color:#68b631;color:#fff;border-color:#68b631;margin-right:1em;min-width:125px;height:auto;white-space:normal;word-break:break-word;word-wrap:break-word;padding:12px 10px;line-height:1.2;font-size:.813em;font-weight:600}#onetrust-banner-sdk #onetrust-pc-btn-handler.cookie-setting-link{background-color:#fff;border:none;color:#68b631;text-decoration:underline;padding-left:0;padding-right:0}#onetrust-banner-sdk .onetrust-close-btn-ui{width:44px;height:44px;background-size:12px;border:none;position:relative;margin:auto;padding:0}#onetrust-banner-sdk .banner_logo{display:none}#onetrust-banner-sdk .ot-b-addl-desc{clear:both;float:left;display:block}#onetrust-banner-sdk #banner-options{float:left;display:table;margin-right:0;margin-left:1em;width:calc(100% - 1em)}#onetrust-banner-sdk .banner-option-input{cursor:pointer;width:auto;height:auto;border:none;padding:0;padding-right:3px;margin:0 0 10px;font-size:.82em;line-height:1.4}#onetrust-banner-sdk .banner-option-input *{pointer-events:none;font-size:inherit;line-height:inherit}#onetrust-banner-sdk .banner-option-input[aria-expanded=true]~.banner-option-details{display:block;height:auto}#onetrust-banner-sdk .banner-option-input[aria-expanded=true] .ot-arrow-container{transform:rotate(90deg)}#onetrust-banner-sdk .banner-option{margin-bottom:12px;margin-left:0;border:none;float:left;padding:0}#onetrust-banner-sdk .banner-option:first-child{padding-left:2px}#onetrust-banner-sdk .banner-option:not(:first-child){padding:0;border:none}#onetrust-banner-sdk .banner-option-header{cursor:pointer;display:inline-block}#onetrust-banner-sdk .banner-option-header :first-child{color:dimgray;font-weight:bold;float:left}#onetrust-banner-sdk .banner-option-header .ot-arrow-container{display:inline-block;border-top:6px solid transparent;border-bottom:6px solid transparent;border-left:6px solid dimgray;margin-left:10px;vertical-align:middle}#onetrust-banner-sdk .banner-option-details{display:none;font-size:.83em;line-height:1.5;padding:10px 0px 5px 10px;margin-right:10px;height:0px}#onetrust-banner-sdk .banner-option-details *{font-size:inherit;line-height:inherit;color:dimgray}#onetrust-banner-sdk .ot-arrow-container,#onetrust-banner-sdk .banner-option-details{transition:all 300ms ease-in 0s;-webkit-transition:all 300ms ease-in 0s;-moz-transition:all 300ms ease-in 0s;-o ...
#         #onetrust-consent-sdk #onetrust-banner-sdk {background-color: #FFFFFF;}
#             #onetrust-consent-sdk #onetrust-policy-title,
#                     #onetrust-consent-sdk #onetrust-policy-text,
#                     #onetrust-consent-sdk .ot-b-addl-desc,
#                     #onetrust-consent-sdk .ot-dpd-desc,
#                     #onetrust-consent-sdk .ot-dpd-title,
#                     #onetrust-consent-sdk #onetrust-policy-text *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk .ot-dpd-desc *:not(.onetrust-vendors-list-handler),
#                     #onetrust-consent-sdk #onetrust-banner-sdk #banner-options *,
#                     #onetrust-banner-sdk .ot-cat-header {
#                         color: #505863;
#                     }
#             #onetrust-consent-sdk #onetrust-banner-sdk .banner-option-details {
#                     background-color: #E9E9E9;}
#              #onetrust-consent-sdk #onetrust-banner-sdk a[href],
#                     #onetrust-consent-sdk #onetrust-banner-sdk a[href] font,
#                     #onetrust-consent-sdk #onetrust-banner-sdk .ot-link-btn
#                         {
#                             color: #3860BE;
#                         }#onetrust-consent-sdk #onetrust-accept-btn-handler,
#                          #onetrust-banner-sdk #onetrust-reject-all-handler {
#                             background-color: #1861BF;border-color: #1861BF;
#                 color: #FFFFFF;
#             }
#             #onetrust-consent-sdk #onetrust-banner-sdk *:focus,
#             #onetrust-consent-sdk #onetrust-banner-sdk:focus {
#                outline-color: #000000;
#                outline-width: 1px;
#             }
#             #onetrust-consent-sdk #onetrust-pc-btn-handler,
#             #onetrust-consent-sdk #onetrust-pc-btn-handler.cookie-setting-link {
#                 color: #0caa41; border-color: #0caa41;
#                 background-color:
#                 #FFFFFF;
#             }#onetrust-banner-sdk {
#     box-shadow: 0px 0px 2px #c4c7cc;
# }.ot-sdk-cookie-policy{font-family:inherit;font-size:16px}.ot-sdk-cookie-policy.otRelFont{font-size:1rem}.ot-sdk-cookie-policy h3,.ot-sdk-cookie-policy h4,.ot-sdk-cookie-policy h6,.ot-sdk-cookie-policy p,.ot-sdk-cookie-policy li,.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy th,.ot-sdk-cookie-policy #cookie-policy-description,.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}.ot-sdk-cookie-policy h4{font-size:1.2em}.ot-sdk-cookie-policy h6{font-size:1em;margin-top:2em}.ot-sdk-cookie-policy th{min-width:75px}.ot-sdk-cookie-policy a,.ot-sdk-cookie-policy a:hover{background:#fff}.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}.ot-sdk-cookie-policy .ot-mobile-border{display:none}.ot-sdk-cookie-policy section{margin-bottom:2em}.ot-sdk-cookie-policy table{border-collapse:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy{font-family:inherit;font-size:1rem}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h3,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h4,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title{color:dimgray}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup{margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group-desc,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-table-header,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td{font-size:.9em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td span,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td a{font-size:inherit}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group{font-size:1em;margin-bottom:.6em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-title{margin-bottom:1.2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy>section{margin-bottom:1em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th{min-width:75px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a:hover{background:#fff}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy thead{background-color:#f6f6f4;font-weight:bold}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-mobile-border{display:none}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy section{margin-bottom:2em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li{list-style:disc;margin-left:1.5em}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-subgroup ul li h4{display:inline-block}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table{border-collapse:inherit;margin:auto;border:1px solid #d7d7d7;border-radius:5px;border-spacing:initial;width:100%;overflow:hidden}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table td{border-bottom:1px solid #d7d7d7;border-right:1px solid #d7d7d7}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr:last-child td{border-bottom:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr th:last-child,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table tr td:last-child{border-right:0px}#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-host,#ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table .ot-cookies-type{width:25%}.ot-sdk-cookie-policy[dir=rtl]{text-align:left}#ot-sdk-cookie-policy h3{font-size:1.5em}@media only screen and (max-wi ...
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h5,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy h6,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy li,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy p,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy a,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy span,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy td,
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-description {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy th {
#                         color: #696969;
#                     }
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy .ot-sdk-cookie-policy-group {
#                         color: #696969;
#                     }
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy #cookie-policy-title {
#                             color: #696969;
#                         }
#
#
#                     #ot-sdk-cookie-policy-v2.ot-sdk-cookie-policy table th {
#                             background-color: #F8F8F8;
#                         }
#
#
#                       @keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       @-webkit-keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       @-moz-keyframes slide-down-custom {
#                           0% {
#                               bottom: 707px !important;
#                           }
#                           100% {
#                               bottom: 0px;
#                           }
#                       }
#                       </style><style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes slideInFromBottomDelay{0%{opacity:0;transform:translateY(100%)}97%{opacity:0;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}</style></head><body class="main loggedIn lang-en en-IE gdGrid _initOk" data-locale="en-IE" marginheight="0" marginwidth="0">
# <!--<decorator:body/> -->
# <div id="UserAlert"></div><header id="SiteNav"><nav class="d-flex align-items-center siteHeader__HeaderStyles__navigationBackground siteHeader__HeaderStyles__relativePosition" data-test="background-header-nav"><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="siteHeader__HeaderStyles__navigationWrapper"><div class="d-flex justify-content-between align-items-center px-std px-md-lg siteHeader__HeaderStyles__mainNav"><div class="d-flex d-lg-none"><div class="d-flex"><button aria-label="Account Menu" class="p-0 siteHeader__HeaderStyles__iconBtn" data-test="user-profile-drawer-trigger" title="Open Account Menu" type="button"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"></path></svg></span></button><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionLeft drawer__DrawerStyles__drawerAnimation"><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><span class=""><div class="siteHeader__HeaderStyles__h1">Profile</div></span></div></div><div><div class="d-flex flex-row"><button aria-label="Close navigation menu" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" type="button"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"></path></svg></span></button></div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__drawerContent"><ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu"><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Profile" href="/member/profile/index.htm" rel="nofollow" target="_top"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"></path></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor">Profile</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect header-menu-item" data-ga-lbl="My Resumes" href="/member/profile/resumes.htm" rel="nofollow" target="_top"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" height="24" style="width: 24px;height: 24px;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M16 2l4 5h-3.5a.5.5 0 01-.5-.5zm-6 2.5a2 2 0 011.15 3.64 4.14 4.14 0 012.74 2.43 1 1 0 01- ...
# window.gdGlobals = window.gdGlobals || [];
# window.gdGlobals[0] = {"analyticsId":"UA-2595786-1","analyticsUrl":"/member/home","deferredScriptType":"text/x-deferred-js","locale":"en-IE","env":"prod","release":"1.14.11","appName":"site-discovery","device":{"handheld":false,"tablet":false,"deviceTypeId":1,"platformTypeId":3,"viewTypeId":4},"page":{"domain":"www.glassdoor.ie","domainId":18,"domainCountryId":70,"domainSuffix":"","projectUrlGroup":"[]","guid":"","flex":false,"section":"home","group":"Home-Member","type":"home:member","id":"home:member","med":"","src":"","content":"","campaign":"","term":"","state":"open","untranslatedUrl":"https://www.glassdoor.ie/member/home/index.htm"},"user":{"guid":"5c59e134-bcb7-4118-aa03-da5624c7bb94","locale":"en_IE","country":"","ipAddr":"190.2.138.12, 141.101.105.214,10.0.194.15, 10.0.212.112","ipLocationId":"3064478","ipLocationType":"C","id":184087058,"membershipType":"BASIC","education":"","occupation":"false","explicitLocation":"false","regDate":"20210227","regMonth":"February","profile":"false","email":"manzov.sergio@gmail.com","isValidated":true,"isContributor":true,"isMemberRoleActive":true},"test":{"planoutIdList":["site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall","site_discovery_header.exp_site_discovery_header_catchall","site_discovery_nav.site_discovery_nav_t2","site_discovery_ugc_search2.PROD_ugc_search2_v1","site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1","site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1","site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1","brand_ads_company_compare.native_ads_compare","brand_ads_company_explorer.native_ads_explore"],"planoutTreatmentList":["fishbowl_default","site_discovery_header_default","career_nav_t2","ugc_search2_t1","ugc_search2_autocomplete_t1","ugc_search2_interviews_t1","ugc_search2_salaries_t1","native_ads_compare_t1","native_ads_explore_t1"]},"job":{},"employer":{},"staticList":{},"search":{"rawKeyword":""},"vendor":{"fbReqPerms":""}};
# window.getGdGlobals = window.getGdGlobals || function () { return gdGlobals[0]; };
# window.GD = window.GD || {};
# window.GD.page = {"ENVIRONMENT":"prod-us-east-1","appleSignInClientID":"com.glassdoor.client","appleSignInEnabled":true,"branchApiKey":"key_live_ckvjcl6hamnn9htW9cXAUcdgAxgsoJtd","deferredDeeplinkEnabled":false,"deferredDeeplinkVariant":false,"dos2":{"fishbowlMemberHome":"t0","enableSameContextSearch":"true","searchBoxV1":"false","careerNav":"t2","ugcSearch2":"true","ugcSearch2_autocomplete":"true","ugcSearch2_interviews":"true","ugcSearch2_salaries":"true","nativeAdsOnCompare":"true","nativeAdsOnExplore":"true"},"fbApi":{"appId":129253937150340,"url":"https://www.glassdoor.ie/secure/crossDomain/facebookChannel.htm","requestLocale":"en-IE"},"googleAppId":"141714232794-u9pltfkeb9skmomag53kf4dt3p4mgp1a.apps.googleusercontent.com","gdpr":{"emailOptOutEnabled":1},"isHandheldDevice":false,"header":{"profilePhotoRelativeUrl":null}};
# window.GD.pageInfo = window.GD.pageInfo || {};
# window.GD.pageInfo.pageGroup = window.getGdGlobals().page.group;
# window.GD.domain = window.getGdGlobals().page.domain;
# </script><script>
# if (window.interceptGlobal) window.interceptGlobal();
# </script><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PST2JZ" style="display:none;visibility:hidden" width="0"></iframe></noscript><script nonce="">
# (function(w,d,s,l){
#     w[l]=w[l]||[];
#     w[l].push({
#         'gtm.start': new Date().getTime(),
#         event:'gtm.js'
#     });
#     var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),
#         dl=l!='dataLayer'?'&l='+l:'';
#     j.async=true;
#     j.src='//www.googletagmanager.com/gtm.js?id=GTM-PST2JZ'+dl;
#     f.parentNode.insertBefore(j,f);
# })(window,document,'script','gdGlobals');
# </script><div>
# <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react/17.0.1/umd/react.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/17.0.1/umd/react-dom.production.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/es6-promise/3.2.2/es6-promise.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js"></script>
# <script defer="" src="/garnish/static/js/gd-runtime.bundle.d0b3e.js"></script>
# <script defer="" src="/garnish/static/js/gd-vendor.bundle.f495b.js"></script>
# <script defer="" src="/garnish/static/js/gd-core.bundle.6354a.js"></script>
# </div><script>
# window.GD = window.GD || {}; window.GD.page = window.GD.page || {};
# window.GD.page.userAlertData = {"isEligibleForRestoreAccessAlert":false,"isEligibleForVerifyEmailAlert":false};
# window.GD.page.headerData = {"type":"hero","menu":{"userMenu":[{"id":"primarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.profile","link":"/member/profile/index.htm","target":"_top","rel":"nofollow","gaLabel":"My Profile","iconKey":"profile"},{"textKey":"site.header.resumes","link":"/member/profile/resumes.htm","target":"_top","rel":"nofollow","gaLabel":"My Resumes","iconKey":"resume"},{"textKey":"site.header.job-preferences","link":"/member/profile/preferences.htm","target":"_top","rel":"nofollow","gaLabel":"Job Preferences","iconKey":"personalizedOutline"}]},{"id":"secondarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.contributions","link":"/member/account/salaries_input.htm","target":"_top","rel":"nofollow","gaLabel":"Contributions","iconKey":"reviews"},{"textKey":"site.header.company-follows","link":"/member/account/followedCompanies_input.htm","target":"_top","rel":"nofollow","gaLabel":"Company Follows","iconKey":"save"},{"textKey":"site.header.email-alerts","link":"/member/account/emailSettings_input.htm","target":"_top","rel":"nofollow","gaLabel":"Email & Alerts","iconKey":"email"}]},{"id":"tertiarySignedInUserMenu","childNavigationLinks":[{"textKey":"site.header.account","link":"/member/account/settings_input.htm","target":"_top","rel":"nofollow","gaLabel":"Account","testLabel":"account-settings","iconKey":"setting"}]}],"subUserMenu":[{"id":"subUserMenuPrimary","childNavigationLinks":[{"gaLabel":"Account","iconKey":"questionMark","link":"https://help.glassdoor.com","rel":"nofollow","target":"_blank","testLabel":"help-center","textKey":"link.label.help-center"},{"textKey":"msg.sign-out","link":"/logout.htm","gaLabel":"Sign Out","testLabel":"sign-out","iconKey":"signOut"}]}],"mainMenu":[{"textKey":"site.header.jobs","link":"/Job/jobsHomeRedirect.htm","target":"_top","gaLabel":"null","testLabel":"site-header-jobs","id":"jobs","iconKey":"jobs","childNavigationLinks":[{"textKey":"site.header.jobs.recentActivity","link":"/Job/Home/recentActivity.htm","target":"_top","gaLabel":"RecentActivity","id":"jobs_recentActivity","iconKey":"search"},{"textKey":"site.header.jobs.alerts","link":"/Job/Home/jobAlerts.htm","target":"_top","gaLabel":"Alerts","id":"jobs_jobAlerts","iconKey":"jobAlertAngled"},{"textKey":"site.header.jobs.saved","link":"/Job/Home/savedJobs.htm","target":"_top","gaLabel":"Saved","id":"jobs_savedJobs","iconKey":"save"},{"textKey":"site.header.jobs.applications","link":"/Job/Home/appliedJobs.htm","target":"_top","gaLabel":"Applications","id":"jobs_appliedJobs","iconKey":"application"}]},{"textKey":"site.header.companies","link":"/Reviews/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-companies","id":"companies","iconKey":"companies","childNavigationLinks":[{"textKey":"site.header.companies.discover","link":"/Reviews/index.htm","target":"_top","gaLabel":"Discover","id":"companies_home","iconKey":"search"},{"textKey":"site.header.companies.compare","link":"/Compare/index.htm","target":"_top","gaLabel":"Compare","id":"companies_compare","iconKey":"compare"},{"textKey":"site.header.companies.follows","link":"/follow/companySuggestions.htm","target":"_top","gaLabel":"Suggested","id":"companies_follows","iconKey":"save"},{"textKey":"site.header.companies.add","link":"/mz-survey/start_input.htm?showSurvey=REVIEWS&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"WriteReview","id":"companies_add","iconKey":"add"}]},{"textKey":"site.header.salaries","link":"/Salaries/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-salaries","id":"salaries","iconKey":"salaries","childNavigationLinks":[{"textKey":"site.header.salaries.discover","link":"/Salaries/index.htm","target":"_top","gaLabel":"Discover","id":"salaries_home","iconKey":"search"},{"textKey":"site.header.salaries.add","link":"/mz-survey/start_input.htm?showSurvey=SALARIES&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"AddSalary","id":"salaries_add","iconKey":"add"}]},{"textKey":"site.header.car ...
# window.GD.page.headerPageId = "member";
# ...
# <script id="" type="text/javascript">(function(){var k=setInterval(function(){window.gdGlobals?(clearInterval(k),q()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(k)},1E4);var q=function(){function l(){e=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/youtube.com\/embed/.test(a.src)})}function r(){var a=window.YT;"undefined"!==typeof a&&"undefined"!==typeof a.Player?(window.clearInterval(f),e.map(m),t(),console.log("~ Glassdoor video")):5>=n?n++:window.clearInterval(f)}
# function m(a){-1===a.src.indexOf("enablejsapi\x3d")&&(a.src+=(~a.src.indexOf("?")?"\x26":"?")+"enablejsapi\x3d1");var b=window.YT;b=new b.Player(a,{events:{onReady:u,onError:v}});b._asData={eventType:void 0,previousEventType:void 0,currentTime:void 0,previousTime:void 0,videoTitle:"not set",videoPlayer:"YT",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,nonInteraction:null,hitValue:0,isPlaylist:!1,nextVidClick:!1,
# adPlaying:!1,videoLoaded:!1};a=b;var c=w,d;for(d in c)a[d]=c[d];b.setListeners();g.push(b)}function u(a){a.target._asData.isPlaylist=!(0>a.target.getPlaylistIndex());a.target._vidLoaded()}function v(a){console.log("~ YT Player Error: "+a._asData)}function t(){document.addEventListener("webkitfullscreenchange",function(a){h()},!1);document.addEventListener("mozfullscreenchange",function(a){h()},!1);document.addEventListener("fullscreenchange",function(a){h()},!1)}function h(){if(document.fullscreenElement){var a=
# g.filter(function(b){return b._asData.videoSrc===document.fullscreenElement.src});a[0]._vidFullScreen()}}function x(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());if(d>b+c)for(b=d,l(),c=0;c<e.length;c++)-1===e[c].src.indexOf("enablejsapi\x3d")&&m(e[c])},3E3)}var y=
# function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"youtube",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),w={setMilestones:function(){var a=this.getVideoLength();this._asData.milestones=
# this._asData.milestones.map(function(b){return b/100*a})},setVideoTitle:function(){this._asData.videoTitle=this.getVideoTitle()},getVideoTitle:function(){var a=this._asData.videoTitle;this.playerInfo&&this.playerInfo.videoData&&this.playerInfo.videoData.title?a=this.playerInfo.videoData.title:this.getVideoData&&this.getVideoData().title&&(a=this.getVideoData().title);a!==this._asData.videoTitle&&this._asData.videoLoaded&&(this._asData.videoLoaded=!1);return a},getVideoLength:function(){return this.getDuration?
# Math.round(this.getDuration()):this.playerInfo&&this.playerInfo.duration?Math.round(this.playerInfo.duration):null},setVideoLength:function(){this._asData.videoLength=this.getVideoLength()},_getCurrentTime:function(){return this.getCurrentTime?Math.round(this.getCurrentTime()):this.playerInfo&&this.playerInfo.currentTime?Math.round(this.playerInfo.currentTime):null},isVideo:function(){return this&&"VIDEO"===this.nodeName},_vidLoaded:function(){this._asData.videoLoaded||(this.setVideoTitle(),this.setVideoLength(),
# this.setMilestones(),this._asData.videoLoaded=!0)},_vidPlay:function(a){var b=void 0===a?this:a.target;b._asData.adPlaying||b._vidLoaded();if(b._asData.adPlaying)b._asData.adPlaying=!1;else if(void 0===a&&this._asData&&"player loaded"===this._asData.eventType&&(this._asData.adPlaying=!0),"autoplay"!==b._asData.eventType&&"click to play"!==b._asData.eventType||0!==b._asData.currentTime){b.milestoneCheck&&window.clearInterval(b.milestoneCheck);b.milestoneCheck=window.setInterval(b._vidMilestones,1E3,
# a);if(b._asData.justFinished&&(b._asData.justFinished=!1,!b._asData.isPlaylist))return;a=b._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===a.length?(b._asData.firstPlay=!1,b._asData.autoplay?b._sendHit(a[1],!0):b._sendHit(a[0],!1)):b._asData.justSeeked||b._sendHit(a,!1);5<Math.abs(b._asData.currentTime-b._asData.previousTime)&&!b._asData.justFinished&&b._sendHit("seek",!1);b._asData.justSeeked=!1}},_vidPause:function(a){var b=a.target;"cued"!==b._asData.eventType&&(window.clearInterval(b.milestoneCheck),
# 5<Math.abs(b._asData.currentTime-b._asData.previousTime)?b._vidSeek(a):b._getCurrentTime()!==b._asData.videoLength&&b._sendHit("pause",!1))},_vidSeek:function(a){a=a.target;"cued"!==a._asData.eventType&&(a._asData.adPlaying||a._asData.justFinished||0===a._asData.currentTime&&(0===a._asData.milestones.length||3===a._asData.milestones.length)||a._asData.justSeeked||a._asData.firstPlay||a._asData.justFinished||a._sendHit("seek",!1),a._asData.justSeeked=!0)},_vidComplete:function(a){a=a.target;if(0<a._asData.milestones.length)for(var b=
# 0;b<a._asData.milestones.length;b++){var c=a._asData.milestones[b];c=c/a._asData.videoLength*100;!Number.isNaN(c)&&0===c%25&&0<c&&100>=c&&(a._asData.hitValue=c,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+c+"%")),!0))}a._asData.justFinished||(a._asData.adPlaying=!1,window.clearInterval(a.milestoneCheck),a._asData.hitValue=100,a._sendHit("complete",!0),a._asData.firstPlay=!0,a._asData.justFinished=!0,a._asData.milestones=[25,50,75],a._asData.isPlaylist?a._asData.finalPlaylistVid||
# (b=a.getPlaylistIndex(),c=a.getPlaylist().length,b+1===c&&(a._asData.finalPlaylistVid=!0),a._asData.autoplay=!0,a._asData.videoLoaded=!1,a._vidLoaded()):(a._asData.autoplay=!1,a.setVideoLength(),a.setMilestones()))},_vidMilestones:function(a){if(void 0!==a){a=a.target;var b=a._getCurrentTime();a._asData.previousTime=b;if(!(b<a._asData.milestones[0])){0===a._asData.milestones.length&&window.clearInterval(a.milestoneCheck);do{var c=a._asData.milestones.splice(0,1)[0];a._asData.firstPlay&&(a._sendHit("autoplay",
# !0),a._asData.firstPlay=!1)}while(c>b);b=c/a._asData.videoLength*100;!Number.isNaN(b)&&0===b%25&&0<b&&100>=b&&(a._asData.hitValue=b,a._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}}},_vidMuted:function(){if(this.isMuted)if(this.isMuted())this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=!1;else return;else if(this.playerInfo)if(this.playerInfo.muted)this._asData.justMuted||(this._asData.justMuted=!0);else if(this._asData.justMuted)this._asData.justMuted=
# !1;else return;this._asData.currentTime=this._getCurrentTime();void 0===this._asData.currentTime||1>this._asData.currentTime||(this._asData.justMuted?this._sendHit("mute",!1):this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.previousEventType=this._asData.eventType;this._asData.eventType=a;this._asData.hitValue=
# a.match(/milestone|complete/i)?this._asData.hitValue:null;this._asData.nonInteraction=b;y(this._asData)},setListeners:function(){this.addEventListener("onStateChange",function(a){if(-1===a.data){if("cued"===a.target._asData.eventType)return;if("player loaded"===a.target._asData.eventType){a.target._vidPlay(a);return}if(a.target._asData.videoTitle!==a.target.getVideoTitle()){a.target._asData.milestones=[25,50,75];a.target._asData.autoplay=!1;a.target._asData.firstPlay=!0;a.target._asData.videoLoaded=
# !1;a.target._asData.adPlaying=!1;a.target._vidLoaded();return}}if(5===a.data)a.target._asData.milestones=[25,50,75],a.target._asData.autoplay=!1,a.target._asData.firstPlay=!0,a.target._asData.videoLoaded=!1,a.target._asData.adPlaying=!1,a.target._asData.eventType="cued",a.target._asData.videoTitle="not set";else{a.target._asData.currentTime=a.target._getCurrentTime();var b=[a.target._vidComplete,a.target._vidPlay,a.target._vidPause,a.target._vidSeek];(b=b[a.data]||void 0)&&b(a);a.target._asData.previousTime=
# a.target._asData.currentTime}},!0);this.addEventListener("onVolumeChange",function(a){a=a.target;a._vidMuted()},!0)}},g=[];window._asVideos=g;var f,n=0,e,p=setInterval(function(){l();if(0<e.length){clearInterval(p);var a=window.YT;if(0<e.length){a="undefined"!==typeof a&&"undefined"!==typeof a.Player;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="//www.youtube.com/iframe_api";b.parentNode.insertBefore(a,b)}f=window.setInterval(r,
# 1E3)}}},500);setTimeout(function(){clearInterval(p)},1E4);setTimeout(function(){x()},5E3)}})();</script>
# <script id="" type="text/javascript">(function(){var l=setInterval(function(){window.gdGlobals?(clearInterval(l),r()):window.gdGlobals=window.gdGlobals||[]},200);setTimeout(function(){clearInterval(l)},1E4);var r=function(){function m(){g=Array.prototype.filter.call(document.getElementsByTagName("iframe"),function(a){return/player.vimeo.com/.test(a.src)})}function t(){var a=window.Vimeo;"undefined"!==typeof a?(window.clearInterval(h),g.map(n)):5>p?p++:window.clearInterval(h)}function n(a){var b=window.Vimeo;b=new b.Player(a);b._asData=
# {eventType:void 0,videoTitle:"not set",videoPlayer:"Vimeo_iframe",videoLength:"not set",videoSrc:a.src,milestones:[25,50,75],firstPlay:!0,autoplay:-1!==a.src.indexOf("autoplay\x3d1"),justSeeked:!1,justFinished:!1,justMuted:!1,vidLoaded:!1,nonInteraction:null,hitValue:0};var c=b,d=u,f;for(f in d)c[f]=d[f];b.setListeners();v.push(b);b._vidLoaded();a._asProcessed=!0}function w(){function a(){var c=document.body,d=document.documentElement;return document.height||Math.max(Math.max(c.scrollHeight,d.scrollHeight),
# Math.max(c.offsetHeight,d.offsetHeight),Math.max(c.clientHeight,d.clientHeight))}var b=a();window.setInterval(function(){var c=100,d=Math.max(b,a());d>b+c&&(b=d,m(),g.map(function(f){f._asProcessed||n(f)}))},3E3)}var x=function(){window.gdGlobals=window.gdGlobals||[];return function(a){if("not set"!==a.videoTitle){var b=a={event:"video-engagement",videoType:"vimeo",videoAction:a.eventType,videoTitle:a.videoTitle,videoPercent:a.hitValue,videoNonInteraction:a.nonInteraction,videoDetails:{title:a.videoTitle,
# videoUrl:a.videoSrc,duration:a.videoLength,currentTime:a.currentTime}};window.setTimeout(function(){window.gdGlobals.push(b)},1,b)}}}(),u={setMilestones:function(){var a=this,b=window.setInterval(function(){var c=a._asData.videoLength;"not set"!==c&&(a._asData.milestones=a._asData.milestones.map(function(d){return d/100*c}),window.clearInterval(b))},200,a)},setVideoTitle:function(){var a=this;this.getVideoTitle().then(function(b){a._asData.videoTitle=b})},replayOrNewVid:function(){var a=this;this._asData.milestones=
# [25,50,75];this.getVideoTitle().then(function(b){a._asData.videoTitle===b?(a._asData.justFinished=!1,a.setMilestones()):a._vidLoaded();a._vidPlay()})},setVideoLength:function(){var a=this;this.getDuration().then(function(b){a._asData.videoLength=Math.round(b)})},_asGetCurrentTime:function(){var a=this;this.getCurrentTime().then(function(b){a._asData.currentTime=b})},_vidLoaded:function(){var a=this;this.setVideoTitle();this.setVideoLength();this.setMilestones();this.getVolume().then(function(c){0===
# c&&(a._asData.justMuted=!0)});var b=setInterval(function(){"not set"!==a._asData.videoTitle&&clearInterval(b)},75);this._asData.justFinished=!1;this._asData.vidLoaded=!0},_vidPlay:function(){if(!e){var a=this;window.setTimeout(function(){if(!e)if(a._asData.justFinished&&a._asData.firstPlay)a.replayOrNewVid();else{var b=a._asData.firstPlay?["initial click to play","autoplay"]:"resume";2===b.length?(a._asData.firstPlay=!1,a._asData.autoplay?a._sendHit(b[1],!0):a._sendHit(b[0],!1)):a._sendHit(b,!1)}},
# 1E3,a)}},_vidPause:function(){var a=this;a._asData.justFinished||e||window.setTimeout(function(){a._asData.justFinished||e||a.getCurrentTime()!==a._asData.videoLength&&a._sendHit("pause",!1)},1E3,a)},_vidSeek:function(){e||this._asData.justFinished||(e=!0,this._sendHit("seek",!1),window.setTimeout(function(){e=!1},2E3))},_vidComplete:function(){if(0<this._asData.milestones.length)for(var a=0;a<this._asData.milestones.length;a++){var b=this._asData.milestones[a];b=b/this._asData.videoLength*100;!Number.isNaN(b)&&
# 0===b%25&&0<b&&100>=b&&(this._asData.hitValue=b,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+b+"%")),!0))}this._asData.hitValue=100;this._sendHit("complete",!0);this._asData.firstPlay=!0;this._asData.justFinished=!0;this._asData.autoplay=!1},_vidMilestones:function(a){this._asData.currentTime=a.seconds;if(!(k||(k=!0,window.setTimeout(function(){k=!1},2E3),this._asData.firstPlay&&3<a.seconds&&this._vidPlay(),a.seconds<this._asData.milestones[0]||0===this._asData.milestones.length))){a=
# a.seconds;do var b=this._asData.milestones.splice(0,1)[0];while(b>a);a=b/this._asData.videoLength*100;!Number.isNaN(a)&&0===a%25&&0<a&&100>=a&&(this._asData.hitValue=a,this._sendHit(decodeURIComponent(encodeURIComponent("milestone "+a+"%")),!0))}},_vidMuted:function(a){!1===this._asData.justMuted&&0===a.volume?(this._asData.justMuted=!0,this._sendHit("mute",!1)):this._asData.justMuted&&0<a.volume&&(this._asData.justMuted=!1,this._sendHit("unmute",!1))},_vidFullScreen:function(){(document.fullscreenElement||
# document.mozFullScreen||document.webkitIsFullScreen||document.msFullscreenElement||document.fullScreen)&&this._sendHit("full screen",!1)},_sendHit:function(a,b){this._asData.eventType=a;this._asData.nonInteraction=b;this._asData.hitValue=a.match(/milestone|complete/i)?this._asData.hitValue:null;x(this._asData)},setListeners:function(){this.on("play",function(){this._vidPlay()},!0);this.on("pause",function(){this._vidPause()},!0);this.on("seeked",function(){this._vidSeek()},!0);this.on("ended",function(){this._vidComplete()},
# !0);this.on("timeupdate",function(a){this._vidMilestones(a)},!0);this.on("volumechange",function(a){this._vidMuted(a)},!0);this.on("fullscreenchange",function(){this._vidFullScreen()},!0);this.on("webkitfullscreenchange",function(){this._vidFullScreen()},!0);this.on("mozfullscreenchange",function(){this._vidFullScreen()},!0);this.on("msfullscreenchange",function(){this._vidFullScreen()},!0)}},v=[],h,p=0,g,e=!1,k=!1,q=setInterval(function(){m();if(0<g.length){clearInterval(q);var a=window.Vimeo;if(0<
# g.length){a="undefined"!==typeof a;if(!a){a=document.createElement("script");var b=document.getElementsByTagName("script")[0];a.async=!0;a.type="text/javascript";a.src="https://player.vimeo.com/api/player.js";b.parentNode.insertBefore(a,b)}h=window.setInterval(t,1E3)}}},500);setTimeout(function(){clearInterval(q)},1E4);setTimeout(function(){w()},5E3)}})();</script></body></html>

# %%
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']

# %%
for city in cities:
    print(cities.index(city) == 0)

# %%
city

# %%
# driver path

## driver path should be the location of the folder where the driver you downloaded is ## 

#driver_path = '/Users/alex/Documents/Tools/Drivers - Selenium/chromedriver' 

## first we need to initiate the driver - probably the most important part of the code ##
#driver = webdriver.Chrome(executable_path = driver_path)

# or new version 
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://www.glassdoor.ie/member/home/index.htm')

# login into your Glassdoor account

# input your email

email = input('Enter your email: ')

# here we are going to find the box where we input the email
email_box = driver.find_element(By.ID, "inlineUserEmail") #email_box = driver.find_element_by_id("username") #deprecated

#clear the search box if it has already something in there
email_box.clear()

# with the method send_keys() you can send the information from the script to the webpage
email_box.send_keys(email)
time.sleep(2)

# input the password
password = getpass('Enter your password: ')

# here we are going to find the box where we input the password
pass_box = driver.find_element(By.ID, 'inlineUserPassword') #pass_box = driver.find_element_by_id('password') #deprecated

#clear the paword box if it has already something in there
pass_box.clear()

# here we will send the password to the driver 
pass_box.send_keys(password)
time.sleep(1)

login = driver.find_element(By.CLASS_NAME,'gd-ui-button') #login = driver.find_element_by_class_name('gd-ui-button mt-std minWidthBtn css-14xfqow evpplnh0') #deprecated
#login =  driver.find_element(By.CSS_SELECTOR, '[name="submit"]').send_keys("webElement")
login.click()
time.sleep(1)

# %%
role = input('Enter position role: ')
# here we are going to find the box where we input the email
seachboxrole = driver.find_element(By.ID, "sc.keyword")
#clear the search box if it has already something in there
seachboxrole.clear()
# with the method send_keys() you can send the information from the script to the webpage
seachboxrole.send_keys(role)
time.sleep(2)

#Click dropdown to select salaries
#dropdown_salaries = driver.find_element(By.CLASS_NAME,'selectedLabel') 
dropdown = driver.find_element(By.CLASS_NAME,'SVGInline-svg')
dropdown.click()

#Click dropdown to select salaries
#dropdown_salaries = driver.find_element(By.CLASS_NAME,'selectedLabel') 
dropdown_salaries = driver.find_element_by_xpath("// span[contains(text(),\'Salaries')]").click()
# Out:
# Enter position role: data analyst
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\SERGIO~1\AppData\Local\Temp/ipykernel_19844/1490728810.py in <module>
#      15 #Click dropdown to select salaries
#      16 #dropdown_salaries = driver.find_element(By.CLASS_NAME,'selectedLabel')
# ---> 17 dropdown_salaries = driver.find_element_by_xpath("// span[contains(text(),\'Salaries')]").click()
#
# C:\dataanalyst\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# C:\dataanalyst\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# C:\dataanalyst\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\dataanalyst\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"// span[contains(text(),'Salaries')]"}
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00EB7413+2389011]
# 	Ordinal0 [0x00E49F61+1941345]
# 	Ordinal0 [0x00D3C658+837208]
# 	Ordinal0 [0x00D691DD+1020381]
# 	Ordinal0 [0x00D6949B+1021083]
# 	Ordinal0 [0x00D96032+1204274]
# 	Ordinal0 [0x00D84194+1130900]
# 	Ordinal0 [0x00D94302+1196802]
# 	Ordinal0 [0x00D83F66+1130342]
# 	Ordinal0 [0x00D5E546+976198]
# 	Ordinal0 [0x00D5F456+980054]
# 	GetHandleVerifier [0x01069632+1727522]
# 	GetHandleVerifier [0x0111BA4D+2457661]
# 	GetHandleVerifier [0x00F4EB81+569713]
# 	GetHandleVerifier [0x00F4DD76+566118]
# 	Ordinal0 [0x00E50B2B+1968939]
# 	Ordinal0 [0x00E55988+1989000]
# 	Ordinal0 [0x00E55A75+1989237]
# 	Ordinal0 [0x00E5ECB1+2026673]
# 	BaseThreadInitThunk [0x75BFFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A4E+238]

# %%
url="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm?clickSource=searchBtn"

# %%
response = requests.get(url ,headers=headers)
soup = BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <!DOCTYPE html>
#
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/">
# <head>
# <title data-rh="true">Salary: Junior Data Analyst in Dublin, Ireland | Glassdoor</title>
# <meta content="8gasaHBZws6-VlwUeolXJRSp0aUrfYzMYjiPfCwfn7" name="globalsign-domain-verification"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="#0caa41" name="theme-color"/><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><meta content="yes" name="apple-mobilegi-web-app-capable"/><meta content="origin" name="referrer"/><meta content="589698942" property="al:ios:app_store_id"/><meta content="Glassdoor" property="al:ios:app_name"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="website" property="og:type"/><meta content="Glassdoor" property="og:site_name"/><meta content="129253937150340" property="fb:app_id"/><meta content="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" property="og:url"/><meta content="https://www.glassdoor.com/app/static/img/partners/fb/logo-1200x630.png?v=721f9cswl" property="og:image"/><meta content="app-id=589698942" name="apple-itunes-app"/><meta content="app-id=com.glassdoor.app" name="google-play-app"/>
# <meta content="Salary: Junior Data Analyst in Dublin, Ireland" data-rh="true" property="og:title"/><meta content="1,969 Junior Data Analyst Salaries in Dublin, Ireland provided anonymously by employees. What salary does a Junior Data Analyst earn in Dublin?" data-rh="true" name="description"/><meta content="1,969 Junior Data Analyst Salaries in Dublin, Ireland provided anonymously by employees. What salary does a Junior Data Analyst earn in Dublin?" data-rh="true" property="og:description"/>
# <link data-rh="true" href="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm?clickSource=searchBtn" rel="canonical"/><link data-rh="true" href="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26_IP2.htm?clickSource=searchBtn" rel="next"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link href="https://www.glassdoor.com/app/static/css/gd-salary-search-core.css?v=12da73993m" media="all" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/app/static/js/dist/gd-site-header.bundle.css?v=f2b9beoqb" media="all" rel="stylesheet" type="text/css"/><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-57.png?v=595028252" rel="apple-touch-icon-precomposed"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-72.png?v=e859f12fg" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-114.png?v=81fd863hl" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://www.glassdoor.com/app/static/img/mobile/icons/touch-icon-144.png?v=0efaf240j" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="/manifest.json" rel="manifest"/><link href="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" rel="canonical"/><link href="https://www.glassdoor.ie/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-IE" rel="alternate"/><link href="https://www.glassdoor.com.au/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-AU" rel="alternate"/><link href="https://www.glassdoor.ca/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-CA" rel="alternate"/><link href="https://www.glassdoor.com.hk/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-HK" rel="alternate"/><link href="https://www.glassdoor.co.in/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-IN" rel="alternate"/><link href="https://www.glassdoor.co.nz/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-NZ" rel="alternate"/><link href="https://www.glassdoor.sg/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-SG" rel="alternate"/><link href="https://www.glassdoor.co.uk/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en-GB" rel="alternate"/><link href="https://www.glassdoor.com/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm" hreflang="en" rel="alternate"/>
# <script>
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/search/salaries?cat=Salaries&o=data+analyst+junior&l=Dublin+%28M%3A+1052%29",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-IE',
# 			'env': 'prod',
# 			'release': '20220426-2',
# 			'appName': 'app',
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.ie",
# 								'domainId':		18,
# 								'domainCountryId': 70,
#
#
# 								'domainSuffix': "ie",
#
#
# 								'group':        "Search-Salaries",
#
#
# 								'projectUrlGroup':        "[]",
#
#
# 								'guid':         '000001808a6951f0ad1e19102059f1ae',
#
#
# 								'flex':         true,
#
#
# 								'section':      "search",
#
#
# 								'type':         "search:search-salaries",
#
#
# 								'id':           "search:search-salaries",
#
# 								'med': '',
#
# 								'src' : '',
# 								'content' : '',
# 								'campaign' : '',
# 								'term' : '',
# 								'state' : 'locked',
# 								'untranslatedUrl' : 'https://www.glassdoor.com/Salaries/dublin-data-analyst-junior-salary-SRCH_IL.0,6_IM1052_KO7,26.htm'
#
#                                     , 'modulesDisplayed': {
#                                         'occMedianNationalShown': 'N',
#                                         'occMedianMetroShown': 'N',
#                                         'employerSalariesShown': 'N',
#                                         'recentSalariesShown': 'N',
#                                         'relatedSalariesShown': 'N',
#                                         'kywPromoShown': 'Y'
#                                     }
#
# 							},
#
# 			'user':         {
#
# 								'guid':         'd9be593d-00f0-4241-a989-50fb66328b99',
#
# 								'ipAddr':       "45.87.214.115",
#
#
# 								'locale':       "en_IE",
#
#
# 								'country':      "IE",
# 								'ipLocationId': "1154170",
# 								'ipLocationType': "C",
#
# 								'elligibleForAppBoy': false,
# 							},
#
# 			'vendor':       {
# 								'fbReqPerms':   ""
# 							},
#
# 				'implicitLoc':'Ireland',
#
# 			'search':       {
#
# 				"rawKeyword":"data analyst junior"
#
# 								, 'location': "Dublin, Ireland",
# 								'locationType': "M",
# 								'locationId': "1052"
#
# 								, 'occupation' : "data analyst junior"
#
# 								, 'totalSearchResults': "0",
# 								'displayedSearchResults': "-1",
# 								'pageNumber': "1",
# 								'noData' : 'true'
#
# 								, 'searchQueryGuid' : ""
#
# 							, 'segmentType' : "OL"
#
# 			},
# 			'employer' : {
#
# 			},
# 			'job' : {
#
# 			},
# 			'test' : {
#
# 				'planoutIdList': [
#
# 						, "site_discovery_ugc_search2.PROD_ugc_search2_v1"
#
# 						, "site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1"
#
# 						, "webapp-job-awareness.trfc_3209_job_awareness"
#
# 						, "growth_global.exp_growth_global_catchAll"
#
# 						, "brand_ads_company_explorer.native_ads_explore"
#
# 						, "user_profile.exp_user_profile_catchall"
#
# 						, "content_single_page_survey.CXP_1419_PROD_test"
#
# 						, "brand_ads_company_compare.native_ads_compare"
#
# 						, "site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1"
#
# 						, "content_reviews_node.I18N_redirect_reviews_node_test_20190530"
#
# 						, "nuf_steps.surveys_order_test"
#
# 						, "site_discovery_nav.site_discovery_nav_t2"
#
# 						, "growth_jobs.growth_jobs_default_catchAll"
#
# 						, "lightweight_data_collection.exp_user_profile_catchall"
#
# 						, "total_comp_salaries_ui_refresh_dec2021.PROD_total_comp_salaries_ui_refresh_20211202"
#
# 						, "content_survey_global_context.CON_238_PROD_test_051221"
#
# 						, "site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1"
#
# 						, "ei_compare_rollout.TRFC_4368_ei_compare"
#
# 						, "company_explorer.TRFC_4524_02102020"
#
# 						, "growth_user_activation.user_activation_post_auth_redirect_exp_20220201"
#
# 						, "growth_brand_campaign.growth_brand_campaign_exp_catchAll"
#
# 						, "nuf_v2_1.ipad_promotion_test"
#
# 						, "nuf_gd_logo.disabled_logo_test"
#
# 						, "site_discovery_header.exp_site_discovery_header_catchall"
#
# 						, "total_comp_salary_occupation_new_ui.total_comp_salary_occupation_new_ui_test_04142021"
#
# 						, "site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall"
#
# 				],
# 				'planoutTreatmentList': [
#
# 						, "ugc_search2_t1"
#
# 						, "ugc_search2_salaries_t1"
#
# 						, "trfc-3209-test"
#
# 						, "growth_global_default"
#
# 						, "native_ads_explore_t1"
#
# 						, "user_profile_default_treatment"
#
# 						, "single_page_t1"
#
# 						, "native_ads_compare_t1"
#
# 						, "ugc_search2_autocomplete_t1"
#
# 						, "redirect2Node_t1"
#
# 						, "surveys_order_test_control"
#
# 						, "career_nav_t2"
#
# 						, "growth_jobs_default"
#
# 						, "lightweight_data_collection_default"
#
# 						, "salaries_ui_t1"
#
# 						, "new_suggested_companies_t1"
#
# 						, "ugc_search2_interviews_t1"
#
# 						, "ei_compare_activated"
#
# 						, "test_on"
#
# 						, "post_auth_redirect_t1"
#
# 						, "growth_brand_campaign_default"
#
# 						, "nuf_v2_1_control"
#
# 						, "disabled_logo_test_t1"
#
# 						, "site_discovery_header_default"
#
# 						, "salary_occupation_new_ui_t1"
#
# 						, "fishbowl_default"
#
# 				]
# 			},
# 			'staticList' : {
#
# 			}
#
# 		}];
#
# 	if(window.projectUrlGroup && Array.isArray(window.projectUrlGroup)) {
# 		var globalsProjectUrlGroup = JSON.parse(gdGlobals[0].page.projectUrlGroup);
# 		var combined = globalsProjectUrlGroup.concat(window.projectUrlGroup);
# 		gdGlobals[0].page.projectUrlGroup = JSON.stringify(combined);
# 	}
#
#
# 	window.getGdGlobals = window.getGdGlobals ||
# 			function() {
# 				return gdGlobals[0];
# 			};
#
# 	GD = window.GD || {};
# 	GD.pageInfo = GD.pageInfo || {};
# 	GD.pageInfo.pageGroup = getGdGlobals().page.group;
# 	GD.domain = getGdGlobals().page.domain;
#
# 	</script><script>
#
# 			(function(w,d,s,l,i) {
# 				w[l] = w[l] || [];
# 				w[l].push({
# 					'gtm.start': new Date().getTime(),
# 					event:       'gtm.js'
# 				});
# 				var f = d.getElementsByTagName(s)[0],
# 						j = d.createElement(s),
# 						dl = l != 'dataLayer' ? '&l=' + l : '';
# 				j.defer=true;
# 				j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
# 				f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','gdGlobals','GTM-PST2JZ');
# 		</script><script></script></head></html>

# %%
# Get data for every city in the list
maindf2= pd.DataFrame()
output =[]
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']
count = 0
mainlist=[]

for city in cities:
    
       
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        time.sleep(3)
        
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        
        
                
        #driver.get(html)
        soup = BeautifulSoup(html)
        output.append(soup)
        # send html to a .txt rewrite the name for each one 
        
        
       

        #url = driver.current_url
        #response = requests.get(url ,headers=headers)
        print(response)
        #soup = BeautifulSoup(response.content)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys = city
        #citydetail[0]["value"]
        position_summary_detail.append(citys)
        print(citys)
    
        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        
        
        position = positiondetail[0].text
        position_summary_detail.append(position)
        print(position)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)
        print(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)
        print(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)
        print(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)
        print(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)
        print(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)
        print(positioninfo)
        
        mainlist.append(position_summary_detail)
        print('Main list: ',position_summary_detail)
        
        #Dataframe creation
        position_summary_detail_df = pd.DataFrame(np.array(position_summary_detail).reshape(-1,len(position_summary_detail)))
        position_summary_detail_df.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
        position_summary_detail_df
        maindf2 = pd.concat([maindf,position_summary_detail_df])

    
        
        print("Falied city:",city)
    
    
       
num = np.random.randint(1,10000000)    
glassdoor_role_table = maindf.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_table{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_unique.csv')
maindf2
# Out:
# <Response [200]>
# Dublin
# Junior Data Analyst Salaries in Dublin Area
# Updated 2 May 2022
# €33,139
# €29K
# €33K
# €40K
# How much does a Junior Data Analyst make in Dublin, Ireland? The average salary for a Junior Data Analyst is €33,139  in Dublin, Ireland. Salaries estimates are based on 11 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Dublin, Ireland.
# Main list:  ['Dublin', 'Junior Data Analyst Salaries in Dublin Area', 'Updated 2 May 2022', '€33,139', '€29K', '€33K', '€40K', 'How much does a Junior Data Analyst make in Dublin, Ireland? The average salary for a Junior Data Analyst is €33,139  in Dublin, Ireland. Salaries estimates are based on 11 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Dublin, Ireland.']
# Falied city: Dublin
# <Response [200]>
# Amsterdam
# Junior Data Analyst Salaries in Amsterdam, Netherlands Area
# Updated 2 May 2022
# €17
# €13
# €17
# €23
# The average salary for Junior Data Analyst is €17 per month in the Amsterdam, Netherlands Area. The average additional cash compensation for a Junior Data Analyst in the Amsterdam, Netherlands Area is €2,000, with a range from €2,000 - €2,000. Salaries estimates are based on 4 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Amsterdam, Netherlands Area.
# Main list:  ['Amsterdam', 'Junior Data Analyst Salaries in Amsterdam, Netherlands Area', 'Updated 2 May 2022', '€17', '€13', '€17', '€23', 'The average salary for Junior Data Analyst is €17 per month in the Amsterdam, Netherlands Area. The average additional cash compensation for a Junior Data Analyst in the Amsterdam, Netherlands Area is €2,000, with a range from €2,000 - €2,000. Salaries estimates are based on 4 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Amsterdam, Netherlands Area.']
# Falied city: Amsterdam
# <Response [200]>
# Madrid
# Junior Data Analyst Salaries in Madrid, Spain Area
# Updated 2 May 2022
# €26,404
# €20K
# €26K
# €32K
# The average salary for Junior Data Analyst is €26,404 per year in the Madrid, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Madrid, Spain Area is €3,118, with a range from €2,110 - €5,000. Salaries estimates are based on 36 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Madrid, Spain Area.
# Main list:  ['Madrid', 'Junior Data Analyst Salaries in Madrid, Spain Area', 'Updated 2 May 2022', '€26,404', '€20K', '€26K', '€32K', 'The average salary for Junior Data Analyst is €26,404 per year in the Madrid, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Madrid, Spain Area is €3,118, with a range from €2,110 - €5,000. Salaries estimates are based on 36 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Madrid, Spain Area.']
# Falied city: Madrid
# <Response [200]>
# Paris
# Junior Data Analyst Salaries in Paris, France Area
# Updated 2 May 2022
# €39,835
# €29K
# €40K
# €48K
# The average salary for Junior Data Analyst is €39,835 per year in the Paris, France Area. The average additional cash compensation for a Junior Data Analyst in the Paris, France Area is €12,308, with a range from €4,148 - €20,469. Salaries estimates are based on 33 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Paris, France Area.
# Main list:  ['Paris', 'Junior Data Analyst Salaries in Paris, France Area', 'Updated 2 May 2022', '€39,835', '€29K', '€40K', '€48K', 'The average salary for Junior Data Analyst is €39,835 per year in the Paris, France Area. The average additional cash compensation for a Junior Data Analyst in the Paris, France Area is €12,308, with a range from €4,148 - €20,469. Salaries estimates are based on 33 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Paris, France Area.']
# Falied city: Paris
# <Response [200]>
# Berlin
# Junior Data Analyst Salaries in Berlin, Germany Area
# Updated 1 May 2022
# €44,470
# €37K
# €44K
# €50K
# The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.
# Main list:  ['Berlin', 'Junior Data Analyst Salaries in Berlin, Germany Area', 'Updated 1 May 2022', '€44,470', '€37K', '€44K', '€50K', 'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.']
# Falied city: Berlin
# <Response [200]>
# Milan
# Junior Data Analyst Salaries in Milan, Italy Area
# Updated 2 May 2022
# €26,537
# €23K
# €27K
# No additional cash compensation has been reported for this role
# How much does a Junior Data Analyst make in Milan, Italy? The average salary for a Junior Data Analyst is €26,537  in Milan, Italy. Salaries estimates are based on 8 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Milan, Italy.
# Main list:  ['Milan', 'Junior Data Analyst Salaries in Milan, Italy Area', 'Updated 2 May 2022', '€26,537', '€23K', '€27K', 'No additional cash compensation has been reported for this role', 'How much does a Junior Data Analyst make in Milan, Italy? The average salary for a Junior Data Analyst is €26,537  in Milan, Italy. Salaries estimates are based on 8 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Milan, Italy.']
# Falied city: Milan
# <Response [200]>
# London
# Junior Data Analyst Salaries in London, United Kingdom Area
# Updated 2 May 2022
# £28,268
# £20K
# £28K
# £40K
# The average salary for Junior Data Analyst is £28,268 per year in the London, United Kingdom Area. The average additional cash compensation for a Junior Data Analyst in the London, United Kingdom Area is £1,417, with a range from £274 - £7,326. Salaries estimates are based on 64 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the London, United Kingdom Area.
# Main list:  ['London', 'Junior Data Analyst Salaries in London, United Kingdom Area', 'Updated 2 May 2022', '£28,268', '£20K', '£28K', '£40K', 'The average salary for Junior Data Analyst is £28,268 per year in the London, United Kingdom Area. The average additional cash compensation for a Junior Data Analyst in the London, United Kingdom Area is £1,417, with a range from £274 - £7,326. Salaries estimates are based on 64 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the London, United Kingdom Area.']
# Falied city: London
# <Response [200]>
# Barcelona
# Junior Data Analyst Salaries in Barcelona, Spain Area
# Updated 2 May 2022
# €24,000
# €18K
# €24K
# €39K
# The average salary for Junior Data Analyst is €24,000 per year in the Barcelona, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Barcelona, Spain Area is €7,575, with a range from €2,820 - €12,330. Salaries estimates are based on 41 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Barcelona, Spain Area.
# Main list:  ['Barcelona', 'Junior Data Analyst Salaries in Barcelona, Spain Area', 'Updated 2 May 2022', '€24,000', '€18K', '€24K', '€39K', 'The average salary for Junior Data Analyst is €24,000 per year in the Barcelona, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Barcelona, Spain Area is €7,575, with a range from €2,820 - €12,330. Salaries estimates are based on 41 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Barcelona, Spain Area.']
# Falied city: Barcelona
# <Response [200]>
# Frankfurt
# Junior Data Analyst Salaries in Berlin, Germany Area
# Updated 1 May 2022
# €44,470
# €37K
# €44K
# €50K
# The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.
# Main list:  ['Frankfurt', 'Junior Data Analyst Salaries in Berlin, Germany Area', 'Updated 1 May 2022', '€44,470', '€37K', '€44K', '€50K', 'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.']
# Falied city: Frankfurt
# <Response [200]>
# Lisbon
# Junior Data Analyst Salaries in Lisbon, Portugal Area
# Updated 30 Apr 2022
# €1,259
# €1K
# €1K
# €2K
# The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.
# Main list:  ['Lisbon', 'Junior Data Analyst Salaries in Lisbon, Portugal Area', 'Updated 30 Apr 2022', '€1,259', '€1K', '€1K', '€2K', 'The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.']
# Falied city: Lisbon
#         city                                           position  \
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam        Junior Data Analyst Salaries in Dublin Area
# 0     Madrid        Junior Data Analyst Salaries in Dublin Area
# 0      Paris  Junior Data Analyst Salaries in Madrid, Spain ...
# 0     Berlin  Junior Data Analyst Salaries in Paris, France ...
# 0      Milan  Junior Data Analyst Salaries in Paris, France ...
# 0     London  Junior Data Analyst Salaries in Milan, Italy Area
# 0     Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €26,404   €20K   €26K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 2 May 2022    €26,537   €23K   €27K
# 0  Updated 30 Apr 2022     €1,259    €1K    €1K
#
#                                               maxpay  \
# 0                                               €40K
# 0                                               €40K
# 0                                               €40K
# 0                                               €32K
# 0                                               €48K
# 0                                               €48K
# 0  No additional cash compensation has been repor...
# 0                                                €2K
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...
# 0  The average salary for Junior Data Analyst is ...

# %%
position_summary_detail
# Out:
# ['Lisbon',
#  'Junior Data Analyst Salaries in Lisbon, Portugal Area',
#  'Updated 30 Apr 2022',
#  '€1,259',
#  '€1K',
#  '€1K',
#  '€2K',
#  'The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.']

# %%
position_summary_detail_df = pd.DataFrame(np.array(position_summary_detail).reshape(-1,len(position_summary_detail)))
position_summary_detail_df
# Out:
#         0                                                  1  \
# 0  Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#                      2       3    4    5    6  \
# 0  Updated 30 Apr 2022  €1,259  €1K  €1K  €2K
#
#                                                    7
# 0  The average salary for Junior Data Analyst is ...

# %%
# Get data for every city in the list
maindf3= pd.DataFrame()
output =[]
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']
count = 0
mainlist=[]
masterlistbycity = []
for city in cities:
    
       
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        time.sleep(3)
        
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        
        
                
        #driver.get(html)
        soup = BeautifulSoup(html)
        output.append(soup)
        # send html to a .txt rewrite the name for each one 
        
        
       

        #url = driver.current_url
        #response = requests.get(url ,headers=headers)
        print(response)
        #soup = BeautifulSoup(response.content)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys = city
        #citydetail[0]["value"]
        position_summary_detail.append(citys)
        print(citys)
    
        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        
        
        position = positiondetail[0].text
        position_summary_detail.append(position)
        print(position)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)
        print(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)
        print(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)
        print(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)
        print(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)
        print(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)
        print(positioninfo)
        
        mainlist.append(position_summary_detail)
        print('Main list: ',position_summary_detail)
        masterlistbycity.append(position_summary_detail)
        
        #Dataframe creation
        position_summary_detail_df = pd.DataFrame(np.array(position_summary_detail).reshape(-1,len(position_summary_detail)))
        position_summary_detail_df.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
        position_summary_detail_df
        maindf3 = pd.concat([maindf,position_summary_detail_df])
        

    
        
        print("Falied city:",city)
    
    
       
num = np.random.randint(1,10000000)    
glassdoor_role_table = maindf.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_table{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_unique.csv')
maindf3
# Out:
# <Response [200]>
# Dublin
# Junior Data Analyst Salaries in Dublin Area
# Updated 2 May 2022
# €33,139
# €29K
# €33K
# €40K
# How much does a Junior Data Analyst make in Dublin, Ireland? The average salary for a Junior Data Analyst is €33,139  in Dublin, Ireland. Salaries estimates are based on 11 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Dublin, Ireland.
# Main list:  ['Dublin', 'Junior Data Analyst Salaries in Dublin Area', 'Updated 2 May 2022', '€33,139', '€29K', '€33K', '€40K', 'How much does a Junior Data Analyst make in Dublin, Ireland? The average salary for a Junior Data Analyst is €33,139  in Dublin, Ireland. Salaries estimates are based on 11 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Dublin, Ireland.']
# Falied city: Dublin
# <Response [200]>
# Amsterdam
# Junior Data Analyst Salaries in Amsterdam, Netherlands Area
# Updated 2 May 2022
# €17
# €13
# €17
# €23
# The average salary for Junior Data Analyst is €17 per month in the Amsterdam, Netherlands Area. The average additional cash compensation for a Junior Data Analyst in the Amsterdam, Netherlands Area is €2,000, with a range from €2,000 - €2,000. Salaries estimates are based on 4 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Amsterdam, Netherlands Area.
# Main list:  ['Amsterdam', 'Junior Data Analyst Salaries in Amsterdam, Netherlands Area', 'Updated 2 May 2022', '€17', '€13', '€17', '€23', 'The average salary for Junior Data Analyst is €17 per month in the Amsterdam, Netherlands Area. The average additional cash compensation for a Junior Data Analyst in the Amsterdam, Netherlands Area is €2,000, with a range from €2,000 - €2,000. Salaries estimates are based on 4 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Amsterdam, Netherlands Area.']
# Falied city: Amsterdam
# <Response [200]>
# Madrid
# Junior Data Analyst Salaries in Madrid, Spain Area
# Updated 2 May 2022
# €26,404
# €20K
# €26K
# €32K
# The average salary for Junior Data Analyst is €26,404 per year in the Madrid, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Madrid, Spain Area is €3,118, with a range from €2,110 - €5,000. Salaries estimates are based on 36 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Madrid, Spain Area.
# Main list:  ['Madrid', 'Junior Data Analyst Salaries in Madrid, Spain Area', 'Updated 2 May 2022', '€26,404', '€20K', '€26K', '€32K', 'The average salary for Junior Data Analyst is €26,404 per year in the Madrid, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Madrid, Spain Area is €3,118, with a range from €2,110 - €5,000. Salaries estimates are based on 36 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Madrid, Spain Area.']
# Falied city: Madrid
# <Response [200]>
# Paris
# Junior Data Analyst Salaries in Paris, France Area
# Updated 2 May 2022
# €39,835
# €29K
# €40K
# €48K
# The average salary for Junior Data Analyst is €39,835 per year in the Paris, France Area. The average additional cash compensation for a Junior Data Analyst in the Paris, France Area is €12,308, with a range from €4,148 - €20,469. Salaries estimates are based on 33 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Paris, France Area.
# Main list:  ['Paris', 'Junior Data Analyst Salaries in Paris, France Area', 'Updated 2 May 2022', '€39,835', '€29K', '€40K', '€48K', 'The average salary for Junior Data Analyst is €39,835 per year in the Paris, France Area. The average additional cash compensation for a Junior Data Analyst in the Paris, France Area is €12,308, with a range from €4,148 - €20,469. Salaries estimates are based on 33 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Paris, France Area.']
# Falied city: Paris
# <Response [200]>
# Berlin
# Junior Data Analyst Salaries in Berlin, Germany Area
# Updated 1 May 2022
# €44,470
# €37K
# €44K
# €50K
# The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.
# Main list:  ['Berlin', 'Junior Data Analyst Salaries in Berlin, Germany Area', 'Updated 1 May 2022', '€44,470', '€37K', '€44K', '€50K', 'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.']
# Falied city: Berlin
# <Response [200]>
# Milan
# Junior Data Analyst Salaries in Milan, Italy Area
# Updated 2 May 2022
# €26,537
# €23K
# €27K
# No additional cash compensation has been reported for this role
# How much does a Junior Data Analyst make in Milan, Italy? The average salary for a Junior Data Analyst is €26,537  in Milan, Italy. Salaries estimates are based on 8 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Milan, Italy.
# Main list:  ['Milan', 'Junior Data Analyst Salaries in Milan, Italy Area', 'Updated 2 May 2022', '€26,537', '€23K', '€27K', 'No additional cash compensation has been reported for this role', 'How much does a Junior Data Analyst make in Milan, Italy? The average salary for a Junior Data Analyst is €26,537  in Milan, Italy. Salaries estimates are based on 8 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Milan, Italy.']
# Falied city: Milan
# <Response [200]>
# London
# Junior Data Analyst Salaries in London, United Kingdom Area
# Updated 2 May 2022
# £28,268
# £20K
# £28K
# £40K
# The average salary for Junior Data Analyst is £28,268 per year in the London, United Kingdom Area. The average additional cash compensation for a Junior Data Analyst in the London, United Kingdom Area is £1,417, with a range from £274 - £7,326. Salaries estimates are based on 64 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the London, United Kingdom Area.
# Main list:  ['London', 'Junior Data Analyst Salaries in London, United Kingdom Area', 'Updated 2 May 2022', '£28,268', '£20K', '£28K', '£40K', 'The average salary for Junior Data Analyst is £28,268 per year in the London, United Kingdom Area. The average additional cash compensation for a Junior Data Analyst in the London, United Kingdom Area is £1,417, with a range from £274 - £7,326. Salaries estimates are based on 64 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the London, United Kingdom Area.']
# Falied city: London
# <Response [200]>
# Barcelona
# Junior Data Analyst Salaries in Barcelona, Spain Area
# Updated 2 May 2022
# €24,000
# €18K
# €24K
# €39K
# The average salary for Junior Data Analyst is €24,000 per year in the Barcelona, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Barcelona, Spain Area is €7,575, with a range from €2,820 - €12,330. Salaries estimates are based on 41 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Barcelona, Spain Area.
# Main list:  ['Barcelona', 'Junior Data Analyst Salaries in Barcelona, Spain Area', 'Updated 2 May 2022', '€24,000', '€18K', '€24K', '€39K', 'The average salary for Junior Data Analyst is €24,000 per year in the Barcelona, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Barcelona, Spain Area is €7,575, with a range from €2,820 - €12,330. Salaries estimates are based on 41 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Barcelona, Spain Area.']
# Falied city: Barcelona
# <Response [200]>
# Frankfurt
# Junior Data Analyst Salaries in Berlin, Germany Area
# Updated 1 May 2022
# €44,470
# €37K
# €44K
# €50K
# The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.
# Main list:  ['Frankfurt', 'Junior Data Analyst Salaries in Berlin, Germany Area', 'Updated 1 May 2022', '€44,470', '€37K', '€44K', '€50K', 'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.']
# Falied city: Frankfurt
# <Response [200]>
# Lisbon
# Junior Data Analyst Salaries in Lisbon, Portugal Area
# Updated 30 Apr 2022
# €1,259
# €1K
# €1K
# €2K
# The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.
# Main list:  ['Lisbon', 'Junior Data Analyst Salaries in Lisbon, Portugal Area', 'Updated 30 Apr 2022', '€1,259', '€1K', '€1K', '€2K', 'The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.']
# Falied city: Lisbon
#         city                                           position  \
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam        Junior Data Analyst Salaries in Dublin Area
# 0     Madrid        Junior Data Analyst Salaries in Dublin Area
# 0      Paris  Junior Data Analyst Salaries in Madrid, Spain ...
# 0     Berlin  Junior Data Analyst Salaries in Paris, France ...
# 0      Milan  Junior Data Analyst Salaries in Paris, France ...
# 0     London  Junior Data Analyst Salaries in Milan, Italy Area
# 0     Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022    €26,404   €20K   €26K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 2 May 2022    €26,537   €23K   €27K
# 0  Updated 30 Apr 2022     €1,259    €1K    €1K
#
#                                               maxpay  \
# 0                                               €40K
# 0                                               €40K
# 0                                               €40K
# 0                                               €32K
# 0                                               €48K
# 0                                               €48K
# 0  No additional cash compensation has been repor...
# 0                                                €2K
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...
# 0  The average salary for Junior Data Analyst is ...

# %%
masterlistbycity
# Out:
# [['Dublin',
#   'Junior Data Analyst Salaries in Dublin Area',
#   'Updated 2 May 2022',
#   '€33,139',
#   '€29K',
#   '€33K',
#   '€40K',
#   'How much does a Junior Data Analyst make in Dublin, Ireland? The average salary for a Junior Data Analyst is €33,139  in Dublin, Ireland. Salaries estimates are based on 11 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Dublin, Ireland.'],
#  ['Amsterdam',
#   'Junior Data Analyst Salaries in Amsterdam, Netherlands Area',
#   'Updated 2 May 2022',
#   '€17',
#   '€13',
#   '€17',
#   '€23',
#   'The average salary for Junior Data Analyst is €17 per month in the Amsterdam, Netherlands Area. The average additional cash compensation for a Junior Data Analyst in the Amsterdam, Netherlands Area is €2,000, with a range from €2,000 - €2,000. Salaries estimates are based on 4 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Amsterdam, Netherlands Area.'],
#  ['Madrid',
#   'Junior Data Analyst Salaries in Madrid, Spain Area',
#   'Updated 2 May 2022',
#   '€26,404',
#   '€20K',
#   '€26K',
#   '€32K',
#   'The average salary for Junior Data Analyst is €26,404 per year in the Madrid, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Madrid, Spain Area is €3,118, with a range from €2,110 - €5,000. Salaries estimates are based on 36 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Madrid, Spain Area.'],
#  ['Paris',
#   'Junior Data Analyst Salaries in Paris, France Area',
#   'Updated 2 May 2022',
#   '€39,835',
#   '€29K',
#   '€40K',
#   '€48K',
#   'The average salary for Junior Data Analyst is €39,835 per year in the Paris, France Area. The average additional cash compensation for a Junior Data Analyst in the Paris, France Area is €12,308, with a range from €4,148 - €20,469. Salaries estimates are based on 33 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Paris, France Area.'],
#  ['Berlin',
#   'Junior Data Analyst Salaries in Berlin, Germany Area',
#   'Updated 1 May 2022',
#   '€44,470',
#   '€37K',
#   '€44K',
#   '€50K',
#   'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.'],
#  ['Milan',
#   'Junior Data Analyst Salaries in Milan, Italy Area',
#   'Updated 2 May 2022',
#   '€26,537',
#   '€23K',
#   '€27K',
#   'No additional cash compensation has been reported for this role',
#   'How much does a Junior Data Analyst make in Milan, Italy? The average salary for a Junior Data Analyst is €26,537  in Milan, Italy. Salaries estimates are based on 8 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in Milan, Italy.'],
#  ['London',
#   'Junior Data Analyst Salaries in London, United Kingdom Area',
#   'Updated 2 May 2022',
#   '£28,268',
#   '£20K',
#   '£28K',
#   '£40K',
#   'The average salary for Junior Data Analyst is £28,268 per year in the London, United Kingdom Area. The average additional cash compensation for a Junior Data Analyst in the London, United Kingdom Area is £1,417, with a range from £274 - £7,326. Salaries estimates are based on 64 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the London, United Kingdom Area.'],
#  ['Barcelona',
#   'Junior Data Analyst Salaries in Barcelona, Spain Area',
#   'Updated 2 May 2022',
#   '€24,000',
#   '€18K',
#   '€24K',
#   '€39K',
#   'The average salary for Junior Data Analyst is €24,000 per year in the Barcelona, Spain Area. The average additional cash compensation for a Junior Data Analyst in the Barcelona, Spain Area is €7,575, with a range from €2,820 - €12,330. Salaries estimates are based on 41 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Barcelona, Spain Area.'],
#  ['Frankfurt',
#   'Junior Data Analyst Salaries in Berlin, Germany Area',
#   'Updated 1 May 2022',
#   '€44,470',
#   '€37K',
#   '€44K',
#   '€50K',
#   'The average salary for Junior Data Analyst is €44,470 per year in the Berlin, Germany Area. The average additional cash compensation for a Junior Data Analyst in the Berlin, Germany Area is €4,296, with a range from €4,296 - €4,296. Salaries estimates are based on 19 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Berlin, Germany Area.'],
#  ['Lisbon',
#   'Junior Data Analyst Salaries in Lisbon, Portugal Area',
#   'Updated 30 Apr 2022',
#   '€1,259',
#   '€1K',
#   '€1K',
#   '€2K',
#   'The average salary for Junior Data Analyst is €1,259 per month in the Lisbon, Portugal Area. The average additional cash compensation for a Junior Data Analyst in the Lisbon, Portugal Area is €1,546, with a range from €520 - €2,572. Salaries estimates are based on 7 salaries submitted anonymously to Glassdoor by Junior Data Analyst employees in the Lisbon, Portugal Area.']]

# %%
master_df = pd.DataFrame()
for city in masterlistbycity:
    df_temp_ = pd.DataFrame(np.array(city).reshape(-1,len(city)))
    df_temp_.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
    master_df = pd.concat([master_df,df_temp_])
master_df
# Out:
#         city                                           position  \
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam  Junior Data Analyst Salaries in Amsterdam, Net...
# 0     Madrid  Junior Data Analyst Salaries in Madrid, Spain ...
# 0      Paris  Junior Data Analyst Salaries in Paris, France ...
# 0     Berlin  Junior Data Analyst Salaries in Berlin, German...
# 0      Milan  Junior Data Analyst Salaries in Milan, Italy Area
# 0     London  Junior Data Analyst Salaries in London, United...
# 0  Barcelona  Junior Data Analyst Salaries in Barcelona, Spa...
# 0  Frankfurt  Junior Data Analyst Salaries in Berlin, German...
# 0     Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022        €17    €13    €17
# 0   Updated 2 May 2022    €26,404   €20K   €26K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0   Updated 2 May 2022    €26,537   €23K   €27K
# 0   Updated 2 May 2022    £28,268   £20K   £28K
# 0   Updated 2 May 2022    €24,000   €18K   €24K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0  Updated 30 Apr 2022     €1,259    €1K    €1K
#
#                                               maxpay  \
# 0                                               €40K
# 0                                                €23
# 0                                               €32K
# 0                                               €48K
# 0                                               €50K
# 0  No additional cash compensation has been repor...
# 0                                               £40K
# 0                                               €39K
# 0                                               €50K
# 0                                                €2K
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...

# %%
# Get data for every city in the list
maindf4= pd.DataFrame()
output =[]
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']
count = 0
mainlist=[]
masterlistbycity_ = []
for city in cities:
    
       
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        time.sleep(3)
        
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        
        
                
        #driver.get(html)
        soup = BeautifulSoup(html)
        output.append(soup)
        # send html to a .txt rewrite the name for each one 
        
        
       

        #url = driver.current_url
        #response = requests.get(url ,headers=headers)
        #print(response)
        #soup = BeautifulSoup(response.content)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys = city
        #citydetail[0]["value"]
        position_summary_detail.append(citys)
        print(citys)
    
        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        
        
        position = positiondetail[0].text
        position_summary_detail.append(position)
        #print(position)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)
        #print(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)
        #print(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)
        #print(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)
        #print(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)
        #print(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)
        #print(positioninfo)
        
        mainlist.append(position_summary_detail)
        #print('Main list: ',position_summary_detail)
        masterlistbycity_.append(position_summary_detail)
        


#Dataframe creation        
master_df_ = pd.DataFrame()
for cit in masterlistbycity:
    df_temp_ = pd.DataFrame(np.array(cit).reshape(-1,len(cit)))
    df_temp_.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
    master_df_ = pd.concat([master_df_,df_temp_])
master_df_
    

    
    
       
num = np.random.randint(1,10000000)    
glassdoor_role_table = master_df_.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_tableok{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_uniqueok.csv')
# Out:
# Dublin
# Amsterdam
# Madrid
# Paris
# Berlin
# Milan
# London
# Barcelona
# Frankfurt
# Lisbon

# %%
master_df_
# Out:
#         city                                           position  \
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam  Junior Data Analyst Salaries in Amsterdam, Net...
# 0     Madrid  Junior Data Analyst Salaries in Madrid, Spain ...
# 0      Paris  Junior Data Analyst Salaries in Paris, France ...
# 0     Berlin  Junior Data Analyst Salaries in Berlin, German...
# 0      Milan  Junior Data Analyst Salaries in Milan, Italy Area
# 0     London  Junior Data Analyst Salaries in London, United...
# 0  Barcelona  Junior Data Analyst Salaries in Barcelona, Spa...
# 0  Frankfurt  Junior Data Analyst Salaries in Berlin, German...
# 0     Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022        €17    €13    €17
# 0   Updated 2 May 2022    €26,404   €20K   €26K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0   Updated 2 May 2022    €26,537   €23K   €27K
# 0   Updated 2 May 2022    £28,268   £20K   £28K
# 0   Updated 2 May 2022    €24,000   €18K   €24K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0  Updated 30 Apr 2022     €1,259    €1K    €1K
#
#                                               maxpay  \
# 0                                               €40K
# 0                                                €23
# 0                                               €32K
# 0                                               €48K
# 0                                               €50K
# 0  No additional cash compensation has been repor...
# 0                                               £40K
# 0                                               €39K
# 0                                               €50K
# 0                                                €2K
#
#                                         positioninfo
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...

# %%
# Get data for every city in the list
maindf5= pd.DataFrame()
output =[]
cities = ['Dublin','Amsterdam','Madrid','Paris','Berlin','Milan','London','Barcelona','Frankfurt','Lisbon']
count = 0
mainlist=[]
masterlistbycity_1 = []
for city in cities:
    
       
        #Input location to find

        location = city
        seachboxlocation = driver.find_element(By.ID, "sc.location")
        seachboxlocation.click()
        seachboxlocation.clear()
        seachboxlocation.send_keys(Keys.CONTROL + "a")
        seachboxlocation.send_keys(Keys.DELETE)
        seachboxlocation.send_keys(location)
        time.sleep(3)
        #Click search
        search_button_click = driver.find_element(By.CLASS_NAME,'gd-ui-button').click()
        time.sleep(3)
        
        #Dataframe creation

        # get the page you are in using page_source attribute a nd soup it
        html = driver.page_source
        
        
                
        #driver.get(html)
        soup = BeautifulSoup(html)
        output.append(soup)
        # send html to a .txt rewrite the name for each one 
        
        
       

        #url = driver.current_url
        #response = requests.get(url ,headers=headers)
        #print(response)
        #soup = BeautifulSoup(response.content)

        #List creation
        position_summary_detail = []
        #Scraping detail required
        #Get city
        citydetail = soup.find_all('input', {'id':'sc.location'})
        citys = city
        #citydetail[0]["value"]
        position_summary_detail.append(citys)
        print(citys)
    
        #Get position 
        positiondetail = soup.find_all('h1', {'class':'m-0 css-1837fe'})
        
        
        position = positiondetail[0].text
        position_summary_detail.append(position)
        #print(position)

        #Get last update
        updatedatedetail = soup.find_all('span', {'class':'css-1b6bxoo'})
        updatedate = updatedatedetail[0].text
        position_summary_detail.append(updatedate)
        #print(updatedate)

        #get Avg salary per year
        avgbasepaydetail = soup.find_all('span', {'class':'m-0 css-146zilq ebrouyy2'})
        avgbasepay = avgbasepaydetail[0].text
        position_summary_detail.append(avgbasepay)
        #print(avgbasepay)

        #Get min salaryrange
        minpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        minpay = minpaydetail[0].text
        position_summary_detail.append(minpay)
        #print(minpay)

        #Get avg salaryrange
        avgpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        avgpay = avgpaydetail[2].text
        position_summary_detail.append(avgpay)
        #print(avgpay)

        #Get max salaryrange
        maxpaydetail = soup.find_all('p', {'class':'m-0 css-1vkj9it'})
        maxpay= maxpaydetail[4].text
        position_summary_detail.append(maxpay)
        #print(maxpay)

        #Get position resume info
        positioninfodetail = soup.find_all('div', {'class':'d-flex flex-column mt'})
        positioninfo =positioninfodetail[0].span.text
        position_summary_detail.append(positioninfo)
        #print(positioninfo)
        
        mainlist.append(position_summary_detail)
        #print('Main list: ',position_summary_detail)
        masterlistbycity_1.append(position_summary_detail)
        


#Dataframe creation        
master_df_1 = pd.DataFrame()
for cit in masterlistbycity_1:
    df_temp_ = pd.DataFrame(np.array(cit).reshape(-1,len(cit)))
    df_temp_.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
    master_df_1 = pd.concat([master_df_1,df_temp_])
master_df_1
    

    
    
       
num = np.random.randint(1,10000000)    
glassdoor_role_table = master_df_.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_tableok{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_uniquewebdeb.csv')
# Out:
# Dublin
# Amsterdam
# Madrid
# Paris
# Berlin
# Milan
# London
# Barcelona
# Frankfurt
# Lisbon

# %%
#Dataframe creation        
master_df_1 = pd.DataFrame()
for cit in masterlistbycity_1:
    df_temp_ = pd.DataFrame(np.array(cit).reshape(-1,len(cit)))
    df_temp_.columns = ['city','position', 'updatedate', 'avgbasepay', 'minpay', 'avgpay', 'maxpay', 'positioninfo']
    master_df_1 = pd.concat([master_df_1,df_temp_])
master_df_1
# Out:
#         city                                           position  \
# 0     Dublin       Junior Web Developer Salaries in Dublin Area
# 0  Amsterdam  Junior Web Developer Salaries in Amsterdam, Ne...
# 0     Madrid  Junior Web Developer Salaries in Madrid, Spain...
# 0      Paris  Junior Web Developer Salaries in Paris, France...
# 0     Berlin  Junior Web Developer Salaries in Berlin, Germa...
# 0      Milan  Junior Web Developer Salaries in Milan, Italy ...
# 0     London  Junior Web Developer Salaries in London, Unite...
# 0  Barcelona  Junior Web Developer Salaries in Barcelona, Sp...
# 0  Frankfurt  Junior Web Developer Salaries in Barcelona, Sp...
# 0     Lisbon  Junior Web Developer Salaries in Lisbon, Portu...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 3 May 2022    €30,972   €26K   €31K
# 0   Updated 3 May 2022    €42,168   €33K   €42K
# 0   Updated 3 May 2022    €23,214   €15K   €23K
# 0   Updated 3 May 2022    €41,064   €36K   €46K
# 0  Updated 27 Apr 2022    €38,000   €27K   €38K
# 0   Updated 3 May 2022     €1,293   €536    €1K
# 0   Updated 3 May 2022    £28,880   £22K   £29K
# 0  Updated 30 Apr 2022    €24,256   €12K   €24K
# 0  Updated 30 Apr 2022    €24,256   €12K   €24K
# 0  Updated 18 Apr 2022     €1,076   €794    €1K
#
#                                               maxpay  \
# 0                                               €36K
# 0                                               €65K
# 0                                               €42K
# 0  No additional cash compensation has been repor...
# 0                                               €45K
# 0                                                €2K
# 0                                               £37K
# 0                                               €51K
# 0                                               €51K
# 0                                                €1K
#
#                                         positioninfo
# 0  How much does a Junior Web Developer make in D...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...
# 0  How much does a Junior Web Developer make in P...
# 0  The average salary for Junior Web Developer is...
# 0  How much does a Junior Web Developer make in M...
# 0  How much does a Junior Web Developer make in L...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...

# %%
master_df_2roles = pd.concat([master_df_1,master_df_])
master_df_2roles
# Out:
#         city                                           position  \
# 0     Dublin       Junior Web Developer Salaries in Dublin Area
# 0  Amsterdam  Junior Web Developer Salaries in Amsterdam, Ne...
# 0     Madrid  Junior Web Developer Salaries in Madrid, Spain...
# 0      Paris  Junior Web Developer Salaries in Paris, France...
# 0     Berlin  Junior Web Developer Salaries in Berlin, Germa...
# 0      Milan  Junior Web Developer Salaries in Milan, Italy ...
# 0     London  Junior Web Developer Salaries in London, Unite...
# 0  Barcelona  Junior Web Developer Salaries in Barcelona, Sp...
# 0  Frankfurt  Junior Web Developer Salaries in Barcelona, Sp...
# 0     Lisbon  Junior Web Developer Salaries in Lisbon, Portu...
# 0     Dublin        Junior Data Analyst Salaries in Dublin Area
# 0  Amsterdam  Junior Data Analyst Salaries in Amsterdam, Net...
# 0     Madrid  Junior Data Analyst Salaries in Madrid, Spain ...
# 0      Paris  Junior Data Analyst Salaries in Paris, France ...
# 0     Berlin  Junior Data Analyst Salaries in Berlin, German...
# 0      Milan  Junior Data Analyst Salaries in Milan, Italy Area
# 0     London  Junior Data Analyst Salaries in London, United...
# 0  Barcelona  Junior Data Analyst Salaries in Barcelona, Spa...
# 0  Frankfurt  Junior Data Analyst Salaries in Berlin, German...
# 0     Lisbon  Junior Data Analyst Salaries in Lisbon, Portug...
#
#             updatedate avgbasepay minpay avgpay  \
# 0   Updated 3 May 2022    €30,972   €26K   €31K
# 0   Updated 3 May 2022    €42,168   €33K   €42K
# 0   Updated 3 May 2022    €23,214   €15K   €23K
# 0   Updated 3 May 2022    €41,064   €36K   €46K
# 0  Updated 27 Apr 2022    €38,000   €27K   €38K
# 0   Updated 3 May 2022     €1,293   €536    €1K
# 0   Updated 3 May 2022    £28,880   £22K   £29K
# 0  Updated 30 Apr 2022    €24,256   €12K   €24K
# 0  Updated 30 Apr 2022    €24,256   €12K   €24K
# 0  Updated 18 Apr 2022     €1,076   €794    €1K
# 0   Updated 2 May 2022    €33,139   €29K   €33K
# 0   Updated 2 May 2022        €17    €13    €17
# 0   Updated 2 May 2022    €26,404   €20K   €26K
# 0   Updated 2 May 2022    €39,835   €29K   €40K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0   Updated 2 May 2022    €26,537   €23K   €27K
# 0   Updated 2 May 2022    £28,268   £20K   £28K
# 0   Updated 2 May 2022    €24,000   €18K   €24K
# 0   Updated 1 May 2022    €44,470   €37K   €44K
# 0  Updated 30 Apr 2022     €1,259    €1K    €1K
#
#                                               maxpay  \
# 0                                               €36K
# 0                                               €65K
# 0                                               €42K
# 0  No additional cash compensation has been repor...
# 0                                               €45K
# 0                                                €2K
# 0                                               £37K
# 0                                               €51K
# 0                                               €51K
# 0                                                €1K
# 0                                               €40K
# 0                                                €23
# 0                                               €32K
# 0                                               €48K
# 0                                               €50K
# 0  No additional cash compensation has been repor...
# 0                                               £40K
# 0                                               €39K
# 0                                               €50K
# 0                                                €2K
#
#                                         positioninfo
# 0  How much does a Junior Web Developer make in D...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...
# 0  How much does a Junior Web Developer make in P...
# 0  The average salary for Junior Web Developer is...
# 0  How much does a Junior Web Developer make in M...
# 0  How much does a Junior Web Developer make in L...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...
# 0  The average salary for Junior Web Developer is...
# 0  How much does a Junior Data Analyst make in Du...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  How much does a Junior Data Analyst make in Mi...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...
# 0  The average salary for Junior Data Analyst is ...

# %%
glassdoor_role_table = master_df_2roles.reset_index()    
glassdoor_role_table.to_csv(f'glassdoor_role_tableok{num}.csv')
glassdoor_role_table.to_csv('glassdoor_role_table_unique2roles.csv')
